# %% [markdown]
# # load libraries and data

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
"""k fold 대신 stratified k fold"""
from sklearn.model_selection import StratifiedKFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

# psychosocial + rsfMRI + strurctural MRI + diffusion MRI

dataset_name = '.morct.rmvol.some'
train_out = Path(os.getcwd()+'/sex_classify/train'+dataset_name+'.csv')
test_out =Path(os.getcwd()+'/sex_classify/test'+dataset_name+'.csv')
#test.morct.rmvol.some.csv


train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)

# %%
train_data = train_data.drop(columns='fsqc_qc.y')
test_data=test_data.drop(columns='fsqc_qc.y')

# %%
target ='sex'
unused_feat = ['abcd_site','kfold' ,'race.ethnicity', 'subjectkey']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.

start_mor_index = np.where(test_data.columns.values == "lh_bankssts_area._.1")[0][0]

start_con_index = np.where(test_data.columns.values == "con_L.BSTS_L.CACG_count")[0][0]

mor = list(test_data.columns[start_mor_index:start_con_index])
con = list(test_data.columns[start_con_index:])



Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20


#print(len(train_data), len(train_data.columns))
print(len(mor))
print(len(con))
# Out:
# 999
# 3486

# %% [markdown]
# # Fine object featrues

# %% [markdown]
# # For getting feature importance

# %%
def feature(Num_feat, clf_res, test_data_processed, features):
    importance_res = []
    for i in clf_res:
        importance_clf =i.feature_importances_
        importance_res.append(importance_clf)
    
    importance=[importance_res[0][i]/5+importance_res[1][i]/5+ importance_res[2][i]/5+ importance_res[3][i]/5+ importance_res[4][i]/5 for i in range(len(importance_res[1]))]
    
    #print(importance)
    #plt.plot(importance)
    #plt.show()

    #importance_sort = importance.sort(reverse=True)
    
    #labels_importance=importance.argsort()[::-1]

    #feat_name_sort=test_data_processed[features].columns[labels_importance]
    feat_name_sort = test_data_processed[features].columns
    important_features = pd.DataFrame([importance],columns = feat_name_sort, index=['Importance']) 
    important_features =important_features.transpose().sort_values(by=['Importance'], ascending=False)
    important_features = important_features.head(50)
    """
    for i in range (len(test_data_processed[features].columns)):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])
    """
    return important_features

# %% [markdown]
# # Define function for preprocessing for Cross validation

# %%
def preprocessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    # 추가? 값 변경?
    test_data_processed["kfold"] = -1
    train_data_processed["kfold"] = -1

    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)
    
    """stratified로 수정"""
    # kf = KFold(n_splits=NUM_FOLDS) 
    kf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state =0)
    
    # enumerate: 각 split된 data set 순서대로 index를 함께 반환
        # ex. fold 0 일 때, 80%는 trn_, 20%는 val_
    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed[target])):
        #print(len(trn_), len(val_)) -> 출력: 4408, 1102
        # 'kfold' 칼럼은 cross validation할 때 fold 순서를 지정해놓은 것. 
        train_data_processed.loc[val_, 'kfold'] = fold
    
    print("done preprocessing")
    return train_data_processed, test_data_processed

# %% [markdown]
# # Finding best parameters

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(fold, train_data_processed, test_data_processed, features):
    
    """test data 생성"""
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    """
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,16]
    lr_ = [2e-2,1e-3]
    w_ = [0.01]
    g_ = [0.95,0.99]
    ss_ = [10,30]
    
    
    
    
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        """===================Cross Validation==================="""
        
        """validation & test 결과"""
        valid_res = []
        test_auc_res = []
        test_acc_res = []
     
        for i in range(1,fold):
            #print("fold ", i)
            # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
            clf = TabNetClassifier(n_a = hy[0],
                                n_d = hy[0],
                                optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                verbose=0)
            
            df_train = train_data_processed[train_data_processed['kfold'] != i]  # 5개 중 4개 train에 할당
            df_valid = train_data_processed[train_data_processed['kfold'] == i]  
            
            X_train = df_train[features].values
            Y_train = df_train[target].values
            
            X_valid = df_valid[features].values
            Y_valid = df_valid[target].values
            
            #print(i)
            #print(X_train.shape)
            #print(X_valid.shape)


            clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                    eval_name=['train', 'valid'], eval_metric=['auc'],
                    max_epochs=200 , patience=10)
       
            preds_acc = clf.predict(X_test)
            preds_prob = clf.predict_proba(X_test)
            test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
            test_acc = accuracy_score(preds_acc, Y_test)
            
            valid_res.append(clf.best_cost)
            test_auc_res.append(test_auc)
            test_acc_res.append(test_acc)
            print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        #print(valid_res)
        #print(test_auc_res)
        #print(test_acc_res)
        """valid와 test의 평균, 표준편차 출력"""
        print("=====parameter별 valid, test score=====")
        print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: %3f"%np.mean(test_auc_res), "Test ACC 평균: %3f"%np.mean(test_acc_res))

        if np.mean(test_auc_res)>max_auc:
            print("Find new maximum AUC!!")
            max_hy = hy
            max_auc = np.mean(test_auc_res)
    
    return max_hy

# %% [markdown]
# # Train with best parameter

# %%
def bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features):
    hy = max_hy
    print("Max hy:" ,hy)
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values
    """validation & test 결과"""
    valid_res = []
    test_auc_res = []
    test_acc_res = []
    clf_res = []
    preds_prob_res = []
    
    """해당 버전에 추가된 코드"""    
    y_valid_true = []
    y_valid_pred = []
    y_test_pred = []
    
    y_valid_subject = []
    y_test_subject = []
    
    
    for i in range(1,fold):
        clf = TabNetClassifier(n_a = hy[0],n_d = hy[0],
                           optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                           scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                           scheduler_fn=torch.optim.lr_scheduler.StepLR,
                           verbose=0)
        
        # 5개의 fold 사용했으므로 변수 fold 값은 차례대로 0,1,2,3,4 중 하나
        df_train = train_data_processed[train_data_processed['kfold'] != i]  # 5개 중 4개 train에 할당
        df_valid = train_data_processed[train_data_processed['kfold'] == i]  # 5개 중 1개 validation에 할당
        X_train = df_train[features].values
        Y_train = df_train[target].values
            
        X_valid = df_valid[features].values
        Y_valid = df_valid[target].values
        
        #print(i)
        #print(X_train.shape)
        #print(X_valid.shape)
        
        #print(X_valid)
        # 학습 전 subject key 가져옴
        y_valid_subject.append(df_valid['subjectkey'].values)
        y_test_subject.append(test_data_processed['subjectkey'].values)  
        """해당 버전 추가 코드"""
        y_valid_true.append(Y_valid)        
        
        # 학습
        clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                        eval_name=['train', 'valid'], eval_metric=['auc'],
                        max_epochs=200 , patience=30)
        
        # 결과들
        """fold별 validation & test data에 대한 target 예측 배열"""
        """해당 버전 추가 코드"""
        preds_prob_val= clf.predict_proba(X_valid)[:,1]
        y_valid_pred.append(preds_prob_val)
        # y_valid_pred.append(clf.predict(X_valid))
        y_test_pred.append(clf.predict(X_test))


        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)

                    
        valid_res.append(clf.best_cost)
        test_auc_res.append(test_auc)
        test_acc_res.append(test_acc)
        print('[%3d/%4d] '%(i+1, fold),'Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f'%test_auc, 'Test ACC: %.3f'%test_acc)
        preds_prob_res.append(preds_prob)
        clf_res.append(clf)
    
    """valid와 test의 평균, 표준편차 출력"""
    print("Validation 평균: %3f"%np.mean(valid_res), "Test AUC 평균: %3f "%np.mean(test_auc_res), "Test ACC 평균: %3f"%np.mean(test_acc_res))
    preds_prob=[preds_prob_res[0][i]/5+preds_prob_res[1][i]/5+ preds_prob_res[2][i]/5+ preds_prob_res[3][i]/5+ preds_prob_res[4][i]/5 
                for i in range(len(preds_prob_res[1]))]

    
    #preds_prob=[preds_prob_res[0][i]/5+preds_prob_res[1][i]/5+ preds_prob_res[2][i]/5+ preds_prob_res[3][i]/5+ preds_prob_res[4][i]/5 for i in range(len(preds_prob_res[1]))]
    preds_prob = np.array(preds_prob)
    valid_result = np.mean(valid_res)
    test_auc = np.mean(test_auc_res)
    test_acc = np.mean(test_acc_res) 
    
    #return test_auc,test_acc ,valid_result, clf_res, preds_prob, X_test, Y_test, y_valid_pred, y_test_pred, y_valid_subject, y_test_subject
    """수정 필요"""
    return test_auc,test_acc ,valid_result, clf_res, preds_prob, X_test, Y_test, y_valid_pred, y_test_pred, y_valid_subject, y_test_subject, y_valid_true

# %% [markdown]
# # Run function, Split data and and cross validation. This needs to be modified

# %%
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    name_test = test_data_processed['subjectkey'].values
    print("-------------------------------Training Begining-------------------------------")
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    # Start training
    max_hy = find_bestpar(fold, train_data_processed, test_data_processed, features)
    
    # if you want to just test the code, you should use this
    #max_hy = h_space[0]
    #print("Found maximum hyperparmeter, now work with that")
    
    print("-------------------------------Testing Begining-------------------------------")
    test_auc,test_acc ,valid_result, clf_res, preds_prob, X_test, Y_test, y_valid_pred, y_test_pred, y_valid_subject, y_test_subject, y_valid_true= bestpar_tuning(fold, 
                                                                                        train_data_processed, 
                                                                                        test_data_processed, 
                                                                                        max_hy, 
                                                                                        features)
    
    #print("-------------------------------Important Feature-------------------------------")
    import_feat=feature(Num_feat, clf_res, test_data_processed, features)
    #import_feat=0
    #preds_val_prob = clf.predict_proba(X_valid)

    return test_auc,test_acc ,valid_result, clf_res, preds_prob, X_test, Y_test, import_feat, name_test, y_valid_pred, y_test_pred, y_valid_subject, y_test_subject, y_valid_true

# %%
"""해당 버전 추가 코드"""
def save_prob_with_true(model):
    modeltype= "" 
    combined_model=pd.DataFrame({f"subjectkey": model.y_test_subject[0], f"Y_{modeltype}":model.Y_test, f"preds_prob_{modeltype}" :model.preds_prob[:,1]} )
    combined_model.to_csv(f"combined_forROC_{modeltype}_.csv")
    #mdoel.import_feat_every.to_csv(f"{modeltype}_features.csv")

    return combined_model
def save_prob_with_true_valid(model):
    modeltype= "" 
    
    combined_model=pd.DataFrame({f"subjectkey": list(itertools.chain(*model.y_valid_subject)), f"Y_{modeltype}":list(itertools.chain(*model.y_valid_true)), f"preds_prob_{modeltype}" :list(itertools.chain(*model.y_valid_pred) )})
    combined_model.to_csv(f"combined_forROC_{modeltype}_.csv")
    #model.import_feat_every.to_csv(f"{modeltype}_features.csv")

    return combined_model

# %% [markdown]
# # Main code

# %%
class model():
    def __init__(self, train_data_processed, test_data_processed, Num_FOLDS, Num_feat, features):
        test_auc,test_acc ,valid_result, clf_res, preds_prob, X_test, Y_test, import_feat, name_test, y_valid_pred, y_test_pred, y_valid_subject, y_test_subject, y_valid_true = run(train_data_processed,
                                                                              test_data_processed,
                                                                              Num_FOLDS, 
                                                                              Num_feat, 
                                                                              features)
    
    
        self.train_data_processed = train_data_processed
        self.test_auc = test_auc
        self.test_acc = test_acc
        self.valid_result = valid_result
        self.clf_res = clf_res 
        self.preds_prob = preds_prob 
        self.X_test = X_test
        self.Y_test = Y_test
        self.import_feat =  import_feat
        self.name_test = name_test
        self.features = features
        self.y_valid_pred =y_valid_pred
        self.y_test_pred = y_test_pred
        self.y_valid_subject= y_valid_subject
        self.y_test_subject = y_test_subject
        self.y_valid_true = y_valid_true
        """해당 버전 추가 코드"""        
        test_prob_result = save_prob_with_true(self)
        valid_prob_result = save_prob_with_true_valid(self)

        """해당 버전 추가 코드"""
        self.test_prob_result= test_prob_result
        self.valid_prob_result = valid_prob_result

# %%
train_data_processed, test_data_processed = preprocessing (train_data, test_data, Num_FOLDS)
# Out:
# done preprocessing

# %%
features_mor = [col for col in train_data_processed.columns if col in mor]

mor_model = model(train_data_processed, test_data_processed, 5, Num_feat, features_mor)
# Out:
# -------------------------------Training Begining-------------------------------
# -------------------------------Testing Begining-------------------------------
# Max hy: (4, 0.02, 0.01, 0.95, 10)
#
# Early stopping occured at epoch 8 with best_epoch = 7 and best_valid_auc = 0.80682
# Best weights from best epoch are automatically used!
# [  2/   5]  Valid score: 0.806821 Test AUC: 0.803 Test ACC: 0.731
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-509a1b8964fc> in <module>
#       1 features_mor = [col for col in train_data_processed.columns if col in mor]
#       2
# ----> 3 mor_model = model(train_data_processed, test_data_processed, 5, Num_feat, features_mor)
#
# <ipython-input-23-475dc06a9830> in __init__(self, train_data_processed, test_data_processed, Num_FOLDS, Num_feat, features)
#       5                                                                               Num_FOLDS,
#       6                                                                               Num_feat,
# ----> 7                                                                               features)
#       8
#       9
#
# <ipython-input-21-d568edea7240> in run(train_data_processed, test_data_processed, fold, Num_feat, features)
#      22                                                                                         test_data_processed,
#      23                                                                                         max_hy,
# ---> 24                                                                                         features)
#      25
#      26     #print("-------------------------------Important Feature-------------------------------")
#
# <ipython-input-20-cbe948427528> in bestpar_tuning(fold, train_data_processed, test_data_processed, max_hy, features)
#      50         clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)],
#      51                         eval_name=['train', 'valid'], eval_metric=['auc'],
# ---> 52                         max_epochs=200 , patience=1)
#      53
#      54         # 결과들
#
# ~/anaconda3/lib/python3.6/site-packages/pytorch_tabnet/abstract_model.py in fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised)
#     220             self._callback_container.on_epoch_begin(epoch_idx)
#     221
# --> 222             self._train_epoch(train_dataloader)
#     223
#     224             # Apply predict epoch to all eval sets
#
# ~/anaconda3/lib/python3.6/site-packages/pytorch_tabnet/abstract_model.py in _train_epoch(self, train_loader)
#     416         self.network.train()
#     417
# --> 418         for batch_idx, (X, y) in enumerate(train_loader):
#     419             self._callback_container.on_batch_begin(batch_idx)
#     420
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
# --> 477             data = _utils.pin_memory.pin_memory(data)
#     478         return data
#     479
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py in pin_memory(data)
#      53         return type(data)(*(pin_memory(sample) for sample in data))
#      54     elif isinstance(data, container_abcs.Sequence):
# ---> 55         return [pin_memory(sample) for sample in data]
#      56     elif hasattr(data, "pin_memory"):
#      57         return data.pin_memory()
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py in <listcomp>(.0)
#      53         return type(data)(*(pin_memory(sample) for sample in data))
#      54     elif isinstance(data, container_abcs.Sequence):
# ---> 55         return [pin_memory(sample) for sample in data]
#      56     elif hasattr(data, "pin_memory"):
#      57         return data.pin_memory()
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/pin_memory.py in pin_memory(data)
#      45 def pin_memory(data):
#      46     if isinstance(data, torch.Tensor):
# ---> 47         return data.pin_memory()
#      48     elif isinstance(data, string_classes):
#      49         return data
#
# KeyboardInterrupt:

# %%
#save the model 

exp_type = "sex_classify"

with open(f'./{exp_type}/features_mor.pkl', 'wb') as f:
    dill.dump(mor_model, f)

# %%
features_con = [col for col in train_data_processed.columns if col in con]

con_model = model(train_data_processed, test_data_processed, 22, Num_feat, features_con)

# %%
#save the model 

exp_type = "sex_classify"

with open(f'./{exp_type}/con_model.pkl', 'wb') as f:
    dill.dump(con_model, f)

# %%
features_con_mor = [col for col in train_data_processed.columns if col in con+mor]

con_mor_model = model(train_data_processed, test_data_processed, 22, Num_feat, features_con_mor)
# Out:
# -------------------------------Training Begining-------------------------------
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=16.0), HTML(value='')))
# Device used : cuda
#
# Early stopping occured at epoch 28 with best_epoch = 18 and best_valid_auc = 0.92507
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.925073 Test AUC: 0.933% Test ACC: 0.862%
# Device used : cuda
#
# Early stopping occured at epoch 40 with best_epoch = 30 and best_valid_auc = 0.94748
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.947477 Test AUC: 0.926% Test ACC: 0.845%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 23 and best_valid_auc = 0.94953
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.949530 Test AUC: 0.935% Test ACC: 0.868%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 28 and best_valid_auc = 0.94084
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.940845 Test AUC: 0.932% Test ACC: 0.838%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.96439
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.964386 Test AUC: 0.929% Test ACC: 0.855%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.94988
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.949879 Test AUC: 0.932% Test ACC: 0.846%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.95232
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.952317 Test AUC: 0.924% Test ACC: 0.832%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.96532
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.965322 Test AUC: 0.935% Test ACC: 0.867%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 23 and best_valid_auc = 0.95373
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.953727 Test AUC: 0.928% Test ACC: 0.847%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.93827
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.938275 Test AUC: 0.934% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 31 and best_valid_auc = 0.93741
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.937406 Test AUC: 0.928% Test ACC: 0.838%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 40 and best_valid_auc = 0.94559
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.945591 Test AUC: 0.929% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 37 with best_epoch = 27 and best_valid_auc = 0.95044
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.950440 Test AUC: 0.934% Test ACC: 0.826%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.94314
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.943135 Test AUC: 0.929% Test ACC: 0.831%
# Device used : cuda
#
# Early stopping occured at epoch 41 with best_epoch = 31 and best_valid_auc = 0.93472
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.934717 Test AUC: 0.929% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 28 and best_valid_auc = 0.94988
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.949877 Test AUC: 0.928% Test ACC: 0.850%
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 13 and best_valid_auc = 0.93612
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.936124 Test AUC: 0.921% Test ACC: 0.836%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.95202
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.952020 Test AUC: 0.933% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.94085
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.940852 Test AUC: 0.932% Test ACC: 0.859%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 29 and best_valid_auc = 0.94082
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.940823 Test AUC: 0.931% Test ACC: 0.860%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 29 and best_valid_auc = 0.92926
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.929261 Test AUC: 0.931% Test ACC: 0.857%
# =====parameter별 valid, test score=====
# Validation 평균: 0.945099 Test AUC 평균: 0.930087 Test ACC 평균: 0.849300
# Find new maximum AUC!!
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 22 and best_valid_auc = 0.92764
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.927639 Test AUC: 0.931% Test ACC: 0.842%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 32 and best_valid_auc = 0.9468
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.946800 Test AUC: 0.930% Test ACC: 0.835%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.94728
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.947278 Test AUC: 0.935% Test ACC: 0.860%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 40 and best_valid_auc = 0.94735
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.947353 Test AUC: 0.928% Test ACC: 0.840%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.96281
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.962813 Test AUC: 0.930% Test ACC: 0.868%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.94454
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.944541 Test AUC: 0.934% Test ACC: 0.857%
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 24 and best_valid_auc = 0.95693
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.956925 Test AUC: 0.929% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.96297
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.962973 Test AUC: 0.923% Test ACC: 0.824%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.95804
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.958042 Test AUC: 0.933% Test ACC: 0.848%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.93477
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.934774 Test AUC: 0.931% Test ACC: 0.855%
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 22 and best_valid_auc = 0.9409
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.940896 Test AUC: 0.933% Test ACC: 0.856%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 32 and best_valid_auc = 0.94831
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.948313 Test AUC: 0.925% Test ACC: 0.850%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.95044
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.950440 Test AUC: 0.929% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.9432
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.943197 Test AUC: 0.931% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 31 with best_epoch = 21 and best_valid_auc = 0.93066
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.930658 Test AUC: 0.926% Test ACC: 0.852%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.94928
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.949281 Test AUC: 0.928% Test ACC: 0.847%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.94066
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.940657 Test AUC: 0.927% Test ACC: 0.840%
# Device used : cuda
#
# Early stopping occured at epoch 44 with best_epoch = 34 and best_valid_auc = 0.9559
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.955898 Test AUC: 0.929% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.94354
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.943538 Test AUC: 0.926% Test ACC: 0.853%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.94196
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.941957 Test AUC: 0.929% Test ACC: 0.854%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.93553
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.935530 Test AUC: 0.931% Test ACC: 0.858%
# =====parameter별 valid, test score=====
# Validation 평균: 0.946167 Test AUC 평균: 0.929438 Test ACC 평균: 0.850033
# Device used : cuda
#
# Early stopping occured at epoch 28 with best_epoch = 18 and best_valid_auc = 0.93189
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.931891 Test AUC: 0.929% Test ACC: 0.854%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.94859
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.948588 Test AUC: 0.935% Test ACC: 0.861%
# Device used : cuda
#
# Early stopping occured at epoch 37 with best_epoch = 27 and best_valid_auc = 0.95105
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.951051 Test AUC: 0.930% Test ACC: 0.857%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 28 and best_valid_auc = 0.94985
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.949853 Test AUC: 0.925% Test ACC: 0.841%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.96646
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.966464 Test AUC: 0.935% Test ACC: 0.866%
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 22 and best_valid_auc = 0.945
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.945000 Test AUC: 0.932% Test ACC: 0.853%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 23 and best_valid_auc = 0.96589
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.965886 Test AUC: 0.936% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.96297
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.962973 Test AUC: 0.923% Test ACC: 0.824%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.95402
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.954025 Test AUC: 0.930% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.93705
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.937047 Test AUC: 0.930% Test ACC: 0.840%
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 24 and best_valid_auc = 0.93767
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.937671 Test AUC: 0.932% Test ACC: 0.861%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 35 and best_valid_auc = 0.94418
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.944184 Test AUC: 0.928% Test ACC: 0.859%
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 24 and best_valid_auc = 0.95444
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.954442 Test AUC: 0.929% Test ACC: 0.812%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.94801
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.948012 Test AUC: 0.927% Test ACC: 0.849%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.94026
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.940262 Test AUC: 0.926% Test ACC: 0.846%
# Device used : cuda
#
# Early stopping occured at epoch 45 with best_epoch = 35 and best_valid_auc = 0.94962
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.949623 Test AUC: 0.932% Test ACC: 0.846%
# Device used : cuda
#
# Early stopping occured at epoch 47 with best_epoch = 37 and best_valid_auc = 0.93998
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.939983 Test AUC: 0.935% Test ACC: 0.838%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.95337
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.953373 Test AUC: 0.932% Test ACC: 0.852%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.93795
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.937955 Test AUC: 0.928% Test ACC: 0.857%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.93539
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.935393 Test AUC: 0.924% Test ACC: 0.845%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 29 and best_valid_auc = 0.93481
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.934814 Test AUC: 0.931% Test ACC: 0.862%
# =====parameter별 valid, test score=====
# Validation 평균: 0.947071 Test AUC 평균: 0.929967 Test ACC 평균: 0.849593
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 22 and best_valid_auc = 0.92764
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.927639 Test AUC: 0.931% Test ACC: 0.842%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 28 and best_valid_auc = 0.94646
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.946462 Test AUC: 0.935% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.94728
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.947278 Test AUC: 0.935% Test ACC: 0.860%
# Device used : cuda
#
# Early stopping occured at epoch 50 with best_epoch = 40 and best_valid_auc = 0.94693
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.946927 Test AUC: 0.929% Test ACC: 0.852%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.96281
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.962813 Test AUC: 0.930% Test ACC: 0.868%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.94454
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.944541 Test AUC: 0.934% Test ACC: 0.857%
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 24 and best_valid_auc = 0.95693
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.956925 Test AUC: 0.929% Test ACC: 0.858%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.96297
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.962973 Test AUC: 0.923% Test ACC: 0.824%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.95804
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.958042 Test AUC: 0.933% Test ACC: 0.848%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.93477
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.934774 Test AUC: 0.931% Test ACC: 0.855%
# Device used : cuda
#
# Early stopping occured at epoch 32 with best_epoch = 22 and best_valid_auc = 0.9409
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.940896 Test AUC: 0.933% Test ACC: 0.856%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 32 and best_valid_auc = 0.94906
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.949064 Test AUC: 0.925% Test ACC: 0.849%
# Device used : cuda
#
# Early stopping occured at epoch 46 with best_epoch = 36 and best_valid_auc = 0.95261
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.952605 Test AUC: 0.924% Test ACC: 0.831%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.9432
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.943197 Test AUC: 0.931% Test ACC: 0.851%
# Device used : cuda
#
# Early stopping occured at epoch 31 with best_epoch = 21 and best_valid_auc = 0.93066
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.930658 Test AUC: 0.926% Test ACC: 0.852%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.94928
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.949281 Test AUC: 0.928% Test ACC: 0.847%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.94066
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.940657 Test AUC: 0.927% Test ACC: 0.840%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 29 and best_valid_auc = 0.95112
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.951118 Test AUC: 0.928% Test ACC: 0.855%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.94354
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.943538 Test AUC: 0.926% Test ACC: 0.853%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.94196
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.941957 Test AUC: 0.929% Test ACC: 0.854%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.93553
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.935530 Test AUC: 0.931% Test ACC: 0.858%
# =====parameter별 valid, test score=====
# Validation 평균: 0.946042 Test AUC 평균: 0.929463 Test ACC 평균: 0.850815
# Device used : cuda
#
# Early stopping occured at epoch 17 with best_epoch = 7 and best_valid_auc = 0.54751
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.547507 Test AUC: 0.536% Test ACC: 0.534%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.57822
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.578217 Test AUC: 0.523% Test ACC: 0.526%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.57334
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.573345 Test AUC: 0.514% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.58788
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.587882 Test AUC: 0.533% Test ACC: 0.516%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.5723
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.572295 Test AUC: 0.491% Test ACC: 0.487%
# Device used : cuda
#
# Early stopping occured at epoch 14 with best_epoch = 4 and best_valid_auc = 0.562
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.562005 Test AUC: 0.507% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.58781
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.587814 Test AUC: 0.494% Test ACC: 0.502%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.58469
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.584692 Test AUC: 0.496% Test ACC: 0.492%
# Device used : cuda
#
# Early stopping occured at epoch 10 with best_epoch = 0 and best_valid_auc = 0.53025
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.530253 Test AUC: 0.478% Test ACC: 0.488%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.58295
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.582951 Test AUC: 0.505% Test ACC: 0.505%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.57633
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.576332 Test AUC: 0.522% Test ACC: 0.519%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.57726
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.577261 Test AUC: 0.539% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 14 with best_epoch = 4 and best_valid_auc = 0.55448
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.554480 Test AUC: 0.502% Test ACC: 0.504%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.57543
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.575430 Test AUC: 0.527% Test ACC: 0.520%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.57008
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.570083 Test AUC: 0.528% Test ACC: 0.516%
# Device used : cuda
#
# Early stopping occured at epoch 16 with best_epoch = 6 and best_valid_auc = 0.59731
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.597312 Test AUC: 0.502% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.59989
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.599887 Test AUC: 0.534% Test ACC: 0.527%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.54973
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.549728 Test AUC: 0.524% Test ACC: 0.522%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.56404
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.564038 Test AUC: 0.523% Test ACC: 0.512%
# =====parameter별 valid, test score=====
# Validation 평균: 0.584027 Test AUC 평균: 0.528329 Test ACC 평균: 0.521757
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.58145
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.581452 Test AUC: 0.558% Test ACC: 0.548%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.57749
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.577493 Test AUC: 0.558% Test ACC: 0.538%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.54962
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.549621 Test AUC: 0.519% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 23 and best_valid_auc = 0.61593
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.615934 Test AUC: 0.559% Test ACC: 0.549%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.5723
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.572295 Test AUC: 0.491% Test ACC: 0.487%
# Device used : cuda
#
# Early stopping occured at epoch 14 with best_epoch = 4 and best_valid_auc = 0.562
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.562005 Test AUC: 0.507% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.60522
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.605223 Test AUC: 0.528% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.58469
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.584692 Test AUC: 0.496% Test ACC: 0.492%
# Device used : cuda
#
# Early stopping occured at epoch 10 with best_epoch = 0 and best_valid_auc = 0.53025
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.530253 Test AUC: 0.478% Test ACC: 0.488%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.58331
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.583313 Test AUC: 0.526% Test ACC: 0.516%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.56838
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.568381 Test AUC: 0.530% Test ACC: 0.529%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.56201
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.562010 Test AUC: 0.505% Test ACC: 0.513%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.56342
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.563417 Test AUC: 0.529% Test ACC: 0.526%
# Device used : cuda
#
# Early stopping occured at epoch 73 with best_epoch = 63 and best_valid_auc = 0.76273
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.762725 Test AUC: 0.743% Test ACC: 0.684%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.57543
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.575430 Test AUC: 0.527% Test ACC: 0.520%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.55597
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.555970 Test AUC: 0.522% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.55864
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.558641 Test AUC: 0.556% Test ACC: 0.536%
# Device used : cuda
#
# Early stopping occured at epoch 16 with best_epoch = 6 and best_valid_auc = 0.59731
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.597312 Test AUC: 0.502% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.59427
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.594269 Test AUC: 0.548% Test ACC: 0.540%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.54973
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.549728 Test AUC: 0.524% Test ACC: 0.522%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.62964
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.629643 Test AUC: 0.569% Test ACC: 0.552%
# =====parameter별 valid, test score=====
# Validation 평균: 0.584753 Test AUC 평균: 0.536936 Test ACC 평균: 0.529282
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.57647
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.576466 Test AUC: 0.541% Test ACC: 0.529%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.56643
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.566427 Test AUC: 0.521% Test ACC: 0.518%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 60 and best_valid_auc = 0.75893
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.758929 Test AUC: 0.733% Test ACC: 0.675%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.59703
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.597032 Test AUC: 0.528% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.5723
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.572295 Test AUC: 0.491% Test ACC: 0.487%
# Device used : cuda
#
# Early stopping occured at epoch 14 with best_epoch = 4 and best_valid_auc = 0.562
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.562005 Test AUC: 0.507% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.58218
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.582181 Test AUC: 0.532% Test ACC: 0.528%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.58469
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.584692 Test AUC: 0.496% Test ACC: 0.492%
# Device used : cuda
#
# Early stopping occured at epoch 10 with best_epoch = 0 and best_valid_auc = 0.53025
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.530253 Test AUC: 0.478% Test ACC: 0.488%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.57861
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.578605 Test AUC: 0.520% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.57324
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.573240 Test AUC: 0.526% Test ACC: 0.522%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.56415
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.564145 Test AUC: 0.523% Test ACC: 0.510%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.56969
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.569694 Test AUC: 0.534% Test ACC: 0.520%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.59152
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.591516 Test AUC: 0.521% Test ACC: 0.516%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.58498
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.584977 Test AUC: 0.540% Test ACC: 0.536%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.55201
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.552013 Test AUC: 0.510% Test ACC: 0.503%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.57222
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.572215 Test AUC: 0.506% Test ACC: 0.500%
# Device used : cuda
#
# Early stopping occured at epoch 16 with best_epoch = 6 and best_valid_auc = 0.59731
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.597312 Test AUC: 0.502% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.62833
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.628330 Test AUC: 0.530% Test ACC: 0.517%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.54973
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.549728 Test AUC: 0.524% Test ACC: 0.522%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.59114
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.591139 Test AUC: 0.536% Test ACC: 0.534%
# =====parameter별 valid, test score=====
# Validation 평균: 0.584914 Test AUC 평균: 0.528544 Test ACC 평균: 0.521513
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.58145
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.581452 Test AUC: 0.558% Test ACC: 0.548%
# Device used : cuda
#
# Early stopping occured at epoch 25 with best_epoch = 15 and best_valid_auc = 0.57749
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.577493 Test AUC: 0.558% Test ACC: 0.538%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.54962
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.549621 Test AUC: 0.519% Test ACC: 0.514%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 23 and best_valid_auc = 0.61593
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.615934 Test AUC: 0.559% Test ACC: 0.549%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.5723
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.572295 Test AUC: 0.491% Test ACC: 0.487%
# Device used : cuda
#
# Early stopping occured at epoch 14 with best_epoch = 4 and best_valid_auc = 0.562
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.562005 Test AUC: 0.507% Test ACC: 0.507%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.60522
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.605223 Test AUC: 0.528% Test ACC: 0.524%
# Device used : cuda
#
# Early stopping occured at epoch 13 with best_epoch = 3 and best_valid_auc = 0.58469
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.584692 Test AUC: 0.496% Test ACC: 0.492%
# Device used : cuda
#
# Early stopping occured at epoch 10 with best_epoch = 0 and best_valid_auc = 0.53025
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.530253 Test AUC: 0.478% Test ACC: 0.488%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.58331
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.583313 Test AUC: 0.526% Test ACC: 0.516%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.56838
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.568381 Test AUC: 0.530% Test ACC: 0.529%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.56201
# Best weights from best epoch are automatically used!
# [ 13/  22]  Valid score: 0.562010 Test AUC: 0.505% Test ACC: 0.513%
# Device used : cuda
#
# Early stopping occured at epoch 22 with best_epoch = 12 and best_valid_auc = 0.56342
# Best weights from best epoch are automatically used!
# [ 14/  22]  Valid score: 0.563417 Test AUC: 0.529% Test ACC: 0.526%
# Device used : cuda
#
# Early stopping occured at epoch 37 with best_epoch = 27 and best_valid_auc = 0.57676
# Best weights from best epoch are automatically used!
# [ 15/  22]  Valid score: 0.576762 Test AUC: 0.569% Test ACC: 0.554%
# Device used : cuda
#
# Early stopping occured at epoch 19 with best_epoch = 9 and best_valid_auc = 0.57543
# Best weights from best epoch are automatically used!
# [ 16/  22]  Valid score: 0.575430 Test AUC: 0.527% Test ACC: 0.520%
# Device used : cuda
#
# Early stopping occured at epoch 21 with best_epoch = 11 and best_valid_auc = 0.55597
# Best weights from best epoch are automatically used!
# [ 17/  22]  Valid score: 0.555970 Test AUC: 0.522% Test ACC: 0.521%
# Device used : cuda
#
# Early stopping occured at epoch 29 with best_epoch = 19 and best_valid_auc = 0.55864
# Best weights from best epoch are automatically used!
# [ 18/  22]  Valid score: 0.558641 Test AUC: 0.556% Test ACC: 0.536%
# Device used : cuda
#
# Early stopping occured at epoch 16 with best_epoch = 6 and best_valid_auc = 0.59731
# Best weights from best epoch are automatically used!
# [ 19/  22]  Valid score: 0.597312 Test AUC: 0.502% Test ACC: 0.508%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.59427
# Best weights from best epoch are automatically used!
# [ 20/  22]  Valid score: 0.594269 Test AUC: 0.548% Test ACC: 0.540%
# Device used : cuda
#
# Early stopping occured at epoch 15 with best_epoch = 5 and best_valid_auc = 0.54973
# Best weights from best epoch are automatically used!
# [ 21/  22]  Valid score: 0.549728 Test AUC: 0.524% Test ACC: 0.522%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 25 and best_valid_auc = 0.62964
# Best weights from best epoch are automatically used!
# [ 22/  22]  Valid score: 0.629643 Test AUC: 0.569% Test ACC: 0.552%
# =====parameter별 valid, test score=====
# Validation 평균: 0.575897 Test AUC 평균: 0.528659 Test ACC 평균: 0.523052
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 13 and best_valid_auc = 0.92698
# Best weights from best epoch are automatically used!
# [  2/  22]  Valid score: 0.926979 Test AUC: 0.937% Test ACC: 0.861%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.94852
# Best weights from best epoch are automatically used!
# [  3/  22]  Valid score: 0.948515 Test AUC: 0.931% Test ACC: 0.831%
# Device used : cuda
#
# Early stopping occured at epoch 34 with best_epoch = 24 and best_valid_auc = 0.95091
# Best weights from best epoch are automatically used!
# [  4/  22]  Valid score: 0.950913 Test AUC: 0.934% Test ACC: 0.861%
# Device used : cuda
#
# Early stopping occured at epoch 27 with best_epoch = 17 and best_valid_auc = 0.93907
# Best weights from best epoch are automatically used!
# [  5/  22]  Valid score: 0.939072 Test AUC: 0.930% Test ACC: 0.853%
# Device used : cuda
#
# Early stopping occured at epoch 26 with best_epoch = 16 and best_valid_auc = 0.96798
# Best weights from best epoch are automatically used!
# [  6/  22]  Valid score: 0.967981 Test AUC: 0.933% Test ACC: 0.859%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 26 and best_valid_auc = 0.94662
# Best weights from best epoch are automatically used!
# [  7/  22]  Valid score: 0.946618 Test AUC: 0.932% Test ACC: 0.857%
# Device used : cuda
#
# Early stopping occured at epoch 40 with best_epoch = 30 and best_valid_auc = 0.96019
# Best weights from best epoch are automatically used!
# [  8/  22]  Valid score: 0.960189 Test AUC: 0.933% Test ACC: 0.856%
# Device used : cuda
#
# Early stopping occured at epoch 24 with best_epoch = 14 and best_valid_auc = 0.96767
# Best weights from best epoch are automatically used!
# [  9/  22]  Valid score: 0.967671 Test AUC: 0.926% Test ACC: 0.841%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 20 and best_valid_auc = 0.96022
# Best weights from best epoch are automatically used!
# [ 10/  22]  Valid score: 0.960224 Test AUC: 0.934% Test ACC: 0.842%
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 13 and best_valid_auc = 0.94176
# Best weights from best epoch are automatically used!
# [ 11/  22]  Valid score: 0.941755 Test AUC: 0.928% Test ACC: 0.792%
# Device used : cuda
#
# Early stopping occured at epoch 38 with best_epoch = 28 and best_valid_auc = 0.94355
# Best weights from best epoch are automatically used!
# [ 12/  22]  Valid score: 0.943546 Test AUC: 0.936% Test ACC: 0.859%
# Device used : cuda

# %%
con_mor_model

# %%
def ext_csv(filename):
    name = "mor+con"
    print(name)
    csv_test= filename.test_prob_result
    csv_valid= filename.valid_prob_result
    csv_test.to_csv(f"./CSV/{name}_test.csv")
    csv_valid.to_csv(f"./CSV/{name}_valid.csv")
    
ext_csv(con_mor_model)
# Out:
# mor+con

# %%
import dill
exp_type = "sex_classify"

with open(f'./{exp_type}/con_mor_model_0511.pkl', 'wb') as f:
    dill.dump(con_mor_model, f)
