# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

dataset_name = 'morphology and connectome'
train_out = Path(os.getcwd()+'/data1/SuicidalIdeation_'+dataset_name+'_train.csv')
test_out =Path(os.getcwd()+'/data1/SuicidalIdeation_'+dataset_name+'_test.csv')


train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)
target ='Suicidalideation.x'
unused_feat = ['Set', 'subjectkey', 'abcd_site.x', 'Unnamed: 0', 'kflod',
               'src_subject_id','interview_date','gender','eventname']
n=0
start_mri = 0;
for i in test_data.columns:
    #print(i)
    if i =='lh_bankssts_area._.1':
        start_mri =n
    n +=1

    
mri = list(test_data.columns[start_mri:])
print(mri)
Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20
# Out:
# ['lh_bankssts_area._.1', 'lh_caudalanteriorcingulate_area._.1', 'lh_caudalmiddlefrontal_area._.1', 'lh_cuneus_area._.1', 'lh_entorhinal_area._.1', 'lh_fusiform_area._.1', 'lh_inferiorparietal_area._.1', 'lh_inferiortemporal_area._.1', 'lh_isthmuscingulate_area._.1', 'lh_lateraloccipital_area._.1', 'lh_lateralorbitofrontal_area._.1', 'lh_lingual_area._.1', 'lh_medialorbitofrontal_area._.1', 'lh_middletemporal_area._.1', 'lh_parahippocampal_area._.1', 'lh_paracentral_area._.1', 'lh_parsopercularis_area._.1', 'lh_parsorbitalis_area._.1', 'lh_parstriangularis_area._.1', 'lh_pericalcarine_area._.1', 'lh_postcentral_area._.1', 'lh_posteriorcingulate_area._.1', 'lh_precentral_area._.1', 'lh_precuneus_area._.1', 'lh_rostralanteriorcingulate_area._.1', 'lh_rostralmiddlefrontal_area._.1', 'lh_superiorfrontal_area._.1', 'lh_superiorparietal_area._.1', 'lh_superiortemporal_area._.1', 'lh_supramarginal_area._.1', 'lh_frontalpole_area._.1', 'lh_temporalpole_area._.1', 'lh_transversetemporal_area._.1', 'lh_insula_area._.1', 'lh_WhiteSurfArea_area._.1', 'rh_bankssts_area._.2', 'rh_caudalanteriorcingulate_area._.2', 'rh_caudalmiddlefrontal_area._.2', 'rh_cuneus_area._.2', 'rh_entorhinal_area._.2', 'rh_fusiform_area._.2', 'rh_inferiorparietal_area._.2', 'rh_inferiortemporal_area._.2', 'rh_isthmuscingulate_area._.2', 'rh_lateraloccipital_area._.2', 'rh_lateralorbitofrontal_area._.2', 'rh_lingual_area._.2', 'rh_medialorbitofrontal_area._.2', 'rh_middletemporal_area._.2', 'rh_parahippocampal_area._.2', 'rh_paracentral_area._.2', 'rh_parsopercularis_area._.2', 'rh_parsorbitalis_area._.2', 'rh_parstriangularis_area._.2', 'rh_pericalcarine_area._.2', 'rh_postcentral_area._.2', 'rh_posteriorcingulate_area._.2', 'rh_precentral_area._.2', 'rh_precuneus_area._.2', 'rh_rostralanteriorcingulate_area._.2', 'rh_rostralmiddlefrontal_area._.2', 'rh_superiorfrontal_area._.2', 'rh_superiorparietal_area._.2', 'rh_superiortemporal_area._.2', 'rh_supramarginal_area._.2', 'rh_frontalpole_area._.2', 'rh_temporalpole_area._.2', 'rh_transversetemporal_area._.2', 'rh_insula_area._.2', 'rh_WhiteSurfArea_area._.2', 'lh_bankssts_meancurv._.3', 'lh_caudalanteriorcingulate_meancurv._.3', 'lh_caudalmiddlefrontal_meancurv._.3', 'lh_cuneus_meancurv._.3', 'lh_entorhinal_meancurv._.3', 'lh_fusiform_meancurv._.3', 'lh_inferiorparietal_meancurv._.3', 'lh_inferiortemporal_meancurv._.3', 'lh_isthmuscingulate_meancurv._.3', 'lh_lateraloccipital_meancurv._.3', 'lh_lateralorbitofrontal_meancurv._.3', 'lh_lingual_meancurv._.3', 'lh_medialorbitofrontal_meancurv._.3', 'lh_middletemporal_meancurv._.3', 'lh_parahippocampal_meancurv._.3', 'lh_paracentral_meancurv._.3', 'lh_parsopercularis_meancurv._.3', 'lh_parsorbitalis_meancurv._.3', 'lh_parstriangularis_meancurv._.3', 'lh_pericalcarine_meancurv._.3', 'lh_postcentral_meancurv._.3', 'lh_posteriorcingulate_meancurv._.3', 'lh_precentral_meancurv._.3', 'lh_precuneus_meancurv._.3', 'lh_rostralanteriorcingulate_meancurv._.3', 'lh_rostralmiddlefrontal_meancurv._.3', 'lh_superiorfrontal_meancurv._.3', 'lh_superiorparietal_meancurv._.3', 'lh_superiortemporal_meancurv._.3', 'lh_supramarginal_meancurv._.3', 'lh_frontalpole_meancurv._.3', 'lh_temporalpole_meancurv._.3', 'lh_transversetemporal_meancurv._.3', 'lh_insula_meancurv._.3', 'rh_bankssts_meancurv._.4', 'rh_caudalanteriorcingulate_meancurv._.4', 'rh_caudalmiddlefrontal_meancurv._.4', 'rh_cuneus_meancurv._.4', 'rh_entorhinal_meancurv._.4', 'rh_fusiform_meancurv._.4', 'rh_inferiorparietal_meancurv._.4', 'rh_inferiortemporal_meancurv._.4', 'rh_isthmuscingulate_meancurv._.4', 'rh_lateraloccipital_meancurv._.4', 'rh_lateralorbitofrontal_meancurv._.4', 'rh_lingual_meancurv._.4', 'rh_medialorbitofrontal_meancurv._.4', 'rh_middletemporal_meancurv._.4', 'rh_parahippocampal_meancurv._.4', 'rh_paracentral_meancurv._.4', 'rh_parsopercularis_meancurv._.4', 'rh_parsorbitalis_meancurv._.4', 'rh_parstriangularis_meancurv._.4', 'rh_pericalcarine_meancurv._.4', 'rh_postcentral_meancurv._.4', 'rh_posteriorcingulat ...

# %%
mri
# Out:
# ['lh_bankssts_area._.1',
#  'lh_caudalanteriorcingulate_area._.1',
#  'lh_caudalmiddlefrontal_area._.1',
#  'lh_cuneus_area._.1',
#  'lh_entorhinal_area._.1',
#  'lh_fusiform_area._.1',
#  'lh_inferiorparietal_area._.1',
#  'lh_inferiortemporal_area._.1',
#  'lh_isthmuscingulate_area._.1',
#  'lh_lateraloccipital_area._.1',
#  'lh_lateralorbitofrontal_area._.1',
#  'lh_lingual_area._.1',
#  'lh_medialorbitofrontal_area._.1',
#  'lh_middletemporal_area._.1',
#  'lh_parahippocampal_area._.1',
#  'lh_paracentral_area._.1',
#  'lh_parsopercularis_area._.1',
#  'lh_parsorbitalis_area._.1',
#  'lh_parstriangularis_area._.1',
#  'lh_pericalcarine_area._.1',
#  'lh_postcentral_area._.1',
#  'lh_posteriorcingulate_area._.1',
#  'lh_precentral_area._.1',
#  'lh_precuneus_area._.1',
#  'lh_rostralanteriorcingulate_area._.1',
#  'lh_rostralmiddlefrontal_area._.1',
#  'lh_superiorfrontal_area._.1',
#  'lh_superiorparietal_area._.1',
#  'lh_superiortemporal_area._.1',
#  'lh_supramarginal_area._.1',
#  'lh_frontalpole_area._.1',
#  'lh_temporalpole_area._.1',
#  'lh_transversetemporal_area._.1',
#  'lh_insula_area._.1',
#  'lh_WhiteSurfArea_area._.1',
#  'rh_bankssts_area._.2',
#  'rh_caudalanteriorcingulate_area._.2',
#  'rh_caudalmiddlefrontal_area._.2',
#  'rh_cuneus_area._.2',
#  'rh_entorhinal_area._.2',
#  'rh_fusiform_area._.2',
#  'rh_inferiorparietal_area._.2',
#  'rh_inferiortemporal_area._.2',
#  'rh_isthmuscingulate_area._.2',
#  'rh_lateraloccipital_area._.2',
#  'rh_lateralorbitofrontal_area._.2',
#  'rh_lingual_area._.2',
#  'rh_medialorbitofrontal_area._.2',
#  'rh_middletemporal_area._.2',
#  'rh_parahippocampal_area._.2',
#  'rh_paracentral_area._.2',
#  'rh_parsopercularis_area._.2',
#  'rh_parsorbitalis_area._.2',
#  'rh_parstriangularis_area._.2',
#  'rh_pericalcarine_area._.2',
#  'rh_postcentral_area._.2',
#  'rh_posteriorcingulate_area._.2',
#  'rh_precentral_area._.2',
#  'rh_precuneus_area._.2',
#  'rh_rostralanteriorcingulate_area._.2',
#  'rh_rostralmiddlefrontal_area._.2',
#  'rh_superiorfrontal_area._.2',
#  'rh_superiorparietal_area._.2',
#  'rh_superiortemporal_area._.2',
#  'rh_supramarginal_area._.2',
#  'rh_frontalpole_area._.2',
#  'rh_temporalpole_area._.2',
#  'rh_transversetemporal_area._.2',
#  'rh_insula_area._.2',
#  'rh_WhiteSurfArea_area._.2',
#  'lh_bankssts_meancurv._.3',
#  'lh_caudalanteriorcingulate_meancurv._.3',
#  'lh_caudalmiddlefrontal_meancurv._.3',
#  'lh_cuneus_meancurv._.3',
#  'lh_entorhinal_meancurv._.3',
#  'lh_fusiform_meancurv._.3',
#  'lh_inferiorparietal_meancurv._.3',
#  'lh_inferiortemporal_meancurv._.3',
#  'lh_isthmuscingulate_meancurv._.3',
#  'lh_lateraloccipital_meancurv._.3',
#  'lh_lateralorbitofrontal_meancurv._.3',
#  'lh_lingual_meancurv._.3',
#  'lh_medialorbitofrontal_meancurv._.3',
#  'lh_middletemporal_meancurv._.3',
#  'lh_parahippocampal_meancurv._.3',
#  'lh_paracentral_meancurv._.3',
#  'lh_parsopercularis_meancurv._.3',
#  'lh_parsorbitalis_meancurv._.3',
#  'lh_parstriangularis_meancurv._.3',
#  'lh_pericalcarine_meancurv._.3',
#  'lh_postcentral_meancurv._.3',
#  'lh_posteriorcingulate_meancurv._.3',
#  'lh_precentral_meancurv._.3',
#  'lh_precuneus_meancurv._.3',
#  'lh_rostralanteriorcingulate_meancurv._.3',
#  'lh_rostralmiddlefrontal_meancurv._.3',
#  'lh_superiorfrontal_meancurv._.3',
#  'lh_superiorparietal_meancurv._.3',
#  'lh_superiortemporal_meancurv._.3',
#  'lh_supramarginal_meancurv._.3',
#  'lh_frontalpole_meancurv._.3',
#  'lh_temporalpole_meancurv._.3',
#  'lh_transversetemporal_meancurv._.3',
#  'lh_insula_meancurv._.3',
#  'rh_bankssts_meancurv._.4',
#  'rh_caudalanteriorcingulate_meancurv._.4',
#  'rh_caudalmiddlefrontal_meancurv._.4',
#  'rh_cuneus_meancurv._.4',
#  'rh_entorhinal_meancurv._.4',
#  'rh_fusiform_meancurv._.4',
#  'rh_inferiorparietal_meancurv._.4',
#  'rh_inferiortemporal_meancurv._.4',
#  'rh_isthmuscingulate_meancurv._.4',
#  'rh_lateraloccipital_meancurv._.4',
#  'rh_lateralorbitofrontal_meancurv._.4',
#  'rh_lingual_meancurv._.4',
#  'rh_medialorbitofrontal_meancurv._.4',
#  'rh_middletemporal_meancurv._.4',
#  'rh_parahippocampal_meancurv._.4',
#  'rh_paracentral_meancurv._.4',
#  'rh_parsopercularis_meancurv._.4',
#  'rh_parsorbitalis_meancurv._.4',
#  'rh_parstriangularis_meancurv._.4',
#  'rh_pericalcarine_meancurv._.4',
#  'rh_postcentral_meancurv._.4',
#  'rh_posteriorcingulate_meancurv._.4',
#  'rh_precentral_meancurv._.4',
#  'rh_precuneus_meancurv._.4',
#  'rh_rostralanteriorcingulate_meancurv._.4',
#  'rh_rostralmiddlefrontal_meancurv._.4',
#  'rh_superiorfrontal_meancurv._.4',
#  'rh_superiorparietal_meancurv._.4',
#  'rh_superiortemporal_meancurv._.4',
#  'rh_supramarginal_meancurv._.4',
#  'rh_frontalpole_meancurv._.4',
#  'rh_temporalpole_meancurv._.4',
#  'rh_transversetemporal_meancurv._.4',
#  'rh_insula_meancurv._.4',
#  'lh_bankssts_thickness._.5',
#  'lh_caudalanteriorcingulate_thickness._.5',
#  'lh_caudalmiddlefrontal_thickness._.5',
#  'lh_cuneus_thickness._.5',
#  'lh_entorhinal_thickness._.5',
#  'lh_fusiform_thickness._.5',
#  'lh_inferiorparietal_thickness._.5',
#  'lh_inferiortemporal_thickness._.5',
#  'lh_isthmuscingulate_thickness._.5',
#  'lh_lateraloccipital_thickness._.5',
#  'lh_lateralorbitofrontal_thickness._.5',
#  'lh_lingual_thickness._.5',
#  'lh_medialorbitofrontal_thickness._.5',
#  'lh_middletemporal_thickness._.5',
#  'lh_parahippocampal_thickness._.5',
#  'lh_paracentral_thickness._.5',
#  'lh_parsopercularis_thickness._.5',
#  'lh_parsorbitalis_thickness._.5',
#  'lh_parstriangularis_thickness._.5',
#  'lh_pericalcarine_thickness._.5',
#  'lh_postcentral_thickness._.5',
#  'lh_posteriorcingulate_thickness._.5',
#  'lh_precentral_thickness._.5',
#  'lh_precuneus_thickness._.5',
#  'lh_rostralanteriorcingulate_thickness._.5',
#  'lh_rostralmiddlefrontal_thickness._.5',
#  'lh_superiorfrontal_thickness._.5',
#  'lh_superiorparietal_thickness._.5',
#  'lh_superiortemporal_thickness._.5',
#  'lh_supramarginal_thickness._.5',
#  'lh_frontalpole_thickness._.5',
#  'lh_temporalpole_thickness._.5',
#  'lh_transversetemporal_thickness._.5',
#  'lh_insula_thickness._.5',
#  'lh_MeanThickness_thickness._.5',
#  'rh_bankssts_thickness._.6',
#  'rh_caudalanteriorcingulate_thickness._.6',
#  'rh_caudalmiddlefrontal_thickness._.6',
#  'rh_cuneus_thickness._.6',
#  'rh_entorhinal_thickness._.6',
#  'rh_fusiform_thickness._.6',
#  'rh_inferiorparietal_thickness._.6',
#  'rh_inferiortemporal_thickness._.6',
#  'rh_isthmuscingulate_thickness._.6',
#  'rh_lateraloccipital_thickness._.6',
#  'rh_lateralorbitofrontal_thickness._.6',
#  'rh_lingual_thickness._.6',
#  'rh_medialorbitofrontal_thickness._.6',
#  'rh_middletemporal_thickness._.6',
#  'rh_parahippocampal_thickness._.6',
#  'rh_paracentral_thickness._.6',
#  'rh_parsopercularis_thickness._.6',
#  'rh_parsorbitalis_thickness._.6',
#  'rh_parstriangularis_thickness._.6',
#  'rh_pericalcarine_thickness._.6',
#  'rh_postcentral_thickness._.6',
#  'rh_posteriorcingulate_thickness._.6',
#  'rh_precentral_thickness._.6',
#  'rh_precuneus_thickness._.6',
#  'rh_rostralanteriorcingulate_thickness._.6',
#  'rh_rostralmiddlefrontal_thickness._.6',
#  'rh_superiorfrontal_thickness._.6',
#  'rh_superiorparietal_thickness._.6',
#  'rh_superiortemporal_thickness._.6',
#  'rh_supramarginal_thickness._.6',
#  'rh_frontalpole_thickness._.6',
#  'rh_temporalpole_thickness._.6',
#  'rh_transversetemporal_thickness._.6',
#  'rh_insula_thickness._.6',
#  'rh_MeanThickness_thickness._.6',
#  'lh_bankssts_volume._.7',
#  'lh_caudalanteriorcingulate_volume._.7',
#  'lh_caudalmiddlefrontal_volume._.7',
#  'lh_cuneus_volume._.7',
#  'lh_entorhinal_volume._.7',
#  'lh_fusiform_volume._.7',
#  'lh_inferiorparietal_volume._.7',
#  'lh_inferiortemporal_volume._.7',
#  'lh_isthmuscingulate_volume._.7',
#  'lh_lateraloccipital_volume._.7',
#  'lh_lateralorbitofrontal_volume._.7',
#  'lh_lingual_volume._.7',
#  'lh_medialorbitofrontal_volume._.7',
#  'lh_middletemporal_volume._.7',
#  'lh_parahippocampal_volume._.7',
#  'lh_paracentral_volume._.7',
#  'lh_parsopercularis_volume._.7',
#  'lh_parsorbitalis_volume._.7',
#  'lh_parstriangularis_volume._.7',
#  'lh_pericalcarine_volume._.7',
#  'lh_postcentral_volume._.7',
#  'lh_posteriorcingulate_volume._.7',
#  'lh_precentral_volume._.7',
#  'lh_precuneus_volume._.7',
#  'lh_rostralanteriorcingulate_volume._.7',
#  'lh_rostralmiddlefrontal_volume._.7',
#  'lh_superiorfrontal_volume._.7',
#  'lh_superiorparietal_volume._.7',
#  'lh_superiortemporal_volume._.7',
#  'lh_supramarginal_volume._.7',
#  'lh_frontalpole_volume._.7',
#  'lh_temporalpole_volume._.7',
#  'lh_transversetemporal_volume._.7',
#  'lh_insula_volume._.7',
#  'rh_bankssts_volume._.8',
#  'rh_caudalanteriorcingulate_volume._.8',
#  'rh_caudalmiddlefrontal_volume._.8',
#  'rh_cuneus_volume._.8',
#  'rh_entorhinal_volume._.8',
#  'rh_fusiform_volume._.8',
#  'rh_inferiorparietal_volume._.8',
#  'rh_inferiortemporal_volume._.8',
#  'rh_isthmuscingulate_volume._.8',
#  'rh_lateraloccipital_volume._.8',
#  'rh_lateralorbitofrontal_volume._.8',
#  'rh_lingual_volume._.8',
#  'rh_medialorbitofrontal_volume._.8',
#  'rh_middletemporal_volume._.8',
#  'rh_parahippocampal_volume._.8',
#  'rh_paracentral_volume._.8',
#  'rh_parsopercularis_volume._.8',
#  'rh_parsorbitalis_volume._.8',
#  'rh_parstriangularis_volume._.8',
#  'rh_pericalcarine_volume._.8',
#  'rh_postcentral_volume._.8',
#  'rh_posteriorcingulate_volume._.8',
#  'rh_precentral_volume._.8',
#  'rh_precuneus_volume._.8',
#  'rh_rostralanteriorcingulate_volume._.8',
#  'rh_rostralmiddlefrontal_volume._.8',
#  'rh_superiorfrontal_volume._.8',
#  'rh_superiorparietal_volume._.8',
#  'rh_superiortemporal_volume._.8',
#  'rh_supramarginal_volume._.8',
#  'rh_frontalpole_volume._.8',
#  'rh_temporalpole_volume._.8',
#  'rh_transversetemporal_volume._.8',
#  'rh_insula_volume._.8',
#  'Left.Lateral.Ventricle._.9',
#  'Left.Inf.Lat.Vent._.9',
#  'Left.Cerebellum.White.Matter._.9',
#  'Left.Cerebellum.Cortex._.9',
#  'Left.Caudate._.9',
#  'Left.Putamen._.9',
#  'Left.Pallidum._.9',
#  'X3rd.Ventricle._.9',
#  'X4th.Ventricle._.9',
#  'Brain.Stem._.9',
#  'Left.Hippocampus._.9',
#  'Left.Amygdala._.9',
#  'CSF._.9',
#  'Left.Accumbens.area._.9',
#  'Left.VentralDC._.9',
#  'Left.vessel._.9',
#  'Left.choroid.plexus._.9',
#  'Right.Lateral.Ventricle._.9',
#  'Right.Inf.Lat.Vent._.9',
#  'Right.Cerebellum.White.Matter._.9',
#  'Right.Cerebellum.Cortex._.9',
#  'Right.Caudate._.9',
#  'Right.Putamen._.9',
#  'Right.Pallidum._.9',
#  'Right.Hippocampus._.9',
#  'Right.Amygdala._.9',
#  'Right.Accumbens.area._.9',
#  'Right.VentralDC._.9',
#  'Right.vessel._.9',
#  'Right.choroid.plexus._.9',
#  'X5th.Ventricle._.9',
#  'WM.hypointensities._.9',
#  'Left.WM.hypointensities._.9',
#  'Right.WM.hypointensities._.9',
#  'non.WM.hypointensities._.9',
#  'Left.non.WM.hypointensities._.9',
#  'Right.non.WM.hypointensities._.9',
#  'Optic.Chiasm._.9',
#  'CC_Posterior._.9',
#  'CC_Mid_Posterior._.9',
#  'CC_Central._.9',
#  'CC_Mid_Anterior._.9',
#  'CC_Anterior._.9',
#  'lhSurfaceHoles._.9',
#  'rhSurfaceHoles._.9',
#  'SurfaceHoles._.9',
#  'lh_G.S_frontomargin_area._.10',
#  'lh_G.S_occipital_inf_area._.10',
#  'lh_G.S_paracentral_area._.10',
#  'lh_G.S_subcentral_area._.10',
#  'lh_G.S_transv_frontopol_area._.10',
#  'lh_G.S_cingul.Ant_area._.10',
#  'lh_G.S_cingul.Mid.Ant_area._.10',
#  'lh_G.S_cingul.Mid.Post_area._.10',
#  'lh_G_cingul.Post.dorsal_area._.10',
#  'lh_G_cingul.Post.ventral_area._.10',
#  'lh_G_cuneus_area._.10',
#  'lh_G_front_inf.Opercular_area._.10',
#  'lh_G_front_inf.Orbital_area._.10',
#  'lh_G_front_inf.Triangul_area._.10',
#  'lh_G_front_middle_area._.10',
#  'lh_G_front_sup_area._.10',
#  'lh_G_Ins_lg.S_cent_ins_area._.10',
#  'lh_G_insular_short_area._.10',
#  'lh_G_occipital_middle_area._.10',
#  'lh_G_occipital_sup_area._.10',
#  'lh_G_oc.temp_lat.fusifor_area._.10',
#  'lh_G_oc.temp_med.Lingual_area._.10',
#  'lh_G_oc.temp_med.Parahip_area._.10',
#  'lh_G_orbital_area._.10',
#  'lh_G_pariet_inf.Angular_area._.10',
#  'lh_G_pariet_inf.Supramar_area._.10',
#  'lh_G_parietal_sup_area._.10',
#  'lh_G_postcentral_area._.10',
#  'lh_G_precentral_area._.10',
#  'lh_G_precuneus_area._.10',
#  'lh_G_rectus_area._.10',
#  'lh_G_subcallosal_area._.10',
#  'lh_G_temp_sup.G_T_transv_area._.10',
#  'lh_G_temp_sup.Lateral_area._.10',
#  'lh_G_temp_sup.Plan_polar_area._.10',
#  'lh_G_temp_sup.Plan_tempo_area._.10',
#  'lh_G_temporal_inf_area._.10',
#  'lh_G_temporal_middle_area._.10',
#  'lh_Lat_Fis.ant.Horizont_area._.10',
#  'lh_Lat_Fis.ant.Vertical_area._.10',
#  'lh_Lat_Fis.post_area._.10',
#  'lh_Pole_occipital_area._.10',
#  'lh_Pole_temporal_area._.10',
#  'lh_S_calcarine_area._.10',
#  'lh_S_central_area._.10',
#  'lh_S_cingul.Marginalis_area._.10',
#  'lh_S_circular_insula_ant_area._.10',
#  'lh_S_circular_insula_inf_area._.10',
#  'lh_S_circular_insula_sup_area._.10',
#  'lh_S_collat_transv_ant_area._.10',
#  'lh_S_collat_transv_post_area._.10',
#  'lh_S_front_inf_area._.10',
#  'lh_S_front_middle_area._.10',
#  'lh_S_front_sup_area._.10',
#  'lh_S_interm_prim.Jensen_area._.10',
#  'lh_S_intrapariet.P_trans_area._.10',
#  'lh_S_oc_middle.Lunatus_area._.10',
#  'lh_S_oc_sup.transversal_area._.10',
#  'lh_S_occipital_ant_area._.10',
#  'lh_S_oc.temp_lat_area._.10',
#  'lh_S_oc.temp_med.Lingual_area._.10',
#  'lh_S_orbital_lateral_area._.10',
#  'lh_S_orbital_med.olfact_area._.10',
#  'lh_S_orbital.H_Shaped_area._.10',
#  'lh_S_parieto_occipital_area._.10',
#  'lh_S_pericallosal_area._.10',
#  'lh_S_postcentral_area._.10',
#  'lh_S_precentral.inf.part_area._.10',
#  'lh_S_precentral.sup.part_area._.10',
#  'lh_S_suborbital_area._.10',
#  'lh_S_subparietal_area._.10',
#  'lh_S_temporal_inf_area._.10',
#  'lh_S_temporal_sup_area._.10',
#  'lh_S_temporal_transverse_area._.10',
#  'lh_WhiteSurfArea_area._.10',
#  'lh_G.S_frontomargin_meancurv._.11',
#  'lh_G.S_occipital_inf_meancurv._.11',
#  'lh_G.S_paracentral_meancurv._.11',
#  'lh_G.S_subcentral_meancurv._.11',
#  'lh_G.S_transv_frontopol_meancurv._.11',
#  'lh_G.S_cingul.Ant_meancurv._.11',
#  'lh_G.S_cingul.Mid.Ant_meancurv._.11',
#  'lh_G.S_cingul.Mid.Post_meancurv._.11',
#  'lh_G_cingul.Post.dorsal_meancurv._.11',
#  'lh_G_cingul.Post.ventral_meancurv._.11',
#  'lh_G_cuneus_meancurv._.11',
#  'lh_G_front_inf.Opercular_meancurv._.11',
#  'lh_G_front_inf.Orbital_meancurv._.11',
#  'lh_G_front_inf.Triangul_meancurv._.11',
#  'lh_G_front_middle_meancurv._.11',
#  'lh_G_front_sup_meancurv._.11',
#  'lh_G_Ins_lg.S_cent_ins_meancurv._.11',
#  'lh_G_insular_short_meancurv._.11',
#  'lh_G_occipital_middle_meancurv._.11',
#  'lh_G_occipital_sup_meancurv._.11',
#  'lh_G_oc.temp_lat.fusifor_meancurv._.11',
#  'lh_G_oc.temp_med.Lingual_meancurv._.11',
#  'lh_G_oc.temp_med.Parahip_meancurv._.11',
#  'lh_G_orbital_meancurv._.11',
#  'lh_G_pariet_inf.Angular_meancurv._.11',
#  'lh_G_pariet_inf.Supramar_meancurv._.11',
#  'lh_G_parietal_sup_meancurv._.11',
#  'lh_G_postcentral_meancurv._.11',
#  'lh_G_precentral_meancurv._.11',
#  'lh_G_precuneus_meancurv._.11',
#  'lh_G_rectus_meancurv._.11',
#  'lh_G_subcallosal_meancurv._.11',
#  'lh_G_temp_sup.G_T_transv_meancurv._.11',
#  'lh_G_temp_sup.Lateral_meancurv._.11',
#  'lh_G_temp_sup.Plan_polar_meancurv._.11',
#  'lh_G_temp_sup.Plan_tempo_meancurv._.11',
#  'lh_G_temporal_inf_meancurv._.11',
#  'lh_G_temporal_middle_meancurv._.11',
#  'lh_Lat_Fis.ant.Horizont_meancurv._.11',
#  'lh_Lat_Fis.ant.Vertical_meancurv._.11',
#  'lh_Lat_Fis.post_meancurv._.11',
#  'lh_Pole_occipital_meancurv._.11',
#  'lh_Pole_temporal_meancurv._.11',
#  'lh_S_calcarine_meancurv._.11',
#  'lh_S_central_meancurv._.11',
#  'lh_S_cingul.Marginalis_meancurv._.11',
#  'lh_S_circular_insula_ant_meancurv._.11',
#  'lh_S_circular_insula_inf_meancurv._.11',
#  'lh_S_circular_insula_sup_meancurv._.11',
#  'lh_S_collat_transv_ant_meancurv._.11',
#  'lh_S_collat_transv_post_meancurv._.11',
#  'lh_S_front_inf_meancurv._.11',
#  'lh_S_front_middle_meancurv._.11',
#  'lh_S_front_sup_meancurv._.11',
#  'lh_S_interm_prim.Jensen_meancurv._.11',
#  'lh_S_intrapariet.P_trans_meancurv._.11',
#  'lh_S_oc_middle.Lunatus_meancurv._.11',
#  'lh_S_oc_sup.transversal_meancurv._.11',
#  'lh_S_occipital_ant_meancurv._.11',
#  'lh_S_oc.temp_lat_meancurv._.11',
#  'lh_S_oc.temp_med.Lingual_meancurv._.11',
#  'lh_S_orbital_lateral_meancurv._.11',
#  'lh_S_orbital_med.olfact_meancurv._.11',
#  'lh_S_orbital.H_Shaped_meancurv._.11',
#  'lh_S_parieto_occipital_meancurv._.11',
#  'lh_S_pericallosal_meancurv._.11',
#  'lh_S_postcentral_meancurv._.11',
#  'lh_S_precentral.inf.part_meancurv._.11',
#  'lh_S_precentral.sup.part_meancurv._.11',
#  'lh_S_suborbital_meancurv._.11',
#  'lh_S_subparietal_meancurv._.11',
#  'lh_S_temporal_inf_meancurv._.11',
#  'lh_S_temporal_sup_meancurv._.11',
#  'lh_S_temporal_transverse_meancurv._.11',
#  'lh_G.S_frontomargin_thickness._.12',
#  'lh_G.S_occipital_inf_thickness._.12',
#  'lh_G.S_paracentral_thickness._.12',
#  'lh_G.S_subcentral_thickness._.12',
#  'lh_G.S_transv_frontopol_thickness._.12',
#  'lh_G.S_cingul.Ant_thickness._.12',
#  'lh_G.S_cingul.Mid.Ant_thickness._.12',
#  'lh_G.S_cingul.Mid.Post_thickness._.12',
#  'lh_G_cingul.Post.dorsal_thickness._.12',
#  'lh_G_cingul.Post.ventral_thickness._.12',
#  'lh_G_cuneus_thickness._.12',
#  'lh_G_front_inf.Opercular_thickness._.12',
#  'lh_G_front_inf.Orbital_thickness._.12',
#  'lh_G_front_inf.Triangul_thickness._.12',
#  'lh_G_front_middle_thickness._.12',
#  'lh_G_front_sup_thickness._.12',
#  'lh_G_Ins_lg.S_cent_ins_thickness._.12',
#  'lh_G_insular_short_thickness._.12',
#  'lh_G_occipital_middle_thickness._.12',
#  'lh_G_occipital_sup_thickness._.12',
#  'lh_G_oc.temp_lat.fusifor_thickness._.12',
#  'lh_G_oc.temp_med.Lingual_thickness._.12',
#  'lh_G_oc.temp_med.Parahip_thickness._.12',
#  'lh_G_orbital_thickness._.12',
#  'lh_G_pariet_inf.Angular_thickness._.12',
#  'lh_G_pariet_inf.Supramar_thickness._.12',
#  'lh_G_parietal_sup_thickness._.12',
#  'lh_G_postcentral_thickness._.12',
#  'lh_G_precentral_thickness._.12',
#  'lh_G_precuneus_thickness._.12',
#  'lh_G_rectus_thickness._.12',
#  'lh_G_subcallosal_thickness._.12',
#  'lh_G_temp_sup.G_T_transv_thickness._.12',
#  'lh_G_temp_sup.Lateral_thickness._.12',
#  'lh_G_temp_sup.Plan_polar_thickness._.12',
#  'lh_G_temp_sup.Plan_tempo_thickness._.12',
#  'lh_G_temporal_inf_thickness._.12',
#  'lh_G_temporal_middle_thickness._.12',
#  'lh_Lat_Fis.ant.Horizont_thickness._.12',
#  'lh_Lat_Fis.ant.Vertical_thickness._.12',
#  'lh_Lat_Fis.post_thickness._.12',
#  'lh_Pole_occipital_thickness._.12',
#  'lh_Pole_temporal_thickness._.12',
#  'lh_S_calcarine_thickness._.12',
#  'lh_S_central_thickness._.12',
#  'lh_S_cingul.Marginalis_thickness._.12',
#  'lh_S_circular_insula_ant_thickness._.12',
#  'lh_S_circular_insula_inf_thickness._.12',
#  'lh_S_circular_insula_sup_thickness._.12',
#  'lh_S_collat_transv_ant_thickness._.12',
#  'lh_S_collat_transv_post_thickness._.12',
#  'lh_S_front_inf_thickness._.12',
#  'lh_S_front_middle_thickness._.12',
#  'lh_S_front_sup_thickness._.12',
#  'lh_S_interm_prim.Jensen_thickness._.12',
#  'lh_S_intrapariet.P_trans_thickness._.12',
#  'lh_S_oc_middle.Lunatus_thickness._.12',
#  'lh_S_oc_sup.transversal_thickness._.12',
#  'lh_S_occipital_ant_thickness._.12',
#  'lh_S_oc.temp_lat_thickness._.12',
#  'lh_S_oc.temp_med.Lingual_thickness._.12',
#  'lh_S_orbital_lateral_thickness._.12',
#  'lh_S_orbital_med.olfact_thickness._.12',
#  'lh_S_orbital.H_Shaped_thickness._.12',
#  'lh_S_parieto_occipital_thickness._.12',
#  'lh_S_pericallosal_thickness._.12',
#  'lh_S_postcentral_thickness._.12',
#  'lh_S_precentral.inf.part_thickness._.12',
#  'lh_S_precentral.sup.part_thickness._.12',
#  'lh_S_suborbital_thickness._.12',
#  'lh_S_subparietal_thickness._.12',
#  'lh_S_temporal_inf_thickness._.12',
#  'lh_S_temporal_sup_thickness._.12',
#  'lh_S_temporal_transverse_thickness._.12',
#  'lh_MeanThickness_thickness._.12',
#  'lh_G.S_frontomargin_volume._.13',
#  'lh_G.S_occipital_inf_volume._.13',
#  'lh_G.S_paracentral_volume._.13',
#  'lh_G.S_subcentral_volume._.13',
#  'lh_G.S_transv_frontopol_volume._.13',
#  'lh_G.S_cingul.Ant_volume._.13',
#  'lh_G.S_cingul.Mid.Ant_volume._.13',
#  'lh_G.S_cingul.Mid.Post_volume._.13',
#  'lh_G_cingul.Post.dorsal_volume._.13',
#  'lh_G_cingul.Post.ventral_volume._.13',
#  'lh_G_cuneus_volume._.13',
#  'lh_G_front_inf.Opercular_volume._.13',
#  'lh_G_front_inf.Orbital_volume._.13',
#  'lh_G_front_inf.Triangul_volume._.13',
#  'lh_G_front_middle_volume._.13',
#  'lh_G_front_sup_volume._.13',
#  'lh_G_Ins_lg.S_cent_ins_volume._.13',
#  'lh_G_insular_short_volume._.13',
#  'lh_G_occipital_middle_volume._.13',
#  'lh_G_occipital_sup_volume._.13',
#  'lh_G_oc.temp_lat.fusifor_volume._.13',
#  'lh_G_oc.temp_med.Lingual_volume._.13',
#  'lh_G_oc.temp_med.Parahip_volume._.13',
#  'lh_G_orbital_volume._.13',
#  'lh_G_pariet_inf.Angular_volume._.13',
#  'lh_G_pariet_inf.Supramar_volume._.13',
#  'lh_G_parietal_sup_volume._.13',
#  'lh_G_postcentral_volume._.13',
#  'lh_G_precentral_volume._.13',
#  'lh_G_precuneus_volume._.13',
#  'lh_G_rectus_volume._.13',
#  'lh_G_subcallosal_volume._.13',
#  'lh_G_temp_sup.G_T_transv_volume._.13',
#  'lh_G_temp_sup.Lateral_volume._.13',
#  'lh_G_temp_sup.Plan_polar_volume._.13',
#  'lh_G_temp_sup.Plan_tempo_volume._.13',
#  'lh_G_temporal_inf_volume._.13',
#  'lh_G_temporal_middle_volume._.13',
#  'lh_Lat_Fis.ant.Horizont_volume._.13',
#  'lh_Lat_Fis.ant.Vertical_volume._.13',
#  'lh_Lat_Fis.post_volume._.13',
#  'lh_Pole_occipital_volume._.13',
#  'lh_Pole_temporal_volume._.13',
#  'lh_S_calcarine_volume._.13',
#  'lh_S_central_volume._.13',
#  'lh_S_cingul.Marginalis_volume._.13',
#  'lh_S_circular_insula_ant_volume._.13',
#  'lh_S_circular_insula_inf_volume._.13',
#  'lh_S_circular_insula_sup_volume._.13',
#  'lh_S_collat_transv_ant_volume._.13',
#  'lh_S_collat_transv_post_volume._.13',
#  'lh_S_front_inf_volume._.13',
#  'lh_S_front_middle_volume._.13',
#  'lh_S_front_sup_volume._.13',
#  'lh_S_interm_prim.Jensen_volume._.13',
#  'lh_S_intrapariet.P_trans_volume._.13',
#  'lh_S_oc_middle.Lunatus_volume._.13',
#  'lh_S_oc_sup.transversal_volume._.13',
#  'lh_S_occipital_ant_volume._.13',
#  'lh_S_oc.temp_lat_volume._.13',
#  'lh_S_oc.temp_med.Lingual_volume._.13',
#  'lh_S_orbital_lateral_volume._.13',
#  'lh_S_orbital_med.olfact_volume._.13',
#  'lh_S_orbital.H_Shaped_volume._.13',
#  'lh_S_parieto_occipital_volume._.13',
#  'lh_S_pericallosal_volume._.13',
#  'lh_S_postcentral_volume._.13',
#  'lh_S_precentral.inf.part_volume._.13',
#  'lh_S_precentral.sup.part_volume._.13',
#  'lh_S_suborbital_volume._.13',
#  'lh_S_subparietal_volume._.13',
#  'lh_S_temporal_inf_volume._.13',
#  'lh_S_temporal_sup_volume._.13',
#  'lh_S_temporal_transverse_volume._.13',
#  'rh_G.S_frontomargin_area._.14',
#  'rh_G.S_occipital_inf_area._.14',
#  'rh_G.S_paracentral_area._.14',
#  'rh_G.S_subcentral_area._.14',
#  'rh_G.S_transv_frontopol_area._.14',
#  'rh_G.S_cingul.Ant_area._.14',
#  'rh_G.S_cingul.Mid.Ant_area._.14',
#  'rh_G.S_cingul.Mid.Post_area._.14',
#  'rh_G_cingul.Post.dorsal_area._.14',
#  'rh_G_cingul.Post.ventral_area._.14',
#  'rh_G_cuneus_area._.14',
#  'rh_G_front_inf.Opercular_area._.14',
#  'rh_G_front_inf.Orbital_area._.14',
#  'rh_G_front_inf.Triangul_area._.14',
#  'rh_G_front_middle_area._.14',
#  'rh_G_front_sup_area._.14',
#  'rh_G_Ins_lg.S_cent_ins_area._.14',
#  'rh_G_insular_short_area._.14',
#  'rh_G_occipital_middle_area._.14',
#  'rh_G_occipital_sup_area._.14',
#  'rh_G_oc.temp_lat.fusifor_area._.14',
#  'rh_G_oc.temp_med.Lingual_area._.14',
#  'rh_G_oc.temp_med.Parahip_area._.14',
#  'rh_G_orbital_area._.14',
#  'rh_G_pariet_inf.Angular_area._.14',
#  'rh_G_pariet_inf.Supramar_area._.14',
#  'rh_G_parietal_sup_area._.14',
#  'rh_G_postcentral_area._.14',
#  'rh_G_precentral_area._.14',
#  'rh_G_precuneus_area._.14',
#  'rh_G_rectus_area._.14',
#  'rh_G_subcallosal_area._.14',
#  'rh_G_temp_sup.G_T_transv_area._.14',
#  'rh_G_temp_sup.Lateral_area._.14',
#  'rh_G_temp_sup.Plan_polar_area._.14',
#  'rh_G_temp_sup.Plan_tempo_area._.14',
#  'rh_G_temporal_inf_area._.14',
#  'rh_G_temporal_middle_area._.14',
#  'rh_Lat_Fis.ant.Horizont_area._.14',
#  'rh_Lat_Fis.ant.Vertical_area._.14',
#  'rh_Lat_Fis.post_area._.14',
#  'rh_Pole_occipital_area._.14',
#  'rh_Pole_temporal_area._.14',
#  'rh_S_calcarine_area._.14',
#  'rh_S_central_area._.14',
#  'rh_S_cingul.Marginalis_area._.14',
#  'rh_S_circular_insula_ant_area._.14',
#  'rh_S_circular_insula_inf_area._.14',
#  'rh_S_circular_insula_sup_area._.14',
#  'rh_S_collat_transv_ant_area._.14',
#  'rh_S_collat_transv_post_area._.14',
#  'rh_S_front_inf_area._.14',
#  'rh_S_front_middle_area._.14',
#  'rh_S_front_sup_area._.14',
#  'rh_S_interm_prim.Jensen_area._.14',
#  'rh_S_intrapariet.P_trans_area._.14',
#  'rh_S_oc_middle.Lunatus_area._.14',
#  'rh_S_oc_sup.transversal_area._.14',
#  'rh_S_occipital_ant_area._.14',
#  'rh_S_oc.temp_lat_area._.14',
#  'rh_S_oc.temp_med.Lingual_area._.14',
#  'rh_S_orbital_lateral_area._.14',
#  'rh_S_orbital_med.olfact_area._.14',
#  'rh_S_orbital.H_Shaped_area._.14',
#  'rh_S_parieto_occipital_area._.14',
#  'rh_S_pericallosal_area._.14',
#  'rh_S_postcentral_area._.14',
#  'rh_S_precentral.inf.part_area._.14',
#  'rh_S_precentral.sup.part_area._.14',
#  'rh_S_suborbital_area._.14',
#  'rh_S_subparietal_area._.14',
#  'rh_S_temporal_inf_area._.14',
#  'rh_S_temporal_sup_area._.14',
#  'rh_S_temporal_transverse_area._.14',
#  'rh_WhiteSurfArea_area._.14',
#  'rh_G.S_frontomargin_meancurv._.15',
#  'rh_G.S_occipital_inf_meancurv._.15',
#  'rh_G.S_paracentral_meancurv._.15',
#  'rh_G.S_subcentral_meancurv._.15',
#  'rh_G.S_transv_frontopol_meancurv._.15',
#  'rh_G.S_cingul.Ant_meancurv._.15',
#  'rh_G.S_cingul.Mid.Ant_meancurv._.15',
#  'rh_G.S_cingul.Mid.Post_meancurv._.15',
#  'rh_G_cingul.Post.dorsal_meancurv._.15',
#  'rh_G_cingul.Post.ventral_meancurv._.15',
#  'rh_G_cuneus_meancurv._.15',
#  'rh_G_front_inf.Opercular_meancurv._.15',
#  'rh_G_front_inf.Orbital_meancurv._.15',
#  'rh_G_front_inf.Triangul_meancurv._.15',
#  'rh_G_front_middle_meancurv._.15',
#  'rh_G_front_sup_meancurv._.15',
#  'rh_G_Ins_lg.S_cent_ins_meancurv._.15',
#  'rh_G_insular_short_meancurv._.15',
#  'rh_G_occipital_middle_meancurv._.15',
#  'rh_G_occipital_sup_meancurv._.15',
#  'rh_G_oc.temp_lat.fusifor_meancurv._.15',
#  'rh_G_oc.temp_med.Lingual_meancurv._.15',
#  'rh_G_oc.temp_med.Parahip_meancurv._.15',
#  'rh_G_orbital_meancurv._.15',
#  'rh_G_pariet_inf.Angular_meancurv._.15',
#  'rh_G_pariet_inf.Supramar_meancurv._.15',
#  'rh_G_parietal_sup_meancurv._.15',
#  'rh_G_postcentral_meancurv._.15',
#  'rh_G_precentral_meancurv._.15',
#  'rh_G_precuneus_meancurv._.15',
#  'rh_G_rectus_meancurv._.15',
#  'rh_G_subcallosal_meancurv._.15',
#  'rh_G_temp_sup.G_T_transv_meancurv._.15',
#  'rh_G_temp_sup.Lateral_meancurv._.15',
#  'rh_G_temp_sup.Plan_polar_meancurv._.15',
#  'rh_G_temp_sup.Plan_tempo_meancurv._.15',
#  'rh_G_temporal_inf_meancurv._.15',
#  'rh_G_temporal_middle_meancurv._.15',
#  'rh_Lat_Fis.ant.Horizont_meancurv._.15',
#  'rh_Lat_Fis.ant.Vertical_meancurv._.15',
#  'rh_Lat_Fis.post_meancurv._.15',
#  'rh_Pole_occipital_meancurv._.15',
#  'rh_Pole_temporal_meancurv._.15',
#  'rh_S_calcarine_meancurv._.15',
#  'rh_S_central_meancurv._.15',
#  'rh_S_cingul.Marginalis_meancurv._.15',
#  'rh_S_circular_insula_ant_meancurv._.15',
#  'rh_S_circular_insula_inf_meancurv._.15',
#  'rh_S_circular_insula_sup_meancurv._.15',
#  'rh_S_collat_transv_ant_meancurv._.15',
#  'rh_S_collat_transv_post_meancurv._.15',
#  'rh_S_front_inf_meancurv._.15',
#  'rh_S_front_middle_meancurv._.15',
#  'rh_S_front_sup_meancurv._.15',
#  'rh_S_interm_prim.Jensen_meancurv._.15',
#  'rh_S_intrapariet.P_trans_meancurv._.15',
#  'rh_S_oc_middle.Lunatus_meancurv._.15',
#  'rh_S_oc_sup.transversal_meancurv._.15',
#  'rh_S_occipital_ant_meancurv._.15',
#  'rh_S_oc.temp_lat_meancurv._.15',
#  'rh_S_oc.temp_med.Lingual_meancurv._.15',
#  'rh_S_orbital_lateral_meancurv._.15',
#  'rh_S_orbital_med.olfact_meancurv._.15',
#  'rh_S_orbital.H_Shaped_meancurv._.15',
#  'rh_S_parieto_occipital_meancurv._.15',
#  'rh_S_pericallosal_meancurv._.15',
#  'rh_S_postcentral_meancurv._.15',
#  'rh_S_precentral.inf.part_meancurv._.15',
#  'rh_S_precentral.sup.part_meancurv._.15',
#  'rh_S_suborbital_meancurv._.15',
#  'rh_S_subparietal_meancurv._.15',
#  'rh_S_temporal_inf_meancurv._.15',
#  'rh_S_temporal_sup_meancurv._.15',
#  'rh_S_temporal_transverse_meancurv._.15',
#  'rh_G.S_frontomargin_thickness._.16',
#  'rh_G.S_occipital_inf_thickness._.16',
#  'rh_G.S_paracentral_thickness._.16',
#  'rh_G.S_subcentral_thickness._.16',
#  'rh_G.S_transv_frontopol_thickness._.16',
#  'rh_G.S_cingul.Ant_thickness._.16',
#  'rh_G.S_cingul.Mid.Ant_thickness._.16',
#  'rh_G.S_cingul.Mid.Post_thickness._.16',
#  'rh_G_cingul.Post.dorsal_thickness._.16',
#  'rh_G_cingul.Post.ventral_thickness._.16',
#  'rh_G_cuneus_thickness._.16',
#  'rh_G_front_inf.Opercular_thickness._.16',
#  'rh_G_front_inf.Orbital_thickness._.16',
#  'rh_G_front_inf.Triangul_thickness._.16',
#  'rh_G_front_middle_thickness._.16',
#  'rh_G_front_sup_thickness._.16',
#  'rh_G_Ins_lg.S_cent_ins_thickness._.16',
#  'rh_G_insular_short_thickness._.16',
#  'rh_G_occipital_middle_thickness._.16',
#  'rh_G_occipital_sup_thickness._.16',
#  'rh_G_oc.temp_lat.fusifor_thickness._.16',
#  'rh_G_oc.temp_med.Lingual_thickness._.16',
#  'rh_G_oc.temp_med.Parahip_thickness._.16',
#  'rh_G_orbital_thickness._.16',
#  'rh_G_pariet_inf.Angular_thickness._.16',
#  'rh_G_pariet_inf.Supramar_thickness._.16',
#  'rh_G_parietal_sup_thickness._.16',
#  'rh_G_postcentral_thickness._.16',
#  'rh_G_precentral_thickness._.16',
#  'rh_G_precuneus_thickness._.16',
#  'rh_G_rectus_thickness._.16',
#  'rh_G_subcallosal_thickness._.16',
#  'rh_G_temp_sup.G_T_transv_thickness._.16',
#  'rh_G_temp_sup.Lateral_thickness._.16',
#  'rh_G_temp_sup.Plan_polar_thickness._.16',
#  'rh_G_temp_sup.Plan_tempo_thickness._.16',
#  'rh_G_temporal_inf_thickness._.16',
#  'rh_G_temporal_middle_thickness._.16',
#  'rh_Lat_Fis.ant.Horizont_thickness._.16',
#  'rh_Lat_Fis.ant.Vertical_thickness._.16',
#  'rh_Lat_Fis.post_thickness._.16',
#  'rh_Pole_occipital_thickness._.16',
#  'rh_Pole_temporal_thickness._.16',
#  'rh_S_calcarine_thickness._.16',
#  'rh_S_central_thickness._.16',
#  'rh_S_cingul.Marginalis_thickness._.16',
#  'rh_S_circular_insula_ant_thickness._.16',
#  'rh_S_circular_insula_inf_thickness._.16',
#  'rh_S_circular_insula_sup_thickness._.16',
#  'rh_S_collat_transv_ant_thickness._.16',
#  'rh_S_collat_transv_post_thickness._.16',
#  'rh_S_front_inf_thickness._.16',
#  'rh_S_front_middle_thickness._.16',
#  'rh_S_front_sup_thickness._.16',
#  'rh_S_interm_prim.Jensen_thickness._.16',
#  'rh_S_intrapariet.P_trans_thickness._.16',
#  'rh_S_oc_middle.Lunatus_thickness._.16',
#  'rh_S_oc_sup.transversal_thickness._.16',
#  'rh_S_occipital_ant_thickness._.16',
#  'rh_S_oc.temp_lat_thickness._.16',
#  'rh_S_oc.temp_med.Lingual_thickness._.16',
#  'rh_S_orbital_lateral_thickness._.16',
#  'rh_S_orbital_med.olfact_thickness._.16',
#  'rh_S_orbital.H_Shaped_thickness._.16',
#  'rh_S_parieto_occipital_thickness._.16',
#  'rh_S_pericallosal_thickness._.16',
#  'rh_S_postcentral_thickness._.16',
#  'rh_S_precentral.inf.part_thickness._.16',
#  'rh_S_precentral.sup.part_thickness._.16',
#  'rh_S_suborbital_thickness._.16',
#  'rh_S_subparietal_thickness._.16',
#  'rh_S_temporal_inf_thickness._.16',
#  'rh_S_temporal_sup_thickness._.16',
#  'rh_S_temporal_transverse_thickness._.16',
#  'rh_MeanThickness_thickness._.16',
#  'rh_G.S_frontomargin_volume._.17',
#  'rh_G.S_occipital_inf_volume._.17',
#  'rh_G.S_paracentral_volume._.17',
#  'rh_G.S_subcentral_volume._.17',
#  'rh_G.S_transv_frontopol_volume._.17',
#  'rh_G.S_cingul.Ant_volume._.17',
#  'rh_G.S_cingul.Mid.Ant_volume._.17',
#  'rh_G.S_cingul.Mid.Post_volume._.17',
#  'rh_G_cingul.Post.dorsal_volume._.17',
#  'rh_G_cingul.Post.ventral_volume._.17',
#  'rh_G_cuneus_volume._.17',
#  'rh_G_front_inf.Opercular_volume._.17',
#  'rh_G_front_inf.Orbital_volume._.17',
#  'rh_G_front_inf.Triangul_volume._.17',
#  'rh_G_front_middle_volume._.17',
#  'rh_G_front_sup_volume._.17',
#  'rh_G_Ins_lg.S_cent_ins_volume._.17',
#  'rh_G_insular_short_volume._.17',
#  'rh_G_occipital_middle_volume._.17',
#  'rh_G_occipital_sup_volume._.17',
#  'rh_G_oc.temp_lat.fusifor_volume._.17',
#  'rh_G_oc.temp_med.Lingual_volume._.17',
#  'rh_G_oc.temp_med.Parahip_volume._.17',
#  'rh_G_orbital_volume._.17',
#  'rh_G_pariet_inf.Angular_volume._.17',
#  'rh_G_pariet_inf.Supramar_volume._.17',
#  'rh_G_parietal_sup_volume._.17',
#  'rh_G_postcentral_volume._.17',
#  'rh_G_precentral_volume._.17',
#  'rh_G_precuneus_volume._.17',
#  'rh_G_rectus_volume._.17',
#  'rh_G_subcallosal_volume._.17',
#  'rh_G_temp_sup.G_T_transv_volume._.17',
#  'rh_G_temp_sup.Lateral_volume._.17',
#  'rh_G_temp_sup.Plan_polar_volume._.17',
#  'rh_G_temp_sup.Plan_tempo_volume._.17',
#  'rh_G_temporal_inf_volume._.17',
#  'rh_G_temporal_middle_volume._.17',
#  'rh_Lat_Fis.ant.Horizont_volume._.17',
#  'rh_Lat_Fis.ant.Vertical_volume._.17',
#  'rh_Lat_Fis.post_volume._.17',
#  'rh_Pole_occipital_volume._.17',
#  'rh_Pole_temporal_volume._.17',
#  'rh_S_calcarine_volume._.17',
#  'rh_S_central_volume._.17',
#  'rh_S_cingul.Marginalis_volume._.17',
#  'rh_S_circular_insula_ant_volume._.17',
#  'rh_S_circular_insula_inf_volume._.17',
#  'rh_S_circular_insula_sup_volume._.17',
#  'rh_S_collat_transv_ant_volume._.17',
#  'rh_S_collat_transv_post_volume._.17',
#  'rh_S_front_inf_volume._.17',
#  'rh_S_front_middle_volume._.17',
#  'rh_S_front_sup_volume._.17',
#  'rh_S_interm_prim.Jensen_volume._.17',
#  'rh_S_intrapariet.P_trans_volume._.17',
#  'rh_S_oc_middle.Lunatus_volume._.17',
#  'rh_S_oc_sup.transversal_volume._.17',
#  'rh_S_occipital_ant_volume._.17',
#  'rh_S_oc.temp_lat_volume._.17',
#  'rh_S_oc.temp_med.Lingual_volume._.17',
#  'rh_S_orbital_lateral_volume._.17',
#  'rh_S_orbital_med.olfact_volume._.17',
#  'rh_S_orbital.H_Shaped_volume._.17',
#  'rh_S_parieto_occipital_volume._.17',
#  'rh_S_pericallosal_volume._.17',
#  'rh_S_postcentral_volume._.17',
#  'rh_S_precentral.inf.part_volume._.17',
#  'rh_S_precentral.sup.part_volume._.17',
#  'rh_S_suborbital_volume._.17',
#  'rh_S_subparietal_volume._.17',
#  'rh_S_temporal_inf_volume._.17',
#  'rh_S_temporal_sup_volume._.17',
#  'rh_S_temporal_transverse_volume._.17',
#  'wm.lh.bankssts._.18',
#  'wm.lh.caudalanteriorcingulate._.18',
#  'wm.lh.caudalmiddlefrontal._.18',
#  'wm.lh.cuneus._.18',
#  'wm.lh.entorhinal._.18',
#  'wm.lh.fusiform._.18',
#  'wm.lh.inferiorparietal._.18',
#  'wm.lh.inferiortemporal._.18',
#  'wm.lh.isthmuscingulate._.18',
#  'wm.lh.lateraloccipital._.18',
#  'wm.lh.lateralorbitofrontal._.18',
#  'wm.lh.lingual._.18',
#  'wm.lh.medialorbitofrontal._.18',
#  'wm.lh.middletemporal._.18',
#  'wm.lh.parahippocampal._.18',
#  'wm.lh.paracentral._.18',
#  'wm.lh.parsopercularis._.18',
#  'wm.lh.parsorbitalis._.18',
#  'wm.lh.parstriangularis._.18',
#  'wm.lh.pericalcarine._.18',
#  'wm.lh.postcentral._.18',
#  'wm.lh.posteriorcingulate._.18',
#  'wm.lh.precentral._.18',
#  'wm.lh.precuneus._.18',
#  'wm.lh.rostralanteriorcingulate._.18',
#  'wm.lh.rostralmiddlefrontal._.18',
#  'wm.lh.superiorfrontal._.18',
#  'wm.lh.superiorparietal._.18',
#  'wm.lh.superiortemporal._.18',
#  'wm.lh.supramarginal._.18',
#  'wm.lh.frontalpole._.18',
#  'wm.lh.temporalpole._.18',
#  'wm.lh.transversetemporal._.18',
#  'wm.lh.insula._.18',
#  'wm.rh.bankssts._.18',
#  'wm.rh.caudalanteriorcingulate._.18',
#  'wm.rh.caudalmiddlefrontal._.18',
#  'wm.rh.cuneus._.18',
#  'wm.rh.entorhinal._.18',
#  'wm.rh.fusiform._.18',
#  'wm.rh.inferiorparietal._.18',
#  'wm.rh.inferiortemporal._.18',
#  'wm.rh.isthmuscingulate._.18',
#  'wm.rh.lateraloccipital._.18',
#  'wm.rh.lateralorbitofrontal._.18',
#  'wm.rh.lingual._.18',
#  'wm.rh.medialorbitofrontal._.18',
#  'wm.rh.middletemporal._.18',
#  'wm.rh.parahippocampal._.18',
#  'wm.rh.paracentral._.18',
#  'wm.rh.parsopercularis._.18',
#  'wm.rh.parsorbitalis._.18',
#  'wm.rh.parstriangularis._.18',
#  'wm.rh.pericalcarine._.18',
#  'wm.rh.postcentral._.18',
#  'wm.rh.posteriorcingulate._.18',
#  'wm.rh.precentral._.18',
#  'wm.rh.precuneus._.18',
#  'wm.rh.rostralanteriorcingulate._.18',
#  'wm.rh.rostralmiddlefrontal._.18',
#  'wm.rh.superiorfrontal._.18',
#  'wm.rh.superiorparietal._.18',
#  'wm.rh.superiortemporal._.18',
#  'wm.rh.supramarginal._.18',
#  'wm.rh.frontalpole._.18',
#  'wm.rh.temporalpole._.18',
#  'wm.rh.transversetemporal._.18',
#  'wm.rh.insula._.18',
#  'Left.UnsegmentedWhiteMatter._.18',
#  'Right.UnsegmentedWhiteMatter._.18',
#  'con_L.BSTS_L.CACG_count',
#  'con_L.BSTS_L.CMFG_count',
#  'con_L.BSTS_L.CU_count',
#  'con_L.BSTS_L.EC_count',
#  'con_L.BSTS_L.FG_count',
#  'con_L.BSTS_L.IPG_count',
#  'con_L.BSTS_L.ITG_count',
#  'con_L.BSTS_L.ICG_count',
#  'con_L.BSTS_L.LOG_count',
#  'con_L.BSTS_L.LOFG_count',
#  'con_L.BSTS_L.LG_count',
#  'con_L.BSTS_L.MOFG_count',
#  ...]

# %%
train_data_processed = train_data.fillna(0).reset_index(drop=True)
features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] + mri] 

object_feat =[]

j=0
for i in test_data[features].dtypes:
    #print(j)
    if i == 'object':
        print(test_data[features].columns[j])
        object_feat.append(test_data[features].columns[j])
    j+=1
    
print(object_feat)

features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] +mri +object_feat]
# Out:
# []

# %%
def preproecessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    test_data_processed["kfold"] = -1

    train_data_processed["kfold"] = -1

    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)

    kf = KFold(n_splits=NUM_FOLDS)

    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed)):
        train_data_processed.loc[val_, 'kfold'] = fold
    print("done preprocessing")
    return train_data_processed, test_data_processed

def rocvis(true , prob , label ) :
    from sklearn.metrics import roc_curve
    if type(true[0]) == str :
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        true = le.fit_transform(true)
    else :
        pass
    fpr, tpr, thresholds = roc_curve(true, prob)
    plt.plot(fpr, tpr, marker='.', label = label  )
    
# Augmented
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm

def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 


    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

def find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test):
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    # define hyperparameter space
    """
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,8]
    lr_ = [2e-2,1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99]
    ss_ = [10, 20]
  
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        clf = TabNetClassifier(n_a = hy[0],
                               n_d = hy[0],
                               optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                               scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                               scheduler_fn=torch.optim.lr_scheduler.StepLR,
                               verbose=0
                               )
        clf.fit(X_train, Y_train, X_valid, Y_valid, patience=10, batch_size=256, max_epochs=200)
        #clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200) (Recommended)
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
        print("--------Valid score: {} --------------------".format(-clf.best_cost))
        print("--------Test auc: {} Test acc:{}-------------".format(test_auc, test_acc) )
        if test_auc>max_auc:
            max_hy = hy
            max_auc = test_auc
    return max_hy
    
def bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test, max_hy, features):
 
    hy = max_hy
    clf = TabNetClassifier(n_a = hy[0],
                           n_d = hy[0],
                           optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                           scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                           scheduler_fn=torch.optim.lr_scheduler.StepLR,
                           verbose=0
                               )
    clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200)
    preds_acc = clf.predict(X_test)
    preds_prob = clf.predict_proba(X_test)
    test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
    test_acc = accuracy_score(preds_acc, Y_test)
    
    
    
    print("Max hy:" ,hy)
    print("--------Valid score: {} --------------------".format(-clf.best_cost))
    print("FINAL TEST SCORE(max) test auc: {} test acc: {}".format(test_auc, test_acc))
    return test_auc, clf, preds_prob
    
    
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values

    df_train = train_data_processed[train_data_processed.kfold != fold]
    df_valid = train_data_processed[train_data_processed.kfold == fold]
    
    X_train = df_train[features].values
    Y_train = df_train[target].values
    
    X_valid = df_valid[features].values
    Y_valid = df_valid[target].values
    
    y_oof = np.zeros((df_valid.shape[0],len(target)))   # Out of folds validation
    
    print("---------------------------------------Training Begining for fold {}-------------------------------".format(fold+1))
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    # Start training
    max_hy = find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test)
    
    print("Found maximum hyperparmeter, now work with that")
    
    test_auc, clf, preds_prob = bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test
                                               , max_hy, features)
    
    import_feat=feature(Num_feat, clf, test_data_processed, features)
    preds_val_prob = clf.predict_proba(X_valid)

    return test_auc, Y_test, clf, preds_prob, import_feat, Y_valid, preds_val_prob



    
def hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat):
    CV_auc_all = []
    train_data_processed, test_data_processed = preproecessing (train_data, test_data, Num_FOLDS)
    import_feat_every = pd.DataFrame()
    features_all = [ col for col in train_data_processed.columns if col not in unused_feat + [target]] 
    features_mri = [ col for col in mri if col not in 'rsfmri_cor_network.gordon_subcort.aseg_visitid']  
    features_pheno = [ col for col in train_data_processed.columns if col not in unused_feat + [target] 
                +mri] 
    print("all")
    test_auc_all, Y_test_all, clf, preds_prob_all, import_feat_all, Y_valid_all, preds_val_prob_all = run(train_data_processed,
                                                                         test_data_processed,
                                                                         0, 
                                                                         Num_feat, 
                                                                         features_all
                                             )
    print("pheno")
    test_auc_pheno, Y_test_pheno, clf, preds_prob_pheno, import_feat_pheno, Y_valid_pheno, preds_val_prob_pheno = run(train_data_processed, test_data_processed, 
                                            0, Num_feat, features_pheno)
  
    print("mri")
    test_auc_mri, Y_test_mri, clf, preds_prob_mri, import_feat_mri, Y_valid_mri, preds_val_prob_mri = run(train_data_processed, test_data_processed,
                                            0, Num_feat, features_mri)
  
    
    fig , ax = plt.subplots(figsize= (20,10))
    plt.plot([0, 1], [0, 1], linestyle='--')
    rocvis(Y_test_all , preds_prob_all[:,1] , "MRI+Pheno")
    rocvis(Y_test_pheno , preds_prob_pheno[:,1] , "Pheno")
    rocvis(Y_test_mri , preds_prob_mri[:,1] , "MRI")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
    plt.legend(fontsize = 20)
    plt.title(dataset_name, fontsize= 25)
    plt.tight_layout()
    plt.savefig(f'{dataset_name}_ROC.png')

    
    plt.show()
    return test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri

# %%
test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri= hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
# Out:
# done preprocessing
# all
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.7173339784686102 --------------------
# --------Test auc: 0.7197205392718737 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7191000362888593 --------------------
# --------Test auc: 0.7008351072539709 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7347949679448409 --------------------
# --------Test auc: 0.7086403580590579 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7191000362888593 --------------------
# --------Test auc: 0.7008351072539709 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6985605419136327 --------------------
# --------Test auc: 0.6699688881611265 Test acc:0.5613577023498695-------------
# Device used : cuda
# --------Valid score: 0.6873956695294544 --------------------
# --------Test auc: 0.6715244801047977 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.695590903592597 --------------------
# --------Test auc: 0.6606353364990994 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.6873956695294544 --------------------
# --------Test auc: 0.6715244801047977 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.6773799443570824 --------------------
# --------Test auc: 0.6640467223404836 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.6960838272650295 --------------------
# --------Test auc: 0.6383521641831778 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.705189306882787 --------------------
# --------Test auc: 0.6723295671633644 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6960838272650295 --------------------
# --------Test auc: 0.6383521641831778 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7245736059029878 --------------------
# --------Test auc: 0.6896457616942306 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.7290129430264908 --------------------
# --------Test auc: 0.7082309917580918 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7282145881214467 --------------------
# --------Test auc: 0.7011080181212817 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7290129430264908 --------------------
# --------Test auc: 0.7082309917580918 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6875892101124955 --------------------
# --------Test auc: 0.6185251896730527 Test acc:0.5535248041775457-------------
# Device used : cuda
# --------Valid score: 0.6533264787710173 --------------------
# --------Test auc: 0.6990066044429889 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7026127978710537 --------------------
# --------Test auc: 0.6633644451722067 Test acc:0.587467362924282-------------
# Device used : cuda
# --------Valid score: 0.6674126043304707 --------------------
# --------Test auc: 0.6921565416734894 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.6741320914479255 --------------------
# --------Test auc: 0.6188253916270947 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6779605661062054 --------------------
# --------Test auc: 0.6032421811036515 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7114914721180597 --------------------
# --------Test auc: 0.6599530593308226 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6779605661062054 --------------------
# --------Test auc: 0.6032421811036515 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7276460626587637 --------------------
# --------Test auc: 0.679766388297582 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7296540462078142 --------------------
# --------Test auc: 0.6802030456852791 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7150598766178784 --------------------
# --------Test auc: 0.6701872168549752 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7285351397121084 --------------------
# --------Test auc: 0.7084766115386715 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.677694447804524 --------------------
# --------Test auc: 0.6579608099994542 Test acc:0.5378590078328982-------------
# Device used : cuda
# --------Valid score: 0.6709810088302891 --------------------
# --------Test auc: 0.6347088041045794 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.6686282811176969 --------------------
# --------Test auc: 0.6510288739697615 Test acc:0.5404699738903395-------------
# Device used : cuda
# --------Valid score: 0.6709810088302891 --------------------
# --------Test auc: 0.6347088041045794 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.6687310995524374 --------------------
# --------Test auc: 0.623110092243873 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.6995524374017176 --------------------
# --------Test auc: 0.6328530102068664 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.6884843353090601 --------------------
# --------Test auc: 0.6496370285464768 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.6843715979194387 --------------------
# --------Test auc: 0.6238469515856121 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.552897060602395 --------------------
# --------Test auc: 0.46948856503465974 Test acc:0.48825065274151436-------------
# Device used : cuda
# --------Valid score: 0.552897060602395 --------------------
# --------Test auc: 0.46948856503465974 Test acc:0.48825065274151436-------------
# Device used : cuda
# --------Valid score: 0.552897060602395 --------------------
# --------Test auc: 0.46948856503465974 Test acc:0.48825065274151436-------------
# Device used : cuda
# --------Valid score: 0.552897060602395 --------------------
# --------Test auc: 0.46948856503465974 Test acc:0.48825065274151436-------------
# Device used : cuda

# %%
valid_auc_all = roc_auc_score (Y_valid_all, preds_val_prob_all[:,1])
valid_auc_pheno = roc_auc_score (Y_valid_pheno, preds_val_prob_pheno[:,1])
valid_auc_mri = roc_auc_score (Y_valid_mri, preds_val_prob_mri[:,1])

# %%
print(dataset_name)
print("")
print("Test AUC")
print(f"Pheno+MRI:{round((test_auc_all)*100,2)}%")
print( f"Pheno:{round((test_auc_pheno),4)*100}%")
print(f"MRI:{round((test_auc_mri)*100,2)}%")
print("")
    
print("Valid AUC")

print( f"Pheno+MRI:{round(valid_auc_all,4)*100}%")
print( f"Pheno:{round(valid_auc_pheno*100,2)}%")
print( f"MRI:{round(valid_auc_mri,4)*100}%")
# Out:
# morphology and connectome
#
# Test AUC
# Pheno+MRI:73.18%
# Pheno:75.24%
# MRI:50.26%
#
# Valid AUC
# Pheno+MRI:75.38%
# Pheno:77.18%
# MRI:55.42%

# %%
import_feat_every=pd.concat([import_feat_all,import_feat_pheno, import_feat_mri])

import_feat_every.to_csv(f"{dataset_name}_features.csv")

import_feat_every
# Out:
#                               feature name     ratio
# 0                  lh_G_cuneus_volume._.13  0.123277
# 1                           PPSP_frequency  0.096198
# 2                             Depress.CBCL  0.075396
# 3                              AnxDep.CBCL  0.072404
# 4                            close_friends  0.051439
# 5                             Conduct.CBCL  0.043184
# 6       rh_S_precentral.sup.part_area._.14  0.038830
# 7                     con_L.POR_L.PU_count  0.038757
# 8                      con_L.PU_R.TH_count  0.036084
# 9                      con_L.AM_R.AM_count  0.029887
# 10           wm.lh.transversetemporal._.18  0.022767
# 11              poa_total_6month_follow_up  0.022135
# 12                    con_L.FG_L.SFG_count  0.019779
# 13                  con_L.CACG_L.POR_count  0.016205
# 14                    con_R.PCG_R.FP_count  0.015749
# 15                   con_R.HI_R.LOFG_count  0.014970
# 16                  con_R.RACG_R.CER_count  0.014433
# 17                   con_L.LOFG_L.FP_count  0.012720
# 18                  con_L.RACG_R.MTG_count  0.012605
# 19                   con_L.RACG_R.PA_count  0.012468
# 0                              AnxDep.CBCL  0.176570
# 1                             Depress.CBCL  0.153900
# 2                             Conduct.CBCL  0.097614
# 3                           PPSP_frequency  0.095276
# 4                  nihtbx_list_uncorrected  0.076738
# 5                              DA_baseline  0.071334
# 6         Internal.and.External.Comobidity  0.061869
# 7                            PPSP_distress  0.058614
# 8                                 totalBAS  0.035934
# 9                                    Ne_PN  0.028098
# 10               upps_lack_of_perseverance  0.022163
# 11            nihtbx_totalcomp_uncorrected  0.022110
# 12           mania_binary_1_year_follow_up  0.020295
# 13                             abcd_site.y  0.016367
# 14                            Thought.CBCL  0.008514
# 15                   upps_negative_urgency  0.007377
# 16                              upps_total  0.006817
# 17                                  height  0.006786
# 18                                 fes_3_p  0.005725
# 19                           SWTD_baseline  0.003533
# 0                    con_L.MOFG_L.HI_count  0.059191
# 1                   con_L.PCAL_L.TTG_count  0.044154
# 2                    con_L.EC_L.PHIG_count  0.037496
# 3   rh_S_circular_insula_ant_meancurv._.15  0.031729
# 4                     con_L.ITG_R.PU_count  0.028415
# 5                   con_L.SFG_R.CMFG_count  0.027320
# 6                      con_L.CU_L.PU_count  0.025808
# 7        lh_S_collat_transv_post_area._.10  0.025806
# 8                     con_L.PCU_L.HI_count  0.025219
# 9         lh_superiorfrontal_thickness._.5  0.024464
# 10        lh_parstriangularis_meancurv._.3  0.024444
# 11                   con_L.TH_R.BSTS_count  0.024157
# 12                  con_L.PHIG_R.PTR_count  0.023537
# 13                     con_L.TH_R.PA_count  0.022783
# 14                   con_L.LOFG_R.PU_count  0.022449
# 15         lh_parsopercularis_meancurv._.3  0.022382
# 16                    con_L.CU_R.SFG_count  0.021913
# 17                   con_L.SFG_R.ITG_count  0.021404
# 18                  con_L.ITG_R.CMFG_count  0.019137
# 19                 con_R.PHIG_R.PrCG_count  0.018917
