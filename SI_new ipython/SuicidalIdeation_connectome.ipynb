# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

dataset_name = 'connectome'
train_out = Path(os.getcwd()+'/data1/SuicidalIdeation_'+dataset_name+'_train.csv')
test_out =Path(os.getcwd()+'/data1/SuicidalIdeation_'+dataset_name+'_test.csv')


train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)
target ='Suicidalideation.x'
unused_feat = ['Set', 'subjectkey', 'abcd_site.x', 'Unnamed: 0', 'kflod',
               'src_subject_id','interview_date','gender','eventname']
n=0
start_mri = 0;
for i in test_data.columns:
    #print(i)
    if i =='con_L.BSTS_L.CACG_count':
        start_mri =n
    n +=1

    
mri = list(test_data.columns[start_mri:])
print(mri)
Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20
# Out:
# ['con_L.BSTS_L.CACG_count', 'con_L.BSTS_L.CMFG_count', 'con_L.BSTS_L.CU_count', 'con_L.BSTS_L.EC_count', 'con_L.BSTS_L.FG_count', 'con_L.BSTS_L.IPG_count', 'con_L.BSTS_L.ITG_count', 'con_L.BSTS_L.ICG_count', 'con_L.BSTS_L.LOG_count', 'con_L.BSTS_L.LOFG_count', 'con_L.BSTS_L.LG_count', 'con_L.BSTS_L.MOFG_count', 'con_L.BSTS_L.MTG_count', 'con_L.BSTS_L.PHIG_count', 'con_L.BSTS_L.PaCG_count', 'con_L.BSTS_L.POP_count', 'con_L.BSTS_L.POR_count', 'con_L.BSTS_L.PTR_count', 'con_L.BSTS_L.PCAL_count', 'con_L.BSTS_L.PoCG_count', 'con_L.BSTS_L.PCG_count', 'con_L.BSTS_L.PrCG_count', 'con_L.BSTS_L.PCU_count', 'con_L.BSTS_L.RACG_count', 'con_L.BSTS_L.RMFG_count', 'con_L.BSTS_L.SFG_count', 'con_L.BSTS_L.SPG_count', 'con_L.BSTS_L.STG_count', 'con_L.BSTS_L.SMG_count', 'con_L.BSTS_L.FP_count', 'con_L.BSTS_L.TP_count', 'con_L.BSTS_L.TTG_count', 'con_L.BSTS_L.IN_count', 'con_L.BSTS_L.CER_count', 'con_L.BSTS_L.TH_count', 'con_L.BSTS_L.CA_count', 'con_L.BSTS_L.PU_count', 'con_L.BSTS_L.PA_count', 'con_L.BSTS_L.HI_count', 'con_L.BSTS_L.AM_count', 'con_L.BSTS_L.AC_count', 'con_L.BSTS_R.TH_count', 'con_L.BSTS_R.CA_count', 'con_L.BSTS_R.PU_count', 'con_L.BSTS_R.PA_count', 'con_L.BSTS_R.HI_count', 'con_L.BSTS_R.AM_count', 'con_L.BSTS_R.AC_count', 'con_L.BSTS_R.BSTS_count', 'con_L.BSTS_R.CACG_count', 'con_L.BSTS_R.CMFG_count', 'con_L.BSTS_R.CU_count', 'con_L.BSTS_R.EC_count', 'con_L.BSTS_R.FG_count', 'con_L.BSTS_R.IPG_count', 'con_L.BSTS_R.ITG_count', 'con_L.BSTS_R.ICG_count', 'con_L.BSTS_R.LOG_count', 'con_L.BSTS_R.LOFG_count', 'con_L.BSTS_R.LG_count', 'con_L.BSTS_R.MOFG_count', 'con_L.BSTS_R.MTG_count', 'con_L.BSTS_R.PHIG_count', 'con_L.BSTS_R.PaCG_count', 'con_L.BSTS_R.POP_count', 'con_L.BSTS_R.POR_count', 'con_L.BSTS_R.PTR_count', 'con_L.BSTS_R.PCAL_count', 'con_L.BSTS_R.PoCG_count', 'con_L.BSTS_R.PCG_count', 'con_L.BSTS_R.PrCG_count', 'con_L.BSTS_R.PCU_count', 'con_L.BSTS_R.RACG_count', 'con_L.BSTS_R.RMFG_count', 'con_L.BSTS_R.SFG_count', 'con_L.BSTS_R.SPG_count', 'con_L.BSTS_R.STG_count', 'con_L.BSTS_R.SMG_count', 'con_L.BSTS_R.FP_count', 'con_L.BSTS_R.TP_count', 'con_L.BSTS_R.TTG_count', 'con_L.BSTS_R.IN_count', 'con_L.BSTS_R.CER_count', 'con_L.CACG_L.CMFG_count', 'con_L.CACG_L.CU_count', 'con_L.CACG_L.EC_count', 'con_L.CACG_L.FG_count', 'con_L.CACG_L.IPG_count', 'con_L.CACG_L.ITG_count', 'con_L.CACG_L.ICG_count', 'con_L.CACG_L.LOG_count', 'con_L.CACG_L.LOFG_count', 'con_L.CACG_L.LG_count', 'con_L.CACG_L.MOFG_count', 'con_L.CACG_L.MTG_count', 'con_L.CACG_L.PHIG_count', 'con_L.CACG_L.PaCG_count', 'con_L.CACG_L.POP_count', 'con_L.CACG_L.POR_count', 'con_L.CACG_L.PTR_count', 'con_L.CACG_L.PCAL_count', 'con_L.CACG_L.PoCG_count', 'con_L.CACG_L.PCG_count', 'con_L.CACG_L.PrCG_count', 'con_L.CACG_L.PCU_count', 'con_L.CACG_L.RACG_count', 'con_L.CACG_L.RMFG_count', 'con_L.CACG_L.SFG_count', 'con_L.CACG_L.SPG_count', 'con_L.CACG_L.STG_count', 'con_L.CACG_L.SMG_count', 'con_L.CACG_L.FP_count', 'con_L.CACG_L.TP_count', 'con_L.CACG_L.TTG_count', 'con_L.CACG_L.IN_count', 'con_L.CACG_L.CER_count', 'con_L.CACG_L.TH_count', 'con_L.CACG_L.CA_count', 'con_L.CACG_L.PU_count', 'con_L.CACG_L.PA_count', 'con_L.CACG_L.HI_count', 'con_L.CACG_L.AM_count', 'con_L.CACG_L.AC_count', 'con_L.CACG_R.TH_count', 'con_L.CACG_R.CA_count', 'con_L.CACG_R.PU_count', 'con_L.CACG_R.PA_count', 'con_L.CACG_R.HI_count', 'con_L.CACG_R.AM_count', 'con_L.CACG_R.AC_count', 'con_L.CACG_R.BSTS_count', 'con_L.CACG_R.CACG_count', 'con_L.CACG_R.CMFG_count', 'con_L.CACG_R.CU_count', 'con_L.CACG_R.EC_count', 'con_L.CACG_R.FG_count', 'con_L.CACG_R.IPG_count', 'con_L.CACG_R.ITG_count', 'con_L.CACG_R.ICG_count', 'con_L.CACG_R.LOG_count', 'con_L.CACG_R.LOFG_count', 'con_L.CACG_R.LG_count', 'con_L.CACG_R.MOFG_count', 'con_L.CACG_R.MTG_count', 'con_L.CACG_R.PHIG_count', 'con_L.CACG_R.PaCG_count', 'con_L.CACG_R.POP_count', 'con_L.CACG_R.POR_count', 'con_L.CACG_R.PTR_count', 'con_L.CACG_R.PCAL_count', 'con_L.CACG_R.PoCG_count', 'con_L.CACG_R.PCG_count', 'con_L.CACG_R.PrCG_count', 'con_L.CACG_R.PCU_count', 'con_ ...

# %%
mri
# Out:
# ['con_L.BSTS_L.CACG_count',
#  'con_L.BSTS_L.CMFG_count',
#  'con_L.BSTS_L.CU_count',
#  'con_L.BSTS_L.EC_count',
#  'con_L.BSTS_L.FG_count',
#  'con_L.BSTS_L.IPG_count',
#  'con_L.BSTS_L.ITG_count',
#  'con_L.BSTS_L.ICG_count',
#  'con_L.BSTS_L.LOG_count',
#  'con_L.BSTS_L.LOFG_count',
#  'con_L.BSTS_L.LG_count',
#  'con_L.BSTS_L.MOFG_count',
#  'con_L.BSTS_L.MTG_count',
#  'con_L.BSTS_L.PHIG_count',
#  'con_L.BSTS_L.PaCG_count',
#  'con_L.BSTS_L.POP_count',
#  'con_L.BSTS_L.POR_count',
#  'con_L.BSTS_L.PTR_count',
#  'con_L.BSTS_L.PCAL_count',
#  'con_L.BSTS_L.PoCG_count',
#  'con_L.BSTS_L.PCG_count',
#  'con_L.BSTS_L.PrCG_count',
#  'con_L.BSTS_L.PCU_count',
#  'con_L.BSTS_L.RACG_count',
#  'con_L.BSTS_L.RMFG_count',
#  'con_L.BSTS_L.SFG_count',
#  'con_L.BSTS_L.SPG_count',
#  'con_L.BSTS_L.STG_count',
#  'con_L.BSTS_L.SMG_count',
#  'con_L.BSTS_L.FP_count',
#  'con_L.BSTS_L.TP_count',
#  'con_L.BSTS_L.TTG_count',
#  'con_L.BSTS_L.IN_count',
#  'con_L.BSTS_L.CER_count',
#  'con_L.BSTS_L.TH_count',
#  'con_L.BSTS_L.CA_count',
#  'con_L.BSTS_L.PU_count',
#  'con_L.BSTS_L.PA_count',
#  'con_L.BSTS_L.HI_count',
#  'con_L.BSTS_L.AM_count',
#  'con_L.BSTS_L.AC_count',
#  'con_L.BSTS_R.TH_count',
#  'con_L.BSTS_R.CA_count',
#  'con_L.BSTS_R.PU_count',
#  'con_L.BSTS_R.PA_count',
#  'con_L.BSTS_R.HI_count',
#  'con_L.BSTS_R.AM_count',
#  'con_L.BSTS_R.AC_count',
#  'con_L.BSTS_R.BSTS_count',
#  'con_L.BSTS_R.CACG_count',
#  'con_L.BSTS_R.CMFG_count',
#  'con_L.BSTS_R.CU_count',
#  'con_L.BSTS_R.EC_count',
#  'con_L.BSTS_R.FG_count',
#  'con_L.BSTS_R.IPG_count',
#  'con_L.BSTS_R.ITG_count',
#  'con_L.BSTS_R.ICG_count',
#  'con_L.BSTS_R.LOG_count',
#  'con_L.BSTS_R.LOFG_count',
#  'con_L.BSTS_R.LG_count',
#  'con_L.BSTS_R.MOFG_count',
#  'con_L.BSTS_R.MTG_count',
#  'con_L.BSTS_R.PHIG_count',
#  'con_L.BSTS_R.PaCG_count',
#  'con_L.BSTS_R.POP_count',
#  'con_L.BSTS_R.POR_count',
#  'con_L.BSTS_R.PTR_count',
#  'con_L.BSTS_R.PCAL_count',
#  'con_L.BSTS_R.PoCG_count',
#  'con_L.BSTS_R.PCG_count',
#  'con_L.BSTS_R.PrCG_count',
#  'con_L.BSTS_R.PCU_count',
#  'con_L.BSTS_R.RACG_count',
#  'con_L.BSTS_R.RMFG_count',
#  'con_L.BSTS_R.SFG_count',
#  'con_L.BSTS_R.SPG_count',
#  'con_L.BSTS_R.STG_count',
#  'con_L.BSTS_R.SMG_count',
#  'con_L.BSTS_R.FP_count',
#  'con_L.BSTS_R.TP_count',
#  'con_L.BSTS_R.TTG_count',
#  'con_L.BSTS_R.IN_count',
#  'con_L.BSTS_R.CER_count',
#  'con_L.CACG_L.CMFG_count',
#  'con_L.CACG_L.CU_count',
#  'con_L.CACG_L.EC_count',
#  'con_L.CACG_L.FG_count',
#  'con_L.CACG_L.IPG_count',
#  'con_L.CACG_L.ITG_count',
#  'con_L.CACG_L.ICG_count',
#  'con_L.CACG_L.LOG_count',
#  'con_L.CACG_L.LOFG_count',
#  'con_L.CACG_L.LG_count',
#  'con_L.CACG_L.MOFG_count',
#  'con_L.CACG_L.MTG_count',
#  'con_L.CACG_L.PHIG_count',
#  'con_L.CACG_L.PaCG_count',
#  'con_L.CACG_L.POP_count',
#  'con_L.CACG_L.POR_count',
#  'con_L.CACG_L.PTR_count',
#  'con_L.CACG_L.PCAL_count',
#  'con_L.CACG_L.PoCG_count',
#  'con_L.CACG_L.PCG_count',
#  'con_L.CACG_L.PrCG_count',
#  'con_L.CACG_L.PCU_count',
#  'con_L.CACG_L.RACG_count',
#  'con_L.CACG_L.RMFG_count',
#  'con_L.CACG_L.SFG_count',
#  'con_L.CACG_L.SPG_count',
#  'con_L.CACG_L.STG_count',
#  'con_L.CACG_L.SMG_count',
#  'con_L.CACG_L.FP_count',
#  'con_L.CACG_L.TP_count',
#  'con_L.CACG_L.TTG_count',
#  'con_L.CACG_L.IN_count',
#  'con_L.CACG_L.CER_count',
#  'con_L.CACG_L.TH_count',
#  'con_L.CACG_L.CA_count',
#  'con_L.CACG_L.PU_count',
#  'con_L.CACG_L.PA_count',
#  'con_L.CACG_L.HI_count',
#  'con_L.CACG_L.AM_count',
#  'con_L.CACG_L.AC_count',
#  'con_L.CACG_R.TH_count',
#  'con_L.CACG_R.CA_count',
#  'con_L.CACG_R.PU_count',
#  'con_L.CACG_R.PA_count',
#  'con_L.CACG_R.HI_count',
#  'con_L.CACG_R.AM_count',
#  'con_L.CACG_R.AC_count',
#  'con_L.CACG_R.BSTS_count',
#  'con_L.CACG_R.CACG_count',
#  'con_L.CACG_R.CMFG_count',
#  'con_L.CACG_R.CU_count',
#  'con_L.CACG_R.EC_count',
#  'con_L.CACG_R.FG_count',
#  'con_L.CACG_R.IPG_count',
#  'con_L.CACG_R.ITG_count',
#  'con_L.CACG_R.ICG_count',
#  'con_L.CACG_R.LOG_count',
#  'con_L.CACG_R.LOFG_count',
#  'con_L.CACG_R.LG_count',
#  'con_L.CACG_R.MOFG_count',
#  'con_L.CACG_R.MTG_count',
#  'con_L.CACG_R.PHIG_count',
#  'con_L.CACG_R.PaCG_count',
#  'con_L.CACG_R.POP_count',
#  'con_L.CACG_R.POR_count',
#  'con_L.CACG_R.PTR_count',
#  'con_L.CACG_R.PCAL_count',
#  'con_L.CACG_R.PoCG_count',
#  'con_L.CACG_R.PCG_count',
#  'con_L.CACG_R.PrCG_count',
#  'con_L.CACG_R.PCU_count',
#  'con_L.CACG_R.RACG_count',
#  'con_L.CACG_R.RMFG_count',
#  'con_L.CACG_R.SFG_count',
#  'con_L.CACG_R.SPG_count',
#  'con_L.CACG_R.STG_count',
#  'con_L.CACG_R.SMG_count',
#  'con_L.CACG_R.FP_count',
#  'con_L.CACG_R.TP_count',
#  'con_L.CACG_R.TTG_count',
#  'con_L.CACG_R.IN_count',
#  'con_L.CACG_R.CER_count',
#  'con_L.CMFG_L.CU_count',
#  'con_L.CMFG_L.EC_count',
#  'con_L.CMFG_L.FG_count',
#  'con_L.CMFG_L.IPG_count',
#  'con_L.CMFG_L.ITG_count',
#  'con_L.CMFG_L.ICG_count',
#  'con_L.CMFG_L.LOG_count',
#  'con_L.CMFG_L.LOFG_count',
#  'con_L.CMFG_L.LG_count',
#  'con_L.CMFG_L.MOFG_count',
#  'con_L.CMFG_L.MTG_count',
#  'con_L.CMFG_L.PHIG_count',
#  'con_L.CMFG_L.PaCG_count',
#  'con_L.CMFG_L.POP_count',
#  'con_L.CMFG_L.POR_count',
#  'con_L.CMFG_L.PTR_count',
#  'con_L.CMFG_L.PCAL_count',
#  'con_L.CMFG_L.PoCG_count',
#  'con_L.CMFG_L.PCG_count',
#  'con_L.CMFG_L.PrCG_count',
#  'con_L.CMFG_L.PCU_count',
#  'con_L.CMFG_L.RACG_count',
#  'con_L.CMFG_L.RMFG_count',
#  'con_L.CMFG_L.SFG_count',
#  'con_L.CMFG_L.SPG_count',
#  'con_L.CMFG_L.STG_count',
#  'con_L.CMFG_L.SMG_count',
#  'con_L.CMFG_L.FP_count',
#  'con_L.CMFG_L.TP_count',
#  'con_L.CMFG_L.TTG_count',
#  'con_L.CMFG_L.IN_count',
#  'con_L.CMFG_L.CER_count',
#  'con_L.CMFG_L.TH_count',
#  'con_L.CMFG_L.CA_count',
#  'con_L.CMFG_L.PU_count',
#  'con_L.CMFG_L.PA_count',
#  'con_L.CMFG_L.HI_count',
#  'con_L.CMFG_L.AM_count',
#  'con_L.CMFG_L.AC_count',
#  'con_L.CMFG_R.TH_count',
#  'con_L.CMFG_R.CA_count',
#  'con_L.CMFG_R.PU_count',
#  'con_L.CMFG_R.PA_count',
#  'con_L.CMFG_R.HI_count',
#  'con_L.CMFG_R.AM_count',
#  'con_L.CMFG_R.AC_count',
#  'con_L.CMFG_R.BSTS_count',
#  'con_L.CMFG_R.CACG_count',
#  'con_L.CMFG_R.CMFG_count',
#  'con_L.CMFG_R.CU_count',
#  'con_L.CMFG_R.EC_count',
#  'con_L.CMFG_R.FG_count',
#  'con_L.CMFG_R.IPG_count',
#  'con_L.CMFG_R.ITG_count',
#  'con_L.CMFG_R.ICG_count',
#  'con_L.CMFG_R.LOG_count',
#  'con_L.CMFG_R.LOFG_count',
#  'con_L.CMFG_R.LG_count',
#  'con_L.CMFG_R.MOFG_count',
#  'con_L.CMFG_R.MTG_count',
#  'con_L.CMFG_R.PHIG_count',
#  'con_L.CMFG_R.PaCG_count',
#  'con_L.CMFG_R.POP_count',
#  'con_L.CMFG_R.POR_count',
#  'con_L.CMFG_R.PTR_count',
#  'con_L.CMFG_R.PCAL_count',
#  'con_L.CMFG_R.PoCG_count',
#  'con_L.CMFG_R.PCG_count',
#  'con_L.CMFG_R.PrCG_count',
#  'con_L.CMFG_R.PCU_count',
#  'con_L.CMFG_R.RACG_count',
#  'con_L.CMFG_R.RMFG_count',
#  'con_L.CMFG_R.SFG_count',
#  'con_L.CMFG_R.SPG_count',
#  'con_L.CMFG_R.STG_count',
#  'con_L.CMFG_R.SMG_count',
#  'con_L.CMFG_R.FP_count',
#  'con_L.CMFG_R.TP_count',
#  'con_L.CMFG_R.TTG_count',
#  'con_L.CMFG_R.IN_count',
#  'con_L.CMFG_R.CER_count',
#  'con_L.CU_L.EC_count',
#  'con_L.CU_L.FG_count',
#  'con_L.CU_L.IPG_count',
#  'con_L.CU_L.ITG_count',
#  'con_L.CU_L.ICG_count',
#  'con_L.CU_L.LOG_count',
#  'con_L.CU_L.LOFG_count',
#  'con_L.CU_L.LG_count',
#  'con_L.CU_L.MOFG_count',
#  'con_L.CU_L.MTG_count',
#  'con_L.CU_L.PHIG_count',
#  'con_L.CU_L.PaCG_count',
#  'con_L.CU_L.POP_count',
#  'con_L.CU_L.POR_count',
#  'con_L.CU_L.PTR_count',
#  'con_L.CU_L.PCAL_count',
#  'con_L.CU_L.PoCG_count',
#  'con_L.CU_L.PCG_count',
#  'con_L.CU_L.PrCG_count',
#  'con_L.CU_L.PCU_count',
#  'con_L.CU_L.RACG_count',
#  'con_L.CU_L.RMFG_count',
#  'con_L.CU_L.SFG_count',
#  'con_L.CU_L.SPG_count',
#  'con_L.CU_L.STG_count',
#  'con_L.CU_L.SMG_count',
#  'con_L.CU_L.FP_count',
#  'con_L.CU_L.TP_count',
#  'con_L.CU_L.TTG_count',
#  'con_L.CU_L.IN_count',
#  'con_L.CU_L.CER_count',
#  'con_L.CU_L.TH_count',
#  'con_L.CU_L.CA_count',
#  'con_L.CU_L.PU_count',
#  'con_L.CU_L.PA_count',
#  'con_L.CU_L.HI_count',
#  'con_L.CU_L.AM_count',
#  'con_L.CU_L.AC_count',
#  'con_L.CU_R.TH_count',
#  'con_L.CU_R.CA_count',
#  'con_L.CU_R.PU_count',
#  'con_L.CU_R.PA_count',
#  'con_L.CU_R.HI_count',
#  'con_L.CU_R.AM_count',
#  'con_L.CU_R.AC_count',
#  'con_L.CU_R.BSTS_count',
#  'con_L.CU_R.CACG_count',
#  'con_L.CU_R.CMFG_count',
#  'con_L.CU_R.CU_count',
#  'con_L.CU_R.EC_count',
#  'con_L.CU_R.FG_count',
#  'con_L.CU_R.IPG_count',
#  'con_L.CU_R.ITG_count',
#  'con_L.CU_R.ICG_count',
#  'con_L.CU_R.LOG_count',
#  'con_L.CU_R.LOFG_count',
#  'con_L.CU_R.LG_count',
#  'con_L.CU_R.MOFG_count',
#  'con_L.CU_R.MTG_count',
#  'con_L.CU_R.PHIG_count',
#  'con_L.CU_R.PaCG_count',
#  'con_L.CU_R.POP_count',
#  'con_L.CU_R.POR_count',
#  'con_L.CU_R.PTR_count',
#  'con_L.CU_R.PCAL_count',
#  'con_L.CU_R.PoCG_count',
#  'con_L.CU_R.PCG_count',
#  'con_L.CU_R.PrCG_count',
#  'con_L.CU_R.PCU_count',
#  'con_L.CU_R.RACG_count',
#  'con_L.CU_R.RMFG_count',
#  'con_L.CU_R.SFG_count',
#  'con_L.CU_R.SPG_count',
#  'con_L.CU_R.STG_count',
#  'con_L.CU_R.SMG_count',
#  'con_L.CU_R.FP_count',
#  'con_L.CU_R.TP_count',
#  'con_L.CU_R.TTG_count',
#  'con_L.CU_R.IN_count',
#  'con_L.CU_R.CER_count',
#  'con_L.EC_L.FG_count',
#  'con_L.EC_L.IPG_count',
#  'con_L.EC_L.ITG_count',
#  'con_L.EC_L.ICG_count',
#  'con_L.EC_L.LOG_count',
#  'con_L.EC_L.LOFG_count',
#  'con_L.EC_L.LG_count',
#  'con_L.EC_L.MOFG_count',
#  'con_L.EC_L.MTG_count',
#  'con_L.EC_L.PHIG_count',
#  'con_L.EC_L.PaCG_count',
#  'con_L.EC_L.POP_count',
#  'con_L.EC_L.POR_count',
#  'con_L.EC_L.PTR_count',
#  'con_L.EC_L.PCAL_count',
#  'con_L.EC_L.PoCG_count',
#  'con_L.EC_L.PCG_count',
#  'con_L.EC_L.PrCG_count',
#  'con_L.EC_L.PCU_count',
#  'con_L.EC_L.RACG_count',
#  'con_L.EC_L.RMFG_count',
#  'con_L.EC_L.SFG_count',
#  'con_L.EC_L.SPG_count',
#  'con_L.EC_L.STG_count',
#  'con_L.EC_L.SMG_count',
#  'con_L.EC_L.FP_count',
#  'con_L.EC_L.TP_count',
#  'con_L.EC_L.TTG_count',
#  'con_L.EC_L.IN_count',
#  'con_L.EC_L.CER_count',
#  'con_L.EC_L.TH_count',
#  'con_L.EC_L.CA_count',
#  'con_L.EC_L.PU_count',
#  'con_L.EC_L.PA_count',
#  'con_L.EC_L.HI_count',
#  'con_L.EC_L.AM_count',
#  'con_L.EC_L.AC_count',
#  'con_L.EC_R.TH_count',
#  'con_L.EC_R.CA_count',
#  'con_L.EC_R.PU_count',
#  'con_L.EC_R.PA_count',
#  'con_L.EC_R.HI_count',
#  'con_L.EC_R.AM_count',
#  'con_L.EC_R.AC_count',
#  'con_L.EC_R.BSTS_count',
#  'con_L.EC_R.CACG_count',
#  'con_L.EC_R.CMFG_count',
#  'con_L.EC_R.CU_count',
#  'con_L.EC_R.EC_count',
#  'con_L.EC_R.FG_count',
#  'con_L.EC_R.IPG_count',
#  'con_L.EC_R.ITG_count',
#  'con_L.EC_R.ICG_count',
#  'con_L.EC_R.LOG_count',
#  'con_L.EC_R.LOFG_count',
#  'con_L.EC_R.LG_count',
#  'con_L.EC_R.MOFG_count',
#  'con_L.EC_R.MTG_count',
#  'con_L.EC_R.PHIG_count',
#  'con_L.EC_R.PaCG_count',
#  'con_L.EC_R.POP_count',
#  'con_L.EC_R.POR_count',
#  'con_L.EC_R.PTR_count',
#  'con_L.EC_R.PCAL_count',
#  'con_L.EC_R.PoCG_count',
#  'con_L.EC_R.PCG_count',
#  'con_L.EC_R.PrCG_count',
#  'con_L.EC_R.PCU_count',
#  'con_L.EC_R.RACG_count',
#  'con_L.EC_R.RMFG_count',
#  'con_L.EC_R.SFG_count',
#  'con_L.EC_R.SPG_count',
#  'con_L.EC_R.STG_count',
#  'con_L.EC_R.SMG_count',
#  'con_L.EC_R.FP_count',
#  'con_L.EC_R.TP_count',
#  'con_L.EC_R.TTG_count',
#  'con_L.EC_R.IN_count',
#  'con_L.EC_R.CER_count',
#  'con_L.FG_L.IPG_count',
#  'con_L.FG_L.ITG_count',
#  'con_L.FG_L.ICG_count',
#  'con_L.FG_L.LOG_count',
#  'con_L.FG_L.LOFG_count',
#  'con_L.FG_L.LG_count',
#  'con_L.FG_L.MOFG_count',
#  'con_L.FG_L.MTG_count',
#  'con_L.FG_L.PHIG_count',
#  'con_L.FG_L.PaCG_count',
#  'con_L.FG_L.POP_count',
#  'con_L.FG_L.POR_count',
#  'con_L.FG_L.PTR_count',
#  'con_L.FG_L.PCAL_count',
#  'con_L.FG_L.PoCG_count',
#  'con_L.FG_L.PCG_count',
#  'con_L.FG_L.PrCG_count',
#  'con_L.FG_L.PCU_count',
#  'con_L.FG_L.RACG_count',
#  'con_L.FG_L.RMFG_count',
#  'con_L.FG_L.SFG_count',
#  'con_L.FG_L.SPG_count',
#  'con_L.FG_L.STG_count',
#  'con_L.FG_L.SMG_count',
#  'con_L.FG_L.FP_count',
#  'con_L.FG_L.TP_count',
#  'con_L.FG_L.TTG_count',
#  'con_L.FG_L.IN_count',
#  'con_L.FG_L.CER_count',
#  'con_L.FG_L.TH_count',
#  'con_L.FG_L.CA_count',
#  'con_L.FG_L.PU_count',
#  'con_L.FG_L.PA_count',
#  'con_L.FG_L.HI_count',
#  'con_L.FG_L.AM_count',
#  'con_L.FG_L.AC_count',
#  'con_L.FG_R.TH_count',
#  'con_L.FG_R.CA_count',
#  'con_L.FG_R.PU_count',
#  'con_L.FG_R.PA_count',
#  'con_L.FG_R.HI_count',
#  'con_L.FG_R.AM_count',
#  'con_L.FG_R.AC_count',
#  'con_L.FG_R.BSTS_count',
#  'con_L.FG_R.CACG_count',
#  'con_L.FG_R.CMFG_count',
#  'con_L.FG_R.CU_count',
#  'con_L.FG_R.EC_count',
#  'con_L.FG_R.FG_count',
#  'con_L.FG_R.IPG_count',
#  'con_L.FG_R.ITG_count',
#  'con_L.FG_R.ICG_count',
#  'con_L.FG_R.LOG_count',
#  'con_L.FG_R.LOFG_count',
#  'con_L.FG_R.LG_count',
#  'con_L.FG_R.MOFG_count',
#  'con_L.FG_R.MTG_count',
#  'con_L.FG_R.PHIG_count',
#  'con_L.FG_R.PaCG_count',
#  'con_L.FG_R.POP_count',
#  'con_L.FG_R.POR_count',
#  'con_L.FG_R.PTR_count',
#  'con_L.FG_R.PCAL_count',
#  'con_L.FG_R.PoCG_count',
#  'con_L.FG_R.PCG_count',
#  'con_L.FG_R.PrCG_count',
#  'con_L.FG_R.PCU_count',
#  'con_L.FG_R.RACG_count',
#  'con_L.FG_R.RMFG_count',
#  'con_L.FG_R.SFG_count',
#  'con_L.FG_R.SPG_count',
#  'con_L.FG_R.STG_count',
#  'con_L.FG_R.SMG_count',
#  'con_L.FG_R.FP_count',
#  'con_L.FG_R.TP_count',
#  'con_L.FG_R.TTG_count',
#  'con_L.FG_R.IN_count',
#  'con_L.FG_R.CER_count',
#  'con_L.IPG_L.ITG_count',
#  'con_L.IPG_L.ICG_count',
#  'con_L.IPG_L.LOG_count',
#  'con_L.IPG_L.LOFG_count',
#  'con_L.IPG_L.LG_count',
#  'con_L.IPG_L.MOFG_count',
#  'con_L.IPG_L.MTG_count',
#  'con_L.IPG_L.PHIG_count',
#  'con_L.IPG_L.PaCG_count',
#  'con_L.IPG_L.POP_count',
#  'con_L.IPG_L.POR_count',
#  'con_L.IPG_L.PTR_count',
#  'con_L.IPG_L.PCAL_count',
#  'con_L.IPG_L.PoCG_count',
#  'con_L.IPG_L.PCG_count',
#  'con_L.IPG_L.PrCG_count',
#  'con_L.IPG_L.PCU_count',
#  'con_L.IPG_L.RACG_count',
#  'con_L.IPG_L.RMFG_count',
#  'con_L.IPG_L.SFG_count',
#  'con_L.IPG_L.SPG_count',
#  'con_L.IPG_L.STG_count',
#  'con_L.IPG_L.SMG_count',
#  'con_L.IPG_L.FP_count',
#  'con_L.IPG_L.TP_count',
#  'con_L.IPG_L.TTG_count',
#  'con_L.IPG_L.IN_count',
#  'con_L.IPG_L.CER_count',
#  'con_L.IPG_L.TH_count',
#  'con_L.IPG_L.CA_count',
#  'con_L.IPG_L.PU_count',
#  'con_L.IPG_L.PA_count',
#  'con_L.IPG_L.HI_count',
#  'con_L.IPG_L.AM_count',
#  'con_L.IPG_L.AC_count',
#  'con_L.IPG_R.TH_count',
#  'con_L.IPG_R.CA_count',
#  'con_L.IPG_R.PU_count',
#  'con_L.IPG_R.PA_count',
#  'con_L.IPG_R.HI_count',
#  'con_L.IPG_R.AM_count',
#  'con_L.IPG_R.AC_count',
#  'con_L.IPG_R.BSTS_count',
#  'con_L.IPG_R.CACG_count',
#  'con_L.IPG_R.CMFG_count',
#  'con_L.IPG_R.CU_count',
#  'con_L.IPG_R.EC_count',
#  'con_L.IPG_R.FG_count',
#  'con_L.IPG_R.IPG_count',
#  'con_L.IPG_R.ITG_count',
#  'con_L.IPG_R.ICG_count',
#  'con_L.IPG_R.LOG_count',
#  'con_L.IPG_R.LOFG_count',
#  'con_L.IPG_R.LG_count',
#  'con_L.IPG_R.MOFG_count',
#  'con_L.IPG_R.MTG_count',
#  'con_L.IPG_R.PHIG_count',
#  'con_L.IPG_R.PaCG_count',
#  'con_L.IPG_R.POP_count',
#  'con_L.IPG_R.POR_count',
#  'con_L.IPG_R.PTR_count',
#  'con_L.IPG_R.PCAL_count',
#  'con_L.IPG_R.PoCG_count',
#  'con_L.IPG_R.PCG_count',
#  'con_L.IPG_R.PrCG_count',
#  'con_L.IPG_R.PCU_count',
#  'con_L.IPG_R.RACG_count',
#  'con_L.IPG_R.RMFG_count',
#  'con_L.IPG_R.SFG_count',
#  'con_L.IPG_R.SPG_count',
#  'con_L.IPG_R.STG_count',
#  'con_L.IPG_R.SMG_count',
#  'con_L.IPG_R.FP_count',
#  'con_L.IPG_R.TP_count',
#  'con_L.IPG_R.TTG_count',
#  'con_L.IPG_R.IN_count',
#  'con_L.IPG_R.CER_count',
#  'con_L.ITG_L.ICG_count',
#  'con_L.ITG_L.LOG_count',
#  'con_L.ITG_L.LOFG_count',
#  'con_L.ITG_L.LG_count',
#  'con_L.ITG_L.MOFG_count',
#  'con_L.ITG_L.MTG_count',
#  'con_L.ITG_L.PHIG_count',
#  'con_L.ITG_L.PaCG_count',
#  'con_L.ITG_L.POP_count',
#  'con_L.ITG_L.POR_count',
#  'con_L.ITG_L.PTR_count',
#  'con_L.ITG_L.PCAL_count',
#  'con_L.ITG_L.PoCG_count',
#  'con_L.ITG_L.PCG_count',
#  'con_L.ITG_L.PrCG_count',
#  'con_L.ITG_L.PCU_count',
#  'con_L.ITG_L.RACG_count',
#  'con_L.ITG_L.RMFG_count',
#  'con_L.ITG_L.SFG_count',
#  'con_L.ITG_L.SPG_count',
#  'con_L.ITG_L.STG_count',
#  'con_L.ITG_L.SMG_count',
#  'con_L.ITG_L.FP_count',
#  'con_L.ITG_L.TP_count',
#  'con_L.ITG_L.TTG_count',
#  'con_L.ITG_L.IN_count',
#  'con_L.ITG_L.CER_count',
#  'con_L.ITG_L.TH_count',
#  'con_L.ITG_L.CA_count',
#  'con_L.ITG_L.PU_count',
#  'con_L.ITG_L.PA_count',
#  'con_L.ITG_L.HI_count',
#  'con_L.ITG_L.AM_count',
#  'con_L.ITG_L.AC_count',
#  'con_L.ITG_R.TH_count',
#  'con_L.ITG_R.CA_count',
#  'con_L.ITG_R.PU_count',
#  'con_L.ITG_R.PA_count',
#  'con_L.ITG_R.HI_count',
#  'con_L.ITG_R.AM_count',
#  'con_L.ITG_R.AC_count',
#  'con_L.ITG_R.BSTS_count',
#  'con_L.ITG_R.CACG_count',
#  'con_L.ITG_R.CMFG_count',
#  'con_L.ITG_R.CU_count',
#  'con_L.ITG_R.EC_count',
#  'con_L.ITG_R.FG_count',
#  'con_L.ITG_R.IPG_count',
#  'con_L.ITG_R.ITG_count',
#  'con_L.ITG_R.ICG_count',
#  'con_L.ITG_R.LOG_count',
#  'con_L.ITG_R.LOFG_count',
#  'con_L.ITG_R.LG_count',
#  'con_L.ITG_R.MOFG_count',
#  'con_L.ITG_R.MTG_count',
#  'con_L.ITG_R.PHIG_count',
#  'con_L.ITG_R.PaCG_count',
#  'con_L.ITG_R.POP_count',
#  'con_L.ITG_R.POR_count',
#  'con_L.ITG_R.PTR_count',
#  'con_L.ITG_R.PCAL_count',
#  'con_L.ITG_R.PoCG_count',
#  'con_L.ITG_R.PCG_count',
#  'con_L.ITG_R.PrCG_count',
#  'con_L.ITG_R.PCU_count',
#  'con_L.ITG_R.RACG_count',
#  'con_L.ITG_R.RMFG_count',
#  'con_L.ITG_R.SFG_count',
#  'con_L.ITG_R.SPG_count',
#  'con_L.ITG_R.STG_count',
#  'con_L.ITG_R.SMG_count',
#  'con_L.ITG_R.FP_count',
#  'con_L.ITG_R.TP_count',
#  'con_L.ITG_R.TTG_count',
#  'con_L.ITG_R.IN_count',
#  'con_L.ITG_R.CER_count',
#  'con_L.ICG_L.LOG_count',
#  'con_L.ICG_L.LOFG_count',
#  'con_L.ICG_L.LG_count',
#  'con_L.ICG_L.MOFG_count',
#  'con_L.ICG_L.MTG_count',
#  'con_L.ICG_L.PHIG_count',
#  'con_L.ICG_L.PaCG_count',
#  'con_L.ICG_L.POP_count',
#  'con_L.ICG_L.POR_count',
#  'con_L.ICG_L.PTR_count',
#  'con_L.ICG_L.PCAL_count',
#  'con_L.ICG_L.PoCG_count',
#  'con_L.ICG_L.PCG_count',
#  'con_L.ICG_L.PrCG_count',
#  'con_L.ICG_L.PCU_count',
#  'con_L.ICG_L.RACG_count',
#  'con_L.ICG_L.RMFG_count',
#  'con_L.ICG_L.SFG_count',
#  'con_L.ICG_L.SPG_count',
#  'con_L.ICG_L.STG_count',
#  'con_L.ICG_L.SMG_count',
#  'con_L.ICG_L.FP_count',
#  'con_L.ICG_L.TP_count',
#  'con_L.ICG_L.TTG_count',
#  'con_L.ICG_L.IN_count',
#  'con_L.ICG_L.CER_count',
#  'con_L.ICG_L.TH_count',
#  'con_L.ICG_L.CA_count',
#  'con_L.ICG_L.PU_count',
#  'con_L.ICG_L.PA_count',
#  'con_L.ICG_L.HI_count',
#  'con_L.ICG_L.AM_count',
#  'con_L.ICG_L.AC_count',
#  'con_L.ICG_R.TH_count',
#  'con_L.ICG_R.CA_count',
#  'con_L.ICG_R.PU_count',
#  'con_L.ICG_R.PA_count',
#  'con_L.ICG_R.HI_count',
#  'con_L.ICG_R.AM_count',
#  'con_L.ICG_R.AC_count',
#  'con_L.ICG_R.BSTS_count',
#  'con_L.ICG_R.CACG_count',
#  'con_L.ICG_R.CMFG_count',
#  'con_L.ICG_R.CU_count',
#  'con_L.ICG_R.EC_count',
#  'con_L.ICG_R.FG_count',
#  'con_L.ICG_R.IPG_count',
#  'con_L.ICG_R.ITG_count',
#  'con_L.ICG_R.ICG_count',
#  'con_L.ICG_R.LOG_count',
#  'con_L.ICG_R.LOFG_count',
#  'con_L.ICG_R.LG_count',
#  'con_L.ICG_R.MOFG_count',
#  'con_L.ICG_R.MTG_count',
#  'con_L.ICG_R.PHIG_count',
#  'con_L.ICG_R.PaCG_count',
#  'con_L.ICG_R.POP_count',
#  'con_L.ICG_R.POR_count',
#  'con_L.ICG_R.PTR_count',
#  'con_L.ICG_R.PCAL_count',
#  'con_L.ICG_R.PoCG_count',
#  'con_L.ICG_R.PCG_count',
#  'con_L.ICG_R.PrCG_count',
#  'con_L.ICG_R.PCU_count',
#  'con_L.ICG_R.RACG_count',
#  'con_L.ICG_R.RMFG_count',
#  'con_L.ICG_R.SFG_count',
#  'con_L.ICG_R.SPG_count',
#  'con_L.ICG_R.STG_count',
#  'con_L.ICG_R.SMG_count',
#  'con_L.ICG_R.FP_count',
#  'con_L.ICG_R.TP_count',
#  'con_L.ICG_R.TTG_count',
#  'con_L.ICG_R.IN_count',
#  'con_L.ICG_R.CER_count',
#  'con_L.LOG_L.LOFG_count',
#  'con_L.LOG_L.LG_count',
#  'con_L.LOG_L.MOFG_count',
#  'con_L.LOG_L.MTG_count',
#  'con_L.LOG_L.PHIG_count',
#  'con_L.LOG_L.PaCG_count',
#  'con_L.LOG_L.POP_count',
#  'con_L.LOG_L.POR_count',
#  'con_L.LOG_L.PTR_count',
#  'con_L.LOG_L.PCAL_count',
#  'con_L.LOG_L.PoCG_count',
#  'con_L.LOG_L.PCG_count',
#  'con_L.LOG_L.PrCG_count',
#  'con_L.LOG_L.PCU_count',
#  'con_L.LOG_L.RACG_count',
#  'con_L.LOG_L.RMFG_count',
#  'con_L.LOG_L.SFG_count',
#  'con_L.LOG_L.SPG_count',
#  'con_L.LOG_L.STG_count',
#  'con_L.LOG_L.SMG_count',
#  'con_L.LOG_L.FP_count',
#  'con_L.LOG_L.TP_count',
#  'con_L.LOG_L.TTG_count',
#  'con_L.LOG_L.IN_count',
#  'con_L.LOG_L.CER_count',
#  'con_L.LOG_L.TH_count',
#  'con_L.LOG_L.CA_count',
#  'con_L.LOG_L.PU_count',
#  'con_L.LOG_L.PA_count',
#  'con_L.LOG_L.HI_count',
#  'con_L.LOG_L.AM_count',
#  'con_L.LOG_L.AC_count',
#  'con_L.LOG_R.TH_count',
#  'con_L.LOG_R.CA_count',
#  'con_L.LOG_R.PU_count',
#  'con_L.LOG_R.PA_count',
#  'con_L.LOG_R.HI_count',
#  'con_L.LOG_R.AM_count',
#  'con_L.LOG_R.AC_count',
#  'con_L.LOG_R.BSTS_count',
#  'con_L.LOG_R.CACG_count',
#  'con_L.LOG_R.CMFG_count',
#  'con_L.LOG_R.CU_count',
#  'con_L.LOG_R.EC_count',
#  'con_L.LOG_R.FG_count',
#  'con_L.LOG_R.IPG_count',
#  'con_L.LOG_R.ITG_count',
#  'con_L.LOG_R.ICG_count',
#  'con_L.LOG_R.LOG_count',
#  'con_L.LOG_R.LOFG_count',
#  'con_L.LOG_R.LG_count',
#  'con_L.LOG_R.MOFG_count',
#  'con_L.LOG_R.MTG_count',
#  'con_L.LOG_R.PHIG_count',
#  'con_L.LOG_R.PaCG_count',
#  'con_L.LOG_R.POP_count',
#  'con_L.LOG_R.POR_count',
#  'con_L.LOG_R.PTR_count',
#  'con_L.LOG_R.PCAL_count',
#  'con_L.LOG_R.PoCG_count',
#  'con_L.LOG_R.PCG_count',
#  'con_L.LOG_R.PrCG_count',
#  'con_L.LOG_R.PCU_count',
#  'con_L.LOG_R.RACG_count',
#  'con_L.LOG_R.RMFG_count',
#  'con_L.LOG_R.SFG_count',
#  'con_L.LOG_R.SPG_count',
#  'con_L.LOG_R.STG_count',
#  'con_L.LOG_R.SMG_count',
#  'con_L.LOG_R.FP_count',
#  'con_L.LOG_R.TP_count',
#  'con_L.LOG_R.TTG_count',
#  'con_L.LOG_R.IN_count',
#  'con_L.LOG_R.CER_count',
#  'con_L.LOFG_L.LG_count',
#  'con_L.LOFG_L.MOFG_count',
#  'con_L.LOFG_L.MTG_count',
#  'con_L.LOFG_L.PHIG_count',
#  'con_L.LOFG_L.PaCG_count',
#  'con_L.LOFG_L.POP_count',
#  'con_L.LOFG_L.POR_count',
#  'con_L.LOFG_L.PTR_count',
#  'con_L.LOFG_L.PCAL_count',
#  'con_L.LOFG_L.PoCG_count',
#  'con_L.LOFG_L.PCG_count',
#  'con_L.LOFG_L.PrCG_count',
#  'con_L.LOFG_L.PCU_count',
#  'con_L.LOFG_L.RACG_count',
#  'con_L.LOFG_L.RMFG_count',
#  'con_L.LOFG_L.SFG_count',
#  'con_L.LOFG_L.SPG_count',
#  'con_L.LOFG_L.STG_count',
#  'con_L.LOFG_L.SMG_count',
#  'con_L.LOFG_L.FP_count',
#  'con_L.LOFG_L.TP_count',
#  'con_L.LOFG_L.TTG_count',
#  'con_L.LOFG_L.IN_count',
#  'con_L.LOFG_L.CER_count',
#  'con_L.LOFG_L.TH_count',
#  'con_L.LOFG_L.CA_count',
#  'con_L.LOFG_L.PU_count',
#  'con_L.LOFG_L.PA_count',
#  'con_L.LOFG_L.HI_count',
#  'con_L.LOFG_L.AM_count',
#  'con_L.LOFG_L.AC_count',
#  'con_L.LOFG_R.TH_count',
#  'con_L.LOFG_R.CA_count',
#  'con_L.LOFG_R.PU_count',
#  'con_L.LOFG_R.PA_count',
#  'con_L.LOFG_R.HI_count',
#  'con_L.LOFG_R.AM_count',
#  'con_L.LOFG_R.AC_count',
#  'con_L.LOFG_R.BSTS_count',
#  'con_L.LOFG_R.CACG_count',
#  'con_L.LOFG_R.CMFG_count',
#  'con_L.LOFG_R.CU_count',
#  'con_L.LOFG_R.EC_count',
#  'con_L.LOFG_R.FG_count',
#  'con_L.LOFG_R.IPG_count',
#  'con_L.LOFG_R.ITG_count',
#  'con_L.LOFG_R.ICG_count',
#  'con_L.LOFG_R.LOG_count',
#  'con_L.LOFG_R.LOFG_count',
#  'con_L.LOFG_R.LG_count',
#  'con_L.LOFG_R.MOFG_count',
#  'con_L.LOFG_R.MTG_count',
#  'con_L.LOFG_R.PHIG_count',
#  'con_L.LOFG_R.PaCG_count',
#  'con_L.LOFG_R.POP_count',
#  'con_L.LOFG_R.POR_count',
#  'con_L.LOFG_R.PTR_count',
#  'con_L.LOFG_R.PCAL_count',
#  'con_L.LOFG_R.PoCG_count',
#  'con_L.LOFG_R.PCG_count',
#  'con_L.LOFG_R.PrCG_count',
#  'con_L.LOFG_R.PCU_count',
#  'con_L.LOFG_R.RACG_count',
#  'con_L.LOFG_R.RMFG_count',
#  'con_L.LOFG_R.SFG_count',
#  'con_L.LOFG_R.SPG_count',
#  'con_L.LOFG_R.STG_count',
#  'con_L.LOFG_R.SMG_count',
#  'con_L.LOFG_R.FP_count',
#  'con_L.LOFG_R.TP_count',
#  'con_L.LOFG_R.TTG_count',
#  'con_L.LOFG_R.IN_count',
#  'con_L.LOFG_R.CER_count',
#  'con_L.LG_L.MOFG_count',
#  'con_L.LG_L.MTG_count',
#  'con_L.LG_L.PHIG_count',
#  'con_L.LG_L.PaCG_count',
#  'con_L.LG_L.POP_count',
#  'con_L.LG_L.POR_count',
#  'con_L.LG_L.PTR_count',
#  'con_L.LG_L.PCAL_count',
#  'con_L.LG_L.PoCG_count',
#  'con_L.LG_L.PCG_count',
#  'con_L.LG_L.PrCG_count',
#  'con_L.LG_L.PCU_count',
#  'con_L.LG_L.RACG_count',
#  'con_L.LG_L.RMFG_count',
#  'con_L.LG_L.SFG_count',
#  'con_L.LG_L.SPG_count',
#  'con_L.LG_L.STG_count',
#  'con_L.LG_L.SMG_count',
#  'con_L.LG_L.FP_count',
#  'con_L.LG_L.TP_count',
#  'con_L.LG_L.TTG_count',
#  'con_L.LG_L.IN_count',
#  'con_L.LG_L.CER_count',
#  'con_L.LG_L.TH_count',
#  'con_L.LG_L.CA_count',
#  'con_L.LG_L.PU_count',
#  'con_L.LG_L.PA_count',
#  'con_L.LG_L.HI_count',
#  'con_L.LG_L.AM_count',
#  'con_L.LG_L.AC_count',
#  'con_L.LG_R.TH_count',
#  'con_L.LG_R.CA_count',
#  'con_L.LG_R.PU_count',
#  'con_L.LG_R.PA_count',
#  'con_L.LG_R.HI_count',
#  'con_L.LG_R.AM_count',
#  'con_L.LG_R.AC_count',
#  'con_L.LG_R.BSTS_count',
#  'con_L.LG_R.CACG_count',
#  'con_L.LG_R.CMFG_count',
#  'con_L.LG_R.CU_count',
#  'con_L.LG_R.EC_count',
#  'con_L.LG_R.FG_count',
#  'con_L.LG_R.IPG_count',
#  'con_L.LG_R.ITG_count',
#  'con_L.LG_R.ICG_count',
#  'con_L.LG_R.LOG_count',
#  'con_L.LG_R.LOFG_count',
#  'con_L.LG_R.LG_count',
#  'con_L.LG_R.MOFG_count',
#  'con_L.LG_R.MTG_count',
#  'con_L.LG_R.PHIG_count',
#  'con_L.LG_R.PaCG_count',
#  'con_L.LG_R.POP_count',
#  'con_L.LG_R.POR_count',
#  'con_L.LG_R.PTR_count',
#  'con_L.LG_R.PCAL_count',
#  'con_L.LG_R.PoCG_count',
#  'con_L.LG_R.PCG_count',
#  'con_L.LG_R.PrCG_count',
#  'con_L.LG_R.PCU_count',
#  'con_L.LG_R.RACG_count',
#  'con_L.LG_R.RMFG_count',
#  'con_L.LG_R.SFG_count',
#  'con_L.LG_R.SPG_count',
#  'con_L.LG_R.STG_count',
#  'con_L.LG_R.SMG_count',
#  'con_L.LG_R.FP_count',
#  'con_L.LG_R.TP_count',
#  'con_L.LG_R.TTG_count',
#  'con_L.LG_R.IN_count',
#  'con_L.LG_R.CER_count',
#  'con_L.MOFG_L.MTG_count',
#  'con_L.MOFG_L.PHIG_count',
#  'con_L.MOFG_L.PaCG_count',
#  'con_L.MOFG_L.POP_count',
#  'con_L.MOFG_L.POR_count',
#  'con_L.MOFG_L.PTR_count',
#  'con_L.MOFG_L.PCAL_count',
#  'con_L.MOFG_L.PoCG_count',
#  'con_L.MOFG_L.PCG_count',
#  'con_L.MOFG_L.PrCG_count',
#  'con_L.MOFG_L.PCU_count',
#  'con_L.MOFG_L.RACG_count',
#  'con_L.MOFG_L.RMFG_count',
#  'con_L.MOFG_L.SFG_count',
#  'con_L.MOFG_L.SPG_count',
#  'con_L.MOFG_L.STG_count',
#  'con_L.MOFG_L.SMG_count',
#  'con_L.MOFG_L.FP_count',
#  'con_L.MOFG_L.TP_count',
#  'con_L.MOFG_L.TTG_count',
#  'con_L.MOFG_L.IN_count',
#  'con_L.MOFG_L.CER_count',
#  'con_L.MOFG_L.TH_count',
#  'con_L.MOFG_L.CA_count',
#  'con_L.MOFG_L.PU_count',
#  'con_L.MOFG_L.PA_count',
#  'con_L.MOFG_L.HI_count',
#  'con_L.MOFG_L.AM_count',
#  'con_L.MOFG_L.AC_count',
#  'con_L.MOFG_R.TH_count',
#  'con_L.MOFG_R.CA_count',
#  'con_L.MOFG_R.PU_count',
#  'con_L.MOFG_R.PA_count',
#  'con_L.MOFG_R.HI_count',
#  'con_L.MOFG_R.AM_count',
#  'con_L.MOFG_R.AC_count',
#  'con_L.MOFG_R.BSTS_count',
#  'con_L.MOFG_R.CACG_count',
#  'con_L.MOFG_R.CMFG_count',
#  'con_L.MOFG_R.CU_count',
#  'con_L.MOFG_R.EC_count',
#  'con_L.MOFG_R.FG_count',
#  'con_L.MOFG_R.IPG_count',
#  'con_L.MOFG_R.ITG_count',
#  'con_L.MOFG_R.ICG_count',
#  'con_L.MOFG_R.LOG_count',
#  'con_L.MOFG_R.LOFG_count',
#  'con_L.MOFG_R.LG_count',
#  'con_L.MOFG_R.MOFG_count',
#  'con_L.MOFG_R.MTG_count',
#  'con_L.MOFG_R.PHIG_count',
#  'con_L.MOFG_R.PaCG_count',
#  'con_L.MOFG_R.POP_count',
#  'con_L.MOFG_R.POR_count',
#  'con_L.MOFG_R.PTR_count',
#  'con_L.MOFG_R.PCAL_count',
#  'con_L.MOFG_R.PoCG_count',
#  'con_L.MOFG_R.PCG_count',
#  'con_L.MOFG_R.PrCG_count',
#  'con_L.MOFG_R.PCU_count',
#  'con_L.MOFG_R.RACG_count',
#  'con_L.MOFG_R.RMFG_count',
#  'con_L.MOFG_R.SFG_count',
#  'con_L.MOFG_R.SPG_count',
#  'con_L.MOFG_R.STG_count',
#  'con_L.MOFG_R.SMG_count',
#  'con_L.MOFG_R.FP_count',
#  'con_L.MOFG_R.TP_count',
#  'con_L.MOFG_R.TTG_count',
#  'con_L.MOFG_R.IN_count',
#  ...]

# %%
train_data_processed = train_data.fillna(0).reset_index(drop=True)
features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] + mri] 

object_feat =[]

j=0
for i in test_data[features].dtypes:
    #print(j)
    if i == 'object':
        print(test_data[features].columns[j])
        object_feat.append(test_data[features].columns[j])
    j+=1
    
print(object_feat)

features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] +mri +object_feat]
# Out:
# []

# %%
def preproecessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    test_data_processed["kfold"] = -1

    train_data_processed["kfold"] = -1

    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)

    kf = KFold(n_splits=NUM_FOLDS)

    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed)):
        train_data_processed.loc[val_, 'kfold'] = fold
    print("done preprocessing")
    return train_data_processed, test_data_processed

def rocvis(true , prob , label ) :
    from sklearn.metrics import roc_curve
    if type(true[0]) == str :
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        true = le.fit_transform(true)
    else :
        pass
    fpr, tpr, thresholds = roc_curve(true, prob)
    plt.plot(fpr, tpr, marker='.', label = label  )
    
# Augmented
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm

def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 


    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

def find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test):
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    # define hyperparameter space
    """
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,8]
    lr_ = [2e-2,1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99]
    ss_ = [10, 20]
  
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        clf = TabNetClassifier(n_a = hy[0],
                               n_d = hy[0],
                               optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                               scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                               scheduler_fn=torch.optim.lr_scheduler.StepLR,
                               verbose=0
                               )
        clf.fit(X_train, Y_train, X_valid, Y_valid, patience=10, batch_size=256, max_epochs=200)
        #clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200) (Recommended)
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
        print("--------Valid score: {} --------------------".format(-clf.best_cost))
        print("--------Test auc: {} Test acc:{}-------------".format(test_auc, test_acc) )
        if test_auc>max_auc:
            max_hy = hy
            max_auc = test_auc
    return max_hy
    
def bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test, max_hy, features):
 
    hy = max_hy
    clf = TabNetClassifier(n_a = hy[0],
                           n_d = hy[0],
                           optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                           scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                           scheduler_fn=torch.optim.lr_scheduler.StepLR,
                           verbose=0
                               )
    clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200)
    preds_acc = clf.predict(X_test)
    preds_prob = clf.predict_proba(X_test)
    test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
    test_acc = accuracy_score(preds_acc, Y_test)
    
    
    
    print("Max hy:" ,hy)
    print("--------Valid score: {} --------------------".format(-clf.best_cost))
    print("FINAL TEST SCORE(max) test auc: {} test acc: {}".format(test_auc, test_acc))
    return test_auc, clf, preds_prob
    
    
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values

    df_train = train_data_processed[train_data_processed.kfold != fold]
    df_valid = train_data_processed[train_data_processed.kfold == fold]
    
    X_train = df_train[features].values
    Y_train = df_train[target].values
    
    X_valid = df_valid[features].values
    Y_valid = df_valid[target].values
    
    y_oof = np.zeros((df_valid.shape[0],len(target)))   # Out of folds validation
    
    print("---------------------------------------Training Begining for fold {}-------------------------------".format(fold+1))
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    # Start training
    max_hy = find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test)
    
    print("Found maximum hyperparmeter, now work with that")
    
    test_auc, clf, preds_prob = bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test
                                               , max_hy, features)
    
    import_feat=feature(Num_feat, clf, test_data_processed, features)
    preds_val_prob = clf.predict_proba(X_valid)

    return test_auc, Y_test, clf, preds_prob, import_feat, Y_valid, preds_val_prob



    
def hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat):
    CV_auc_all = []
    train_data_processed, test_data_processed = preproecessing (train_data, test_data, Num_FOLDS)
    import_feat_every = pd.DataFrame()
    features_all = [ col for col in train_data_processed.columns if col not in unused_feat + [target]] 
    features_mri = [ col for col in mri if col not in 'rsfmri_cor_network.gordon_subcort.aseg_visitid']  
    features_pheno = [ col for col in train_data_processed.columns if col not in unused_feat + [target] 
                +mri] 
    print("all")
    test_auc_all, Y_test_all, clf, preds_prob_all, import_feat_all, Y_valid_all, preds_val_prob_all = run(train_data_processed,
                                                                         test_data_processed,
                                                                         0, 
                                                                         Num_feat, 
                                                                         features_all
                                             )
    print("pheno")
    test_auc_pheno, Y_test_pheno, clf, preds_prob_pheno, import_feat_pheno, Y_valid_pheno, preds_val_prob_pheno = run(train_data_processed, test_data_processed, 
                                            0, Num_feat, features_pheno)
  
    print("mri")
    test_auc_mri, Y_test_mri, clf, preds_prob_mri, import_feat_mri, Y_valid_mri, preds_val_prob_mri = run(train_data_processed, test_data_processed,
                                            0, Num_feat, features_mri)
  
    
    fig , ax = plt.subplots(figsize= (20,10))
    plt.plot([0, 1], [0, 1], linestyle='--')
    rocvis(Y_test_all , preds_prob_all[:,1] , "MRI+Pheno")
    rocvis(Y_test_pheno , preds_prob_pheno[:,1] , "Pheno")
    rocvis(Y_test_mri , preds_prob_mri[:,1] , "MRI")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
    plt.legend(fontsize = 20)
    plt.title(dataset_name, fontsize= 25)
    plt.tight_layout()
    plt.savefig(f'{dataset_name}_ROC.png')

    
    plt.show()
    return test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri

# %%
test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri= hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
# Out:
# done preprocessing
# all
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.7360227410185073 --------------------
# --------Test auc: 0.7341029419791497 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.733670013305915 --------------------
# --------Test auc: 0.7322471480814366 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7364219184710294 --------------------
# --------Test auc: 0.7275257900769608 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.733670013305915 --------------------
# --------Test auc: 0.7322471480814366 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6934740534655861 --------------------
# --------Test auc: 0.6589432891217728 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6934740534655861 --------------------
# --------Test auc: 0.6589432891217728 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6934740534655861 --------------------
# --------Test auc: 0.6589432891217728 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6934740534655861 --------------------
# --------Test auc: 0.6589432891217728 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6753175275190517 --------------------
# --------Test auc: 0.6478221712788603 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6750423370025401 --------------------
# --------Test auc: 0.6348043229081382 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6894883270835853 --------------------
# --------Test auc: 0.6236013318050324 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6750423370025401 --------------------
# --------Test auc: 0.6348043229081382 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.726357808152897 --------------------
# --------Test auc: 0.6958954205556465 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7216463045844925 --------------------
# --------Test auc: 0.6955406364281425 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7354663118422644 --------------------
# --------Test auc: 0.7010261448610884 Test acc:0.6109660574412533-------------
# Device used : cuda
# --------Valid score: 0.7216463045844925 --------------------
# --------Test auc: 0.6955406364281425 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6721906374742955 --------------------
# --------Test auc: 0.619753288575951 Test acc:0.566579634464752-------------
# Device used : cuda
# --------Valid score: 0.6550139107294062 --------------------
# --------Test auc: 0.6224278150755963 Test acc:0.5430809399477807-------------
# Device used : cuda
# --------Valid score: 0.6833373654288134 --------------------
# --------Test auc: 0.635636701053436 Test acc:0.5587467362924282-------------
# Device used : cuda
# --------Valid score: 0.6860287891617274 --------------------
# --------Test auc: 0.6431690409912123 Test acc:0.5691906005221932-------------
# Device used : cuda
# --------Valid score: 0.6837607354542156 --------------------
# --------Test auc: 0.6529938322143989 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.6323333736542881 --------------------
# --------Test auc: 0.621199716172698 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5264969154469578 --------------------
# --------Test auc: 0.4635118170405545 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6090661666868272 --------------------
# --------Test auc: 0.6494186998526281 Test acc:0.5691906005221932-------------
# Device used : cuda
# --------Valid score: 0.6900205636869481 --------------------
# --------Test auc: 0.6615359423612248 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7192875287286804 --------------------
# --------Test auc: 0.6732984007423175 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.6923249062537801 --------------------
# --------Test auc: 0.6575787347852191 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.7235454215555824 --------------------
# --------Test auc: 0.6762458381092735 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6172009193177694 --------------------
# --------Test auc: 0.6025326128486437 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6148360953187372 --------------------
# --------Test auc: 0.6075541728071612 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.628656102576509 --------------------
# --------Test auc: 0.5969106489820425 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6148360953187372 --------------------
# --------Test auc: 0.6075541728071612 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5371476956574331 --------------------
# --------Test auc: 0.46823317504503026 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5566469093988147 --------------------
# --------Test auc: 0.5578571038698762 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5371476956574331 --------------------
# --------Test auc: 0.46823317504503026 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5566469093988147 --------------------
# --------Test auc: 0.5578571038698762 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5486149752026128 --------------------
# --------Test auc: 0.4739370121718247 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5486149752026128 --------------------
# --------Test auc: 0.4739370121718247 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5486149752026128 --------------------
# --------Test auc: 0.4739370121718247 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5486149752026128 --------------------
# --------Test auc: 0.4739370121718247 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5737873472843837 --------------------
# --------Test auc: 0.5150919709622837 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5737873472843837 --------------------
# --------Test auc: 0.5150919709622837 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5737873472843837 --------------------
# --------Test auc: 0.5150919709622837 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5737873472843837 --------------------
# --------Test auc: 0.5150919709622837 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5369360106447322 --------------------
# --------Test auc: 0.5395447846733257 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5369360106447322 --------------------
# --------Test auc: 0.5395447846733257 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5369360106447322 --------------------
# --------Test auc: 0.5395447846733257 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5369360106447322 --------------------
# --------Test auc: 0.5395447846733257 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5623775250997943 --------------------
# --------Test auc: 0.5099885377435729 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5623775250997943 --------------------
# --------Test auc: 0.5099885377435729 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5623775250997943 --------------------
# --------Test auc: 0.5099885377435729 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5623775250997943 --------------------
# --------Test auc: 0.5099885377435729 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.549413330107657 --------------------
# --------Test auc: 0.4883467059658316 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.5448439579049232 --------------------
# --------Test auc: 0.48490802903771635 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5448439579049232 --------------------
# --------Test auc: 0.48490802903771635 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5448439579049232 --------------------
# --------Test auc: 0.48490802903771635 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5681988629490746 --------------------
# --------Test auc: 0.474783035860488 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5681988629490746 --------------------
# --------Test auc: 0.474783035860488 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5681988629490746 --------------------
# --------Test auc: 0.474783035860488 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5681988629490746 --------------------
# --------Test auc: 0.474783035860488 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.565580016934801 --------------------
# --------Test auc: 0.5164838163855685 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.565580016934801 --------------------
# --------Test auc: 0.5164838163855685 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.565580016934801 --------------------
# --------Test auc: 0.5164838163855685 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.565580016934801 --------------------
# --------Test auc: 0.5164838163855685 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5635932018870207 --------------------
# --------Test auc: 0.495196768735331 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5711322124107899 --------------------
# --------Test auc: 0.4923857868020305 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5635932018870207 --------------------
# --------Test auc: 0.495196768735331 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5711322124107899 --------------------
# --------Test auc: 0.4923857868020305 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5584311116487238 --------------------
# --------Test auc: 0.4893291850881502 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5584311116487238 --------------------
# --------Test auc: 0.4893291850881502 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5614370388290795 --------------------
# --------Test auc: 0.45393264559794777 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.5584311116487238 --------------------
# --------Test auc: 0.4893291850881502 Test acc:0.4856396866840731-------------
# Device used : cuda
# --------Valid score: 0.7493347042457966 --------------------
# --------Test auc: 0.7037552535341958 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7502056368694809 --------------------
# --------Test auc: 0.7266797663882976 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7482520866094109 --------------------
# --------Test auc: 0.7212215490420829 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7502056368694809 --------------------
# --------Test auc: 0.7266797663882976 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6982157977500907 --------------------
# --------Test auc: 0.6462529337918236 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7023678480706423 --------------------
# --------Test auc: 0.6874761202991104 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6835188097254143 --------------------
# --------Test auc: 0.6859887560722668 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7023678480706423 --------------------
# --------Test auc: 0.6874761202991104 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6753538163783719 --------------------
# --------Test auc: 0.6537852737295999 Test acc:0.5535248041775457-------------
# Device used : cuda
# --------Valid score: 0.6758679085520745 --------------------
# --------Test auc: 0.6359096119207467 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.6756622716825934 --------------------
# --------Test auc: 0.653403198515365 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.6758679085520745 --------------------
# --------Test auc: 0.6359096119207467 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.7355026007015846 --------------------
# --------Test auc: 0.6973691392391245 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7397544453852668 --------------------
# --------Test auc: 0.7191201353637903 Test acc:0.556135770234987-------------
# Device used : cuda
# --------Valid score: 0.7295270352001936 --------------------
# --------Test auc: 0.7107417717373505 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7368331922099914 --------------------
# --------Test auc: 0.7267889307352219 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6779242772468852 --------------------
# --------Test auc: 0.6528300856940124 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.6926394097012218 --------------------
# --------Test auc: 0.6572239506577152 Test acc:0.577023498694517-------------
# Device used : cuda
# --------Valid score: 0.677900084674005 --------------------
# --------Test auc: 0.6586976693411932 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.6907100520140317 --------------------
# --------Test auc: 0.6531575787347852 Test acc:0.5718015665796344-------------
# Device used : cuda
# --------Valid score: 0.6370025402201525 --------------------
# --------Test auc: 0.5649527864199553 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.632508769807669 --------------------
# --------Test auc: 0.6070356421592709 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.644024434498609 --------------------
# --------Test auc: 0.6293051689318269 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.632508769807669 --------------------
# --------Test auc: 0.6070356421592709 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.7279061328172253 --------------------
# --------Test auc: 0.713852955624693 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7158340389500424 --------------------
# --------Test auc: 0.6946400305660172 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7160880609652838 --------------------
# --------Test auc: 0.703455051580154 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7166686827144068 --------------------
# --------Test auc: 0.6767097865837018 Test acc:0.5509138381201044-------------
# Device used : cuda
# --------Valid score: 0.6841962017660578 --------------------
# --------Test auc: 0.650455761148409 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.6848917382363613 --------------------
# --------Test auc: 0.6775831013590962 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6784807064231282 --------------------
# --------Test auc: 0.6776922657060204 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6848917382363613 --------------------
# --------Test auc: 0.6775831013590962 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6379248820612073 --------------------
# --------Test auc: 0.6239288248458055 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.676545300592718 --------------------
# --------Test auc: 0.6410130451394574 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6637050925365912 --------------------
# --------Test auc: 0.6182522788057421 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.676545300592718 --------------------
# --------Test auc: 0.6410130451394574 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7222329744768358 --------------------
# --------Test auc: 0.6712242781507559 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7185677996854964 --------------------
# --------Test auc: 0.6884449538780635 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7190032659973389 --------------------
# --------Test auc: 0.6773374815785165 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7364340147574695 --------------------
# --------Test auc: 0.6642650510343322 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.5565319946776339 --------------------
# --------Test auc: 0.5230336772010262 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5565319946776339 --------------------
# --------Test auc: 0.5230336772010262 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5565319946776339 --------------------
# --------Test auc: 0.5230336772010262 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5565319946776339 --------------------
# --------Test auc: 0.5230336772010262 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7033930083464376 --------------------
# --------Test auc: 0.6420501064352383 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.6298929478650054 --------------------
# --------Test auc: 0.5948365263904809 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7029998790371356 --------------------
# --------Test auc: 0.631624911303968 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7029031087456151 --------------------
# --------Test auc: 0.6778560122264069 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.5557396879158099 --------------------
# --------Test auc: 0.4659680148463512 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5557396879158099 --------------------
# --------Test auc: 0.4659680148463512 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5557396879158099 --------------------
# --------Test auc: 0.4659680148463512 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5557396879158099 --------------------
# --------Test auc: 0.4659680148463512 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.6818979073424458 --------------------
# --------Test auc: 0.6273947928606517 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.6910245554614733 --------------------
# --------Test auc: 0.6924840347142622 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.5471089875408249 --------------------
# --------Test auc: 0.5357786147044376 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7115096165477199 --------------------
# --------Test auc: 0.6407128431854157 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.5691302770049596 --------------------
# --------Test auc: 0.5671906555319033 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5691302770049596 --------------------
# --------Test auc: 0.5671906555319033 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5691302770049596 --------------------
# --------Test auc: 0.5671906555319033 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5691302770049596 --------------------
# --------Test auc: 0.5671906555319033 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5279666142494255 --------------------
# --------Test auc: 0.4868456961956225 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5279666142494255 --------------------
# --------Test auc: 0.4868456961956225 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5279666142494255 --------------------
# --------Test auc: 0.4868456961956225 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5279666142494255 --------------------
# --------Test auc: 0.4868456961956225 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5430022982944236 --------------------
# --------Test auc: 0.4914033076797118 Test acc:0.4699738903394256-------------
# Device used : cuda
# --------Valid score: 0.5430022982944236 --------------------
# --------Test auc: 0.4914033076797118 Test acc:0.4699738903394256-------------
# Device used : cuda
# --------Valid score: 0.5430022982944236 --------------------
# --------Test auc: 0.4914033076797118 Test acc:0.4699738903394256-------------
# Device used : cuda
# --------Valid score: 0.5430022982944236 --------------------
# --------Test auc: 0.4914033076797118 Test acc:0.4699738903394256-------------
# Device used : cuda
# --------Valid score: 0.5331619692754324 --------------------
# --------Test auc: 0.5043119917035097 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.5331619692754324 --------------------
# --------Test auc: 0.5043119917035097 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.5331619692754324 --------------------
# --------Test auc: 0.5043119917035097 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.5331619692754324 --------------------
# --------Test auc: 0.5043119917035097 Test acc:0.5195822454308094-------------
#
# Found maximum hyperparmeter, now work with that
# Device used : cuda
# Max hy: (4, 0.02, 0.01, 0.95, 10)
# --------Valid score: 0.7360227410185073 --------------------
# FINAL TEST SCORE(max) test auc: 0.7341029419791497 test acc: 0.5143603133159269
# pheno
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.7718337970243135 --------------------
# --------Test auc: 0.7524425522624312 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7559090359259708 --------------------
# --------Test auc: 0.7305551007041102 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.760560058062175 --------------------
# --------Test auc: 0.7384422247693903 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7559090359259708 --------------------
# --------Test auc: 0.7305551007041102 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7448832708358535 --------------------
# --------Test auc: 0.7148354347470116 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.747680537075118 --------------------
# --------Test auc: 0.7113285301020686 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7561388653683319 --------------------
# --------Test auc: 0.7216036242563179 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.747680537075118 --------------------
# --------Test auc: 0.7113285301020686 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7441877343655497 --------------------
# --------Test auc: 0.7017357131160963 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7493861134631667 --------------------
# --------Test auc: 0.6900278369084657 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7394732067255352 --------------------
# --------Test auc: 0.7024179902843731 Test acc:0.5430809399477807-------------
# Device used : cuda
# --------Valid score: 0.7493861134631667 --------------------
# --------Test auc: 0.6900278369084657 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.754215555824362 --------------------
# --------Test auc: 0.7429998362534797 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7572033385750576 --------------------
# --------Test auc: 0.739602095955461 Test acc:0.5430809399477807-------------
# Device used : cuda
# --------Valid score: 0.7562719245191726 --------------------
# --------Test auc: 0.7344304350199226 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7636869481069312 --------------------
# --------Test auc: 0.7393155395447848 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7430869722995042 --------------------
# --------Test auc: 0.7147535614868183 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7515906616668683 --------------------
# --------Test auc: 0.7197205392718737 Test acc:0.5404699738903395-------------
# Device used : cuda
# --------Valid score: 0.7336881577355749 --------------------
# --------Test auc: 0.7021450794170624 Test acc:0.5378590078328982-------------
# Device used : cuda
# --------Valid score: 0.7491865247369057 --------------------
# --------Test auc: 0.7199115768789914 Test acc:0.5535248041775457-------------
# Device used : cuda
# --------Valid score: 0.7435103423249062 --------------------
# --------Test auc: 0.7053517821079636 Test acc:0.556135770234987-------------
# Device used : cuda
# --------Valid score: 0.7281420104028062 --------------------
# --------Test auc: 0.6973418481523934 Test acc:0.5509138381201044-------------
# Device used : cuda
# --------Valid score: 0.7228196443691787 --------------------
# --------Test auc: 0.7011626002947436 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.7297508164993347 --------------------
# --------Test auc: 0.7086403580590579 Test acc:0.5430809399477807-------------
# Device used : cuda
# --------Valid score: 0.7519837909761703 --------------------
# --------Test auc: 0.7061841602532613 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7491472118059757 --------------------
# --------Test auc: 0.7088859778396375 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7534716342082981 --------------------
# --------Test auc: 0.7210032203482343 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7491472118059757 --------------------
# --------Test auc: 0.7088859778396375 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7374501028184347 --------------------
# --------Test auc: 0.697914960973746 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7447078746824725 --------------------
# --------Test auc: 0.7132252606298783 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7459537921857989 --------------------
# --------Test auc: 0.7089405600130998 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.7461473327688399 --------------------
# --------Test auc: 0.6999890835653075 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7229587516632394 --------------------
# --------Test auc: 0.7033458872332297 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7276581589452038 --------------------
# --------Test auc: 0.6995797172643414 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7361013668803678 --------------------
# --------Test auc: 0.6972599748922003 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7213922825692513 --------------------
# --------Test auc: 0.6910103160307842 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7356417079956454 --------------------
# --------Test auc: 0.6851973145570657 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7607294060723359 --------------------
# --------Test auc: 0.7399705256263305 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7460747550501995 --------------------
# --------Test auc: 0.7017357131160963 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7459840329018991 --------------------
# --------Test auc: 0.7019267507232139 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.6912483367606145 --------------------
# --------Test auc: 0.6956498007750669 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.7050320551590661 --------------------
# --------Test auc: 0.6821680039299166 Test acc:0.5378590078328982-------------
# Device used : cuda
# --------Valid score: 0.697290431837426 --------------------
# --------Test auc: 0.6844058730418644 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.7248094834885691 --------------------
# --------Test auc: 0.713443589323727 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.5928783113584131 --------------------
# --------Test auc: 0.5829785492058293 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5928783113584131 --------------------
# --------Test auc: 0.5829785492058293 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5928783113584131 --------------------
# --------Test auc: 0.5829785492058293 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5928783113584131 --------------------
# --------Test auc: 0.5829785492058293 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5606689246401355 --------------------
# --------Test auc: 0.49808962392882494 Test acc:0.4751958224543081-------------
# Device used : cuda
# --------Valid score: 0.5606689246401355 --------------------
# --------Test auc: 0.49808962392882494 Test acc:0.4751958224543081-------------
# Device used : cuda
# --------Valid score: 0.5606689246401355 --------------------
# --------Test auc: 0.49808962392882494 Test acc:0.4751958224543081-------------
# Device used : cuda
# --------Valid score: 0.5606689246401355 --------------------
# --------Test auc: 0.49808962392882494 Test acc:0.4751958224543081-------------
# Device used : cuda
# --------Valid score: 0.5755110681020925 --------------------
# --------Test auc: 0.5441296872441461 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5755110681020925 --------------------
# --------Test auc: 0.5441296872441461 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5755110681020925 --------------------
# --------Test auc: 0.5441296872441461 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5755110681020925 --------------------
# --------Test auc: 0.5441296872441461 Test acc:0.49869451697127937-------------
# Device used : cuda
# --------Valid score: 0.5353030119753235 --------------------
# --------Test auc: 0.4780852573549479 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5353030119753235 --------------------
# --------Test auc: 0.4780852573549479 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5353030119753235 --------------------
# --------Test auc: 0.4780852573549479 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5353030119753235 --------------------
# --------Test auc: 0.4780852573549479 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5881365670739083 --------------------
# --------Test auc: 0.5650619507668795 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5881365670739083 --------------------
# --------Test auc: 0.5650619507668795 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5881365670739083 --------------------
# --------Test auc: 0.5650619507668795 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5881365670739083 --------------------
# --------Test auc: 0.5650619507668795 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.6032055159066166 --------------------
# --------Test auc: 0.5408547568364173 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.6023769202854724 --------------------
# --------Test auc: 0.5289831341084001 Test acc:0.4621409921671018-------------
# Device used : cuda
# --------Valid score: 0.604251844683682 --------------------
# --------Test auc: 0.5414005785710387 Test acc:0.46475195822454307-------------
# Device used : cuda
# --------Valid score: 0.6023769202854724 --------------------
# --------Test auc: 0.5289831341084001 Test acc:0.4621409921671018-------------
# Device used : cuda
# --------Valid score: 0.5898633119632273 --------------------
# --------Test auc: 0.544811964412423 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5978771017297689 --------------------
# --------Test auc: 0.5304841438786093 Test acc:0.4830287206266319-------------
# Device used : cuda
# --------Valid score: 0.5954094592959962 --------------------
# --------Test auc: 0.5335134545057584 Test acc:0.4804177545691906-------------
# Device used : cuda
# --------Valid score: 0.5978771017297689 --------------------
# --------Test auc: 0.5304841438786093 Test acc:0.4830287206266319-------------
# Device used : cuda
# --------Valid score: 0.7596830772952703 --------------------
# --------Test auc: 0.7306369739643032 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7516329986694085 --------------------
# --------Test auc: 0.7336389935047214 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7536954155074392 --------------------
# --------Test auc: 0.7397249058457509 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7516329986694085 --------------------
# --------Test auc: 0.7336389935047214 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7535744526430387 --------------------
# --------Test auc: 0.7049424158069975 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7520261279787105 --------------------
# --------Test auc: 0.7052562633044048 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7519686706181202 --------------------
# --------Test auc: 0.7114513399923584 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7520261279787105 --------------------
# --------Test auc: 0.7052562633044048 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7150356840449981 --------------------
# --------Test auc: 0.7063751978603788 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7312870448772227 --------------------
# --------Test auc: 0.7329021341629823 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7411122535381638 --------------------
# --------Test auc: 0.7272801702963811 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7312870448772227 --------------------
# --------Test auc: 0.7329021341629823 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7543425668319826 --------------------
# --------Test auc: 0.7348943834943509 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7525825571549534 --------------------
# --------Test auc: 0.7231319251132581 Test acc:0.5509138381201044-------------
# Device used : cuda
# --------Valid score: 0.7600520140316923 --------------------
# --------Test auc: 0.7338027400251078 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7615580016934801 --------------------
# --------Test auc: 0.7399159434528683 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7261158824240957 --------------------
# --------Test auc: 0.7213852955624693 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7285472359985485 --------------------
# --------Test auc: 0.7091315976202173 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7233095439700012 --------------------
# --------Test auc: 0.7298455324491021 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7219426636022742 --------------------
# --------Test auc: 0.7032094317995743 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7272559574210717 --------------------
# --------Test auc: 0.707221221549042 Test acc:0.5535248041775457-------------
# Device used : cuda
# --------Valid score: 0.739225232853514 --------------------
# --------Test auc: 0.7148627258337426 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.730367727107778 --------------------
# --------Test auc: 0.735003547841275 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.739225232853514 --------------------
# --------Test auc: 0.7148627258337426 Test acc:0.5483028720626631-------------
# Device used : cuda
# --------Valid score: 0.7475323575662272 --------------------
# --------Test auc: 0.727907865291196 Test acc:0.5404699738903395-------------
# Device used : cuda
# --------Valid score: 0.7272408370630216 --------------------
# --------Test auc: 0.7223404835980569 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7349461715253418 --------------------
# --------Test auc: 0.7136619180175754 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.7406556187250514 --------------------
# --------Test auc: 0.729845532449102 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7340449981855569 --------------------
# --------Test auc: 0.6848971126030239 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7341901536228379 --------------------
# --------Test auc: 0.6929479831886907 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.734032901899117 --------------------
# --------Test auc: 0.6692320288193875 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7416414660699164 --------------------
# --------Test auc: 0.696413951203537 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7062537800895125 --------------------
# --------Test auc: 0.6938212979640849 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.7463408733518809 --------------------
# --------Test auc: 0.7199934501391846 Test acc:0.5404699738903395-------------
# Device used : cuda
# --------Valid score: 0.7038466190879401 --------------------
# --------Test auc: 0.6498826483270563 Test acc:0.5456919060052219-------------
# Device used : cuda
# --------Valid score: 0.7219547598887142 --------------------
# --------Test auc: 0.6904644942961629 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.7297840812870449 --------------------
# --------Test auc: 0.697587467932973 Test acc:0.5195822454308094-------------
# Device used : cuda
# --------Valid score: 0.7319462924882061 --------------------
# --------Test auc: 0.7052835543911358 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.7233579291157616 --------------------
# --------Test auc: 0.710523443043502 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.724603846619088 --------------------
# --------Test auc: 0.6814311445881774 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.6911878553284142 --------------------
# --------Test auc: 0.6759456361552316 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.708818192814806 --------------------
# --------Test auc: 0.6752360679002237 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7143461957179147 --------------------
# --------Test auc: 0.6928661099284973 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.7181807185194146 --------------------
# --------Test auc: 0.6720430107526881 Test acc:0.5378590078328982-------------
# Device used : cuda
# --------Valid score: 0.6975928389984275 --------------------
# --------Test auc: 0.6880901697505595 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7100762066045724 --------------------
# --------Test auc: 0.666038971671852 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.7169529454457482 --------------------
# --------Test auc: 0.6790568200425741 Test acc:0.5248041775456919-------------
# Device used : cuda
# --------Valid score: 0.6925063505503809 --------------------
# --------Test auc: 0.6691501555591943 Test acc:0.5300261096605744-------------
# Device used : cuda
# --------Valid score: 0.5614188943994194 --------------------
# --------Test auc: 0.49252224223568586 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5614188943994194 --------------------
# --------Test auc: 0.49252224223568586 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5614188943994194 --------------------
# --------Test auc: 0.49252224223568586 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5614188943994194 --------------------
# --------Test auc: 0.49252224223568586 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.547499092778517 --------------------
# --------Test auc: 0.4794225206047705 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.547499092778517 --------------------
# --------Test auc: 0.4794225206047705 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.547499092778517 --------------------
# --------Test auc: 0.4794225206047705 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.547499092778517 --------------------
# --------Test auc: 0.4794225206047705 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.6660699165356236 --------------------
# --------Test auc: 0.6803122100322034 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.6898633119632273 --------------------
# --------Test auc: 0.6837235958735877 Test acc:0.5378590078328982-------------
# Device used : cuda
# --------Valid score: 0.6801258013789766 --------------------
# --------Test auc: 0.6766006222367775 Test acc:0.5274151436031331-------------
# Device used : cuda
# --------Valid score: 0.6875529212531751 --------------------
# --------Test auc: 0.6781835052671797 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.5618180718519415 --------------------
# --------Test auc: 0.5638611429507123 Test acc:0.5744125326370757-------------
# Device used : cuda
# --------Valid score: 0.5618180718519415 --------------------
# --------Test auc: 0.5638611429507123 Test acc:0.5744125326370757-------------
# Device used : cuda
# --------Valid score: 0.5618180718519415 --------------------
# --------Test auc: 0.5638611429507123 Test acc:0.5744125326370757-------------
# Device used : cuda
# --------Valid score: 0.5618180718519415 --------------------
# --------Test auc: 0.5638611429507123 Test acc:0.5744125326370757-------------
# Device used : cuda
# --------Valid score: 0.5774706665053828 --------------------
# --------Test auc: 0.5559194367119699 Test acc:0.577023498694517-------------
# Device used : cuda
# --------Valid score: 0.5774706665053828 --------------------
# --------Test auc: 0.5559194367119699 Test acc:0.577023498694517-------------
# Device used : cuda
# --------Valid score: 0.5774706665053828 --------------------
# --------Test auc: 0.5559194367119699 Test acc:0.577023498694517-------------
# Device used : cuda
# --------Valid score: 0.5774706665053828 --------------------
# --------Test auc: 0.5559194367119699 Test acc:0.577023498694517-------------
# Device used : cuda
# --------Valid score: 0.5654076448530302 --------------------
# --------Test auc: 0.5271273402106871 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.5654076448530302 --------------------
# --------Test auc: 0.5271273402106871 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.5654076448530302 --------------------
# --------Test auc: 0.5271273402106871 Test acc:0.5352480417754569-------------
# Device used : cuda
# --------Valid score: 0.5654076448530302 --------------------
# --------Test auc: 0.5271273402106871 Test acc:0.5352480417754569-------------
#
# Found maximum hyperparmeter, now work with that
# Device used : cuda
# Max hy: (4, 0.02, 0.01, 0.95, 10)
# --------Valid score: 0.7718337970243135 --------------------
# FINAL TEST SCORE(max) test auc: 0.7524425522624312 test acc: 0.5143603133159269
# mri
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.5669408491593081 --------------------
# --------Test auc: 0.5335953277659516 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5421343897423491 --------------------
# --------Test auc: 0.5272637956443426 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5558122656344502 --------------------
# --------Test auc: 0.47934064734457726 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5421343897423491 --------------------
# --------Test auc: 0.5272637956443426 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5730676182412 --------------------
# --------Test auc: 0.5242071939304623 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5530180234667957 --------------------
# --------Test auc: 0.5069865182031549 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5753991774525221 --------------------
# --------Test auc: 0.5295562469297528 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5530180234667957 --------------------
# --------Test auc: 0.5069865182031549 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5549745977984759 --------------------
# --------Test auc: 0.48589050816003493 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5549745977984759 --------------------
# ...
# --------Test auc: 0.479258774084384 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5375589693963954 --------------------
# --------Test auc: 0.5049123956115933 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5277065440909641 --------------------
# --------Test auc: 0.5172479668140385 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5375589693963954 --------------------
# --------Test auc: 0.5049123956115933 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5582496673521229 --------------------
# --------Test auc: 0.4686698324327275 Test acc:0.5221932114882507-------------
# Device used : cuda
# --------Valid score: 0.5577476714648603 --------------------
# --------Test auc: 0.46012772228590143 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5329018991169712 --------------------
# --------Test auc: 0.4452267889307352 Test acc:0.5065274151436031-------------
# Device used : cuda
# --------Valid score: 0.5577476714648603 --------------------
# --------Test auc: 0.46012772228590143 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5566711019716947 --------------------
# --------Test auc: 0.48398013208885976 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5580319341962018 --------------------
# --------Test auc: 0.4991266852246056 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5430264908673037 --------------------
# --------Test auc: 0.5310845477866928 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5580319341962018 --------------------
# --------Test auc: 0.4991266852246056 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5153380912059997 --------------------
# --------Test auc: 0.48212433819114675 Test acc:0.5091383812010444-------------
# Device used : cuda
# --------Valid score: 0.5325994919559696 --------------------
# --------Test auc: 0.4729545330495061 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5658461352364823 --------------------
# --------Test auc: 0.48146935210960107 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5325994919559696 --------------------
# --------Test auc: 0.4729545330495061 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5396939639530665 --------------------
# --------Test auc: 0.5197860378800284 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5396939639530665 --------------------
# --------Test auc: 0.5197860378800284 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5481069311721302 --------------------
# --------Test auc: 0.4930817095136728 Test acc:0.4934725848563969-------------
# Device used : cuda
# --------Valid score: 0.5396939639530665 --------------------
# --------Test auc: 0.5197860378800284 Test acc:0.5117493472584856-------------
# Device used : cuda
# --------Valid score: 0.5407947260191122 --------------------
# --------Test auc: 0.5196222913596419 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.5407947260191122 --------------------
# --------Test auc: 0.5196222913596419 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.5407947260191122 --------------------
# --------Test auc: 0.5196222913596419 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.5407947260191122 --------------------
# --------Test auc: 0.5196222913596419 Test acc:0.5326370757180157-------------
# Device used : cuda
# --------Valid score: 0.5288496431595501 --------------------
# --------Test auc: 0.46528573767807435 Test acc:0.46736292428198434-------------
# Device used : cuda
# --------Valid score: 0.5275795330833435 --------------------
# --------Test auc: 0.4763386278041591 Test acc:0.5039164490861618-------------
# Device used : cuda
# --------Valid score: 0.5275795330833435 --------------------
# --------Test auc: 0.4763386278041591 Test acc:0.5039164490861618-------------
# Device used : cuda
# --------Valid score: 0.5275795330833435 --------------------
# --------Test auc: 0.4763386278041591 Test acc:0.5039164490861618-------------
# Device used : cuda
# --------Valid score: 0.5784988508527882 --------------------
# --------Test auc: 0.5307024725724578 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5521470908431112 --------------------
# --------Test auc: 0.529665411276677 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5467037619450829 --------------------
# --------Test auc: 0.5082691992795153 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5521470908431112 --------------------
# --------Test auc: 0.529665411276677 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5498669408491593 --------------------
# --------Test auc: 0.5212597565635063 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5498669408491593 --------------------
# --------Test auc: 0.5212597565635063 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.557294060723358 --------------------
# --------Test auc: 0.5144915670542001 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5498669408491593 --------------------
# --------Test auc: 0.5212597565635063 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.559229466553768 --------------------
# --------Test auc: 0.5352327929698161 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5599491955969518 --------------------
# --------Test auc: 0.5203318596146498 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.559229466553768 --------------------
# --------Test auc: 0.5352327929698161 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5599491955969518 --------------------
# --------Test auc: 0.5203318596146498 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5595500181444296 --------------------
# --------Test auc: 0.5343594781944216 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5428450465707029 --------------------
# --------Test auc: 0.5256263304404781 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5662150719729043 --------------------
# --------Test auc: 0.46987064024889474 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5428450465707029 --------------------
# --------Test auc: 0.5256263304404781 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5169710898754083 --------------------
# --------Test auc: 0.5249713443589323 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5169710898754083 --------------------
# --------Test auc: 0.5249713443589323 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5169710898754083 --------------------
# --------Test auc: 0.5249713443589323 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5169710898754083 --------------------
# --------Test auc: 0.5249713443589323 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5474416354179268 --------------------
# --------Test auc: 0.4607554172807161 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5558727470666505 --------------------
# --------Test auc: 0.45971835598493527 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5420104028063385 --------------------
# --------Test auc: 0.4755198952022268 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5558727470666505 --------------------
# --------Test auc: 0.45971835598493527 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5852243861134632 --------------------
# --------Test auc: 0.4900387533431581 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5852243861134632 --------------------
# --------Test auc: 0.4900387533431581 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5852243861134632 --------------------
# --------Test auc: 0.4900387533431581 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5852243861134632 --------------------
# --------Test auc: 0.4900387533431581 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5101608806096527 --------------------
# --------Test auc: 0.4761202991103106 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5101608806096527 --------------------
# --------Test auc: 0.4761202991103106 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5101608806096527 --------------------
# --------Test auc: 0.4761202991103106 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5101608806096527 --------------------
# --------Test auc: 0.4761202991103106 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5505322366033628 --------------------
# --------Test auc: 0.5361879810054037 Test acc:0.5169712793733682-------------
# Device used : cuda
# --------Valid score: 0.5375710656828354 --------------------
# --------Test auc: 0.4952513509087932 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5375710656828354 --------------------
# --------Test auc: 0.4952513509087932 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5375710656828354 --------------------
# --------Test auc: 0.4952513509087932 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5704911092294666 --------------------
# --------Test auc: 0.5225424376398669 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5251481795088908 --------------------
# --------Test auc: 0.466240925713662 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5349703640982217 --------------------
# --------Test auc: 0.4941324163528191 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5251481795088908 --------------------
# --------Test auc: 0.466240925713662 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5289887504536107 --------------------
# --------Test auc: 0.4832705638338518 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5289887504536107 --------------------
# --------Test auc: 0.4832705638338518 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5289887504536107 --------------------
# --------Test auc: 0.4832705638338518 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5289887504536107 --------------------
# --------Test auc: 0.4832705638338518 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5309604451433411 --------------------
# --------Test auc: 0.490011462256427 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5309604451433411 --------------------
# --------Test auc: 0.490011462256427 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.560780815289706 --------------------
# --------Test auc: 0.4915670542000982 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5309604451433411 --------------------
# --------Test auc: 0.490011462256427 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5245615096165477 --------------------
# --------Test auc: 0.47451012499317724 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5311902745857022 --------------------
# --------Test auc: 0.4769117406255117 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5293032539010524 --------------------
# --------Test auc: 0.4541236832050652 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5311902745857022 --------------------
# --------Test auc: 0.4769117406255117 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5272166444901415 --------------------
# --------Test auc: 0.4826428688390372 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5272166444901415 --------------------
# --------Test auc: 0.4826428688390372 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5272166444901415 --------------------
# --------Test auc: 0.4826428688390372 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5272166444901415 --------------------
# --------Test auc: 0.4826428688390372 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5081287044877223 --------------------
# --------Test auc: 0.47718465149282246 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5081287044877223 --------------------
# --------Test auc: 0.47718465149282246 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5081287044877223 --------------------
# --------Test auc: 0.47718465149282246 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5081287044877223 --------------------
# --------Test auc: 0.47718465149282246 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5115942905528003 --------------------
# --------Test auc: 0.5084329457999017 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5115942905528003 --------------------
# --------Test auc: 0.5084329457999017 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5115942905528003 --------------------
# --------Test auc: 0.5084329457999017 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5115942905528003 --------------------
# --------Test auc: 0.5084329457999017 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5097435587274707 --------------------
# --------Test auc: 0.5215326674308172 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5097435587274707 --------------------
# --------Test auc: 0.5215326674308172 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5097435587274707 --------------------
# --------Test auc: 0.5215326674308172 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5097435587274707 --------------------
# --------Test auc: 0.5215326674308172 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5103544211926938 --------------------
# --------Test auc: 0.49178538289394685 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5103544211926938 --------------------
# --------Test auc: 0.49178538289394685 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5103544211926938 --------------------
# --------Test auc: 0.49178538289394685 Test acc:0.5143603133159269-------------
# Device used : cuda
# --------Valid score: 0.5103544211926938 --------------------
# --------Test auc: 0.49178538289394685 Test acc:0.5143603133159269-------------
#
# Found maximum hyperparmeter, now work with that
# Device used : cuda
# Max hy: (8, 0.005, 0.0001, 0.95, 10)
# --------Valid score: 0.5505322366033628 --------------------
# FINAL TEST SCORE(max) test auc: 0.5361879810054037 test acc: 0.5169712793733682

# %%
valid_auc_all = roc_auc_score (Y_valid_all, preds_val_prob_all[:,1])
valid_auc_pheno = roc_auc_score (Y_valid_pheno, preds_val_prob_pheno[:,1])
valid_auc_mri = roc_auc_score (Y_valid_mri, preds_val_prob_mri[:,1])

# %%
print(dataset_name)
print("")
print("Test AUC")
print(f"Pheno+MRI:{round((test_auc_all)*100,2)}%")
print( f"Pheno:{round((test_auc_pheno),4)*100}%")
print(f"MRI:{round((test_auc_mri)*100,2)}%")
print("")
    
print("Valid AUC")

print( f"Pheno+MRI:{round(valid_auc_all,4)*100}%")
print( f"Pheno:{round(valid_auc_pheno*100,2)}%")
print( f"MRI:{round(valid_auc_mri,4)*100}%")
# Out:
# connectome
#
# Test AUC
# Pheno+MRI:73.41%
# Pheno:75.24%
# MRI:53.62%
#
# Valid AUC
# Pheno+MRI:73.6%
# Pheno:77.18%
# MRI:55.05%

# %%
import_feat_every=pd.concat([import_feat_all,import_feat_pheno, import_feat_mri])

import_feat_every.to_csv(f"{dataset_name}_features.csv")

import_feat_every
# Out:
#                         feature name     ratio
# 0                       Depress.CBCL  0.147434
# 1                    Aggressive.CBCL  0.125702
# 2                      PPSP_distress  0.083457
# 3              con_L.RMFG_R.PU_count  0.080000
# 4                        AnxDep.CBCL  0.064159
# 5              con_L.PoCG_R.AM_count  0.049654
# 6               con_L.CA_R.STG_count  0.042317
# 7              con_L.CMFG_L.TH_count  0.034116
# 8               con_L.STG_R.IN_count  0.031875
# 9              con_L.CMFG_R.PU_count  0.024649
# 10              con_L.ITG_R.LG_count  0.021940
# 11             con_L.SFG_L.SPG_count  0.020559
# 12             con_L.CMFG_L.TP_count  0.019314
# 13              con_L.POR_R.LG_count  0.017863
# 14             con_L.BSTS_R.CA_count  0.016817
# 15              con_L.LOG_R.HI_count  0.016428
# 16              con_L.CER_L.PU_count  0.015451
# 17              con_L.FG_L.ITG_count  0.015362
# 18            con_L.SMG_R.PrCG_count  0.015099
# 19             con_L.SPG_L.TTG_count  0.014575
# 0                        AnxDep.CBCL  0.176570
# 1                       Depress.CBCL  0.153900
# 2                       Conduct.CBCL  0.097614
# 3                     PPSP_frequency  0.095276
# 4            nihtbx_list_uncorrected  0.076738
# 5                        DA_baseline  0.071334
# 6   Internal.and.External.Comobidity  0.061869
# 7                      PPSP_distress  0.058614
# 8                           totalBAS  0.035934
# 9                              Ne_PN  0.028098
# 10         upps_lack_of_perseverance  0.022163
# 11      nihtbx_totalcomp_uncorrected  0.022110
# 12     mania_binary_1_year_follow_up  0.020295
# 13                       abcd_site.y  0.016367
# 14                      Thought.CBCL  0.008514
# 15             upps_negative_urgency  0.007377
# 16                        upps_total  0.006817
# 17                            height  0.006786
# 18                           fes_3_p  0.005725
# 19                     SWTD_baseline  0.003533
# 0              con_L.HI_R.PoCG_count  0.124212
# 1              con_L.PA_R.PoCG_count  0.048089
# 2             con_L.PCU_R.BSTS_count  0.028456
# 3            con_L.CACG_L.RMFG_count  0.027474
# 4               con_L.POR_L.TH_count  0.023968
# 5              con_L.SMG_R.SFG_count  0.021056
# 6             con_L.PTR_R.RMFG_count  0.016640
# 7              con_L.AC_R.PCAL_count  0.015414
# 8             con_R.PaCG_R.CER_count  0.014799
# 9               con_L.IN_R.SMG_count  0.013064
# 10             con_L.PA_R.RMFG_count  0.012457
# 11              con_L.POR_L.FP_count  0.012336
# 12            con_L.POP_L.PoCG_count  0.011915
# 13             con_R.PU_R.MOFG_count  0.011460
# 14             con_L.PCU_R.LOG_count  0.011114
# 15              con_L.PCU_R.HI_count  0.011000
# 16               con_L.PU_R.AC_count  0.010836
# 17              con_R.CU_R.PCU_count  0.010576
# 18            con_L.LOG_R.PHIG_count  0.010018
# 19            con_L.LOFG_L.POP_count  0.009995
