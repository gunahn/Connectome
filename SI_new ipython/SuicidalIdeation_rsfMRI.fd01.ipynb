# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

dataset_name = 'rsfMRI.fd01'
train_out = Path(os.getcwd()+'/data1/Suicidalideation_'+dataset_name+'_train.csv')
test_out =Path(os.getcwd()+'/data1/Suicidalideation_'+dataset_name+'_test.csv')


train_data= pd.read_csv(train_out)
test_data= pd.read_csv(test_out)
target ='Suicidalideation.x'
unused_feat = ['Set', 'subjectkey', 'abcd_site.x', 'Unnamed: 0', 'kflod',
               'src_subject_id','interview_date','gender','eventname']
n=0
start_mri = 0;
for i in test_data.columns:
    #print(i)
    if i =='rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh':
        start_mri =n
    n +=1

    
mri = list(test_data.columns[start_mri:])
print(mri)
Num_FOLDS  = 5
# the number of feature that you want to show 
Num_feat = 20
# Out:
# ['rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh', 'rsfmri_var_cort.destrieux_g.and.s.occipital.inf.lh', 'rsfmri_var_cort.destrieux_g.and.s.paracentral.lh', 'rsfmri_var_cort.destrieux_g.and.s.subcentral.lh', 'rsfmri_var_cort.destrieux_g.and.s.transv.frontopol.lh', 'rsfmri_var_cort.destrieux_g.and.s.cingul.ant.lh', 'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.ant.lh', 'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.post.lh', 'rsfmri_var_cort.destrieux_g.cingul.post.dorsal.lh', 'rsfmri_var_cort.destrieux_g.cingul.post.ventral.lh', 'rsfmri_var_cort.destrieux_g.cuneus.lh', 'rsfmri_var_cort.destrieux_g.front.inf.opercular.lh', 'rsfmri_var_cort.destrieux_g.front.inf.orbital.lh', 'rsfmri_var_cort.destrieux_g.front.inf.triangul.lh', 'rsfmri_var_cort.destrieux_g.front.middle.lh', 'rsfmri_var_cort.destrieux_g.front.sup.lh', 'rsfmri_var_cort.destrieux_g.ins.lg.and.s.cent.ins.lh', 'rsfmri_var_cort.destrieux_g.insular.short.lh', 'rsfmri_var_cort.destrieux_g.occipital.middle.lh', 'rsfmri_var_cort.destrieux_g.occipital.sup.lh', 'rsfmri_var_cort.destrieux_g.oc.temp.lat.fusifor.lh', 'rsfmri_var_cort.destrieux_g.oc.temp.med.lingual.lh', 'rsfmri_var_cort.destrieux_g.oc.temp.med.parahip.lh', 'rsfmri_var_cort.destrieux_g.orbital.lh', 'rsfmri_var_cort.destrieux_g.pariet.inf.angular.lh', 'rsfmri_var_cort.destrieux_g.pariet.inf.supramar.lh', 'rsfmri_var_cort.destrieux_g.parietal.sup.lh', 'rsfmri_var_cort.destrieux_g.postcentral.lh', 'rsfmri_var_cort.destrieux_g.precentral.lh', 'rsfmri_var_cort.destrieux_g.precuneus.lh', 'rsfmri_var_cort.destrieux_g.rectus.lh', 'rsfmri_var_cort.destrieux_g.subcallosal.lh', 'rsfmri_var_cort.destrieux_g.temp.sup.g.t.transv.lh', 'rsfmri_var_cort.destrieux_g.temp.sup.lateral.lh', 'rsfmri_var_cort.destrieux_g.temp.sup.plan.polar.lh', 'rsfmri_var_cort.destrieux_g.temp.sup.plan.tempo.lh', 'rsfmri_var_cort.destrieux_g.temporal.inf.lh', 'rsfmri_var_cort.destrieux_g.temporal.middle.lh', 'rsfmri_var_cort.destrieux_lat.fis.ant.horizont.lh', 'rsfmri_var_cort.destrieux_lat.fis.ant.vertical.lh', 'rsfmri_var_cort.destrieux_lat.fis.post.lh', 'rsfmri_var_cort.destrieux_pole.occipital.lh', 'rsfmri_var_cort.destrieux_pole.temporal.lh', 'rsfmri_var_cort.destrieux_s.calcarine.lh', 'rsfmri_var_cort.destrieux_s.central.lh', 'rsfmri_var_cort.destrieux_s.cingul.marginalis.lh', 'rsfmri_var_cort.destrieux_s.circular.insula.ant.lh', 'rsfmri_var_cort.destrieux_s.circular.insula.inf.lh', 'rsfmri_var_cort.destrieux_s.circular.insula.sup.lh', 'rsfmri_var_cort.destrieux_s.collat.transv.ant.lh', 'rsfmri_var_cort.destrieux_s.collat.transv.post.lh', 'rsfmri_var_cort.destrieux_s.front.inf.lh', 'rsfmri_var_cort.destrieux_s.front.middle.lh', 'rsfmri_var_cort.destrieux_s.front.sup.lh', 'rsfmri_var_cort.destrieux_s.interm.prim.jensen.lh', 'rsfmri_var_cort.destrieux_s.intrapariet.and.p.trans.lh', 'rsfmri_var_cort.destrieux_s.oc.middle.and.lunatus.lh', 'rsfmri_var_cort.destrieux_s.oc.sup.and.transversal.lh', 'rsfmri_var_cort.destrieux_s.occipital.ant.lh', 'rsfmri_var_cort.destrieux_s.oc.temp.lat.lh', 'rsfmri_var_cort.destrieux_s.oc.temp.med.and.lingual.lh', 'rsfmri_var_cort.destrieux_s.orbital.lateral.lh', 'rsfmri_var_cort.destrieux_s.orbital.med.olfact.lh', 'rsfmri_var_cort.destrieux_s.orbital.h.shaped.lh', 'rsfmri_var_cort.destrieux_s.parieto.occipital.lh', 'rsfmri_var_cort.destrieux_s.pericallosal.lh', 'rsfmri_var_cort.destrieux_s.postcentral.lh', 'rsfmri_var_cort.destrieux_s.precentral.inf.part.lh', 'rsfmri_var_cort.destrieux_s.precentral.sup.part.lh', 'rsfmri_var_cort.destrieux_s.suborbital.lh', 'rsfmri_var_cort.destrieux_s.subparietal.lh', 'rsfmri_var_cort.destrieux_s.temporal.inf.lh', 'rsfmri_var_cort.destrieux_s.temporal.sup.lh', 'rsfmri_var_cort.destrieux_s.temporal.transverse.lh', 'rsfmri_var_cort.destrieux_g.and.s.frontomargin.rh', 'rsfmri_var_cort.destrieux_g.and.s.occipital.inf.rh', 'rsfmri_var_cort.destrieux_g.and.s.paracentral.rh', 'rsfmri_var_cort.destrieux_g.and.s.subcentral.rh', 'rsfmri_var_cort.destrieux_g.and.s.transv.frontopol.rh', 'rsfmr ...

# %%
mri
# Out:
# ['rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.occipital.inf.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.paracentral.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.subcentral.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.transv.frontopol.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.ant.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.ant.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.post.lh',
#  'rsfmri_var_cort.destrieux_g.cingul.post.dorsal.lh',
#  'rsfmri_var_cort.destrieux_g.cingul.post.ventral.lh',
#  'rsfmri_var_cort.destrieux_g.cuneus.lh',
#  'rsfmri_var_cort.destrieux_g.front.inf.opercular.lh',
#  'rsfmri_var_cort.destrieux_g.front.inf.orbital.lh',
#  'rsfmri_var_cort.destrieux_g.front.inf.triangul.lh',
#  'rsfmri_var_cort.destrieux_g.front.middle.lh',
#  'rsfmri_var_cort.destrieux_g.front.sup.lh',
#  'rsfmri_var_cort.destrieux_g.ins.lg.and.s.cent.ins.lh',
#  'rsfmri_var_cort.destrieux_g.insular.short.lh',
#  'rsfmri_var_cort.destrieux_g.occipital.middle.lh',
#  'rsfmri_var_cort.destrieux_g.occipital.sup.lh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.lat.fusifor.lh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.med.lingual.lh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.med.parahip.lh',
#  'rsfmri_var_cort.destrieux_g.orbital.lh',
#  'rsfmri_var_cort.destrieux_g.pariet.inf.angular.lh',
#  'rsfmri_var_cort.destrieux_g.pariet.inf.supramar.lh',
#  'rsfmri_var_cort.destrieux_g.parietal.sup.lh',
#  'rsfmri_var_cort.destrieux_g.postcentral.lh',
#  'rsfmri_var_cort.destrieux_g.precentral.lh',
#  'rsfmri_var_cort.destrieux_g.precuneus.lh',
#  'rsfmri_var_cort.destrieux_g.rectus.lh',
#  'rsfmri_var_cort.destrieux_g.subcallosal.lh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.g.t.transv.lh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.lateral.lh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.plan.polar.lh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.plan.tempo.lh',
#  'rsfmri_var_cort.destrieux_g.temporal.inf.lh',
#  'rsfmri_var_cort.destrieux_g.temporal.middle.lh',
#  'rsfmri_var_cort.destrieux_lat.fis.ant.horizont.lh',
#  'rsfmri_var_cort.destrieux_lat.fis.ant.vertical.lh',
#  'rsfmri_var_cort.destrieux_lat.fis.post.lh',
#  'rsfmri_var_cort.destrieux_pole.occipital.lh',
#  'rsfmri_var_cort.destrieux_pole.temporal.lh',
#  'rsfmri_var_cort.destrieux_s.calcarine.lh',
#  'rsfmri_var_cort.destrieux_s.central.lh',
#  'rsfmri_var_cort.destrieux_s.cingul.marginalis.lh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.ant.lh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.inf.lh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.sup.lh',
#  'rsfmri_var_cort.destrieux_s.collat.transv.ant.lh',
#  'rsfmri_var_cort.destrieux_s.collat.transv.post.lh',
#  'rsfmri_var_cort.destrieux_s.front.inf.lh',
#  'rsfmri_var_cort.destrieux_s.front.middle.lh',
#  'rsfmri_var_cort.destrieux_s.front.sup.lh',
#  'rsfmri_var_cort.destrieux_s.interm.prim.jensen.lh',
#  'rsfmri_var_cort.destrieux_s.intrapariet.and.p.trans.lh',
#  'rsfmri_var_cort.destrieux_s.oc.middle.and.lunatus.lh',
#  'rsfmri_var_cort.destrieux_s.oc.sup.and.transversal.lh',
#  'rsfmri_var_cort.destrieux_s.occipital.ant.lh',
#  'rsfmri_var_cort.destrieux_s.oc.temp.lat.lh',
#  'rsfmri_var_cort.destrieux_s.oc.temp.med.and.lingual.lh',
#  'rsfmri_var_cort.destrieux_s.orbital.lateral.lh',
#  'rsfmri_var_cort.destrieux_s.orbital.med.olfact.lh',
#  'rsfmri_var_cort.destrieux_s.orbital.h.shaped.lh',
#  'rsfmri_var_cort.destrieux_s.parieto.occipital.lh',
#  'rsfmri_var_cort.destrieux_s.pericallosal.lh',
#  'rsfmri_var_cort.destrieux_s.postcentral.lh',
#  'rsfmri_var_cort.destrieux_s.precentral.inf.part.lh',
#  'rsfmri_var_cort.destrieux_s.precentral.sup.part.lh',
#  'rsfmri_var_cort.destrieux_s.suborbital.lh',
#  'rsfmri_var_cort.destrieux_s.subparietal.lh',
#  'rsfmri_var_cort.destrieux_s.temporal.inf.lh',
#  'rsfmri_var_cort.destrieux_s.temporal.sup.lh',
#  'rsfmri_var_cort.destrieux_s.temporal.transverse.lh',
#  'rsfmri_var_cort.destrieux_g.and.s.frontomargin.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.occipital.inf.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.paracentral.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.subcentral.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.transv.frontopol.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.ant.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.ant.rh',
#  'rsfmri_var_cort.destrieux_g.and.s.cingul.mid.post.rh',
#  'rsfmri_var_cort.destrieux_g.cingul.post.dorsal.rh',
#  'rsfmri_var_cort.destrieux_g.cingul.post.ventral.rh',
#  'rsfmri_var_cort.destrieux_g.cuneus.rh',
#  'rsfmri_var_cort.destrieux_g.front.inf.opercular.rh',
#  'rsfmri_var_cort.destrieux_g.front.inf.orbital.rh',
#  'rsfmri_var_cort.destrieux_g.front.inf.triangul.rh',
#  'rsfmri_var_cort.destrieux_g.front.middle.rh',
#  'rsfmri_var_cort.destrieux_g.front.sup.rh',
#  'rsfmri_var_cort.destrieux_g.ins.lg.and.s.cent.ins.rh',
#  'rsfmri_var_cort.destrieux_g.insular.short.rh',
#  'rsfmri_var_cort.destrieux_g.occipital.middle.rh',
#  'rsfmri_var_cort.destrieux_g.occipital.sup.rh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.lat.fusifor.rh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.med.lingual.rh',
#  'rsfmri_var_cort.destrieux_g.oc.temp.med.parahip.rh',
#  'rsfmri_var_cort.destrieux_g.orbital.rh',
#  'rsfmri_var_cort.destrieux_g.pariet.inf.angular.rh',
#  'rsfmri_var_cort.destrieux_g.pariet.inf.supramar.rh',
#  'rsfmri_var_cort.destrieux_g.parietal.sup.rh',
#  'rsfmri_var_cort.destrieux_g.postcentral.rh',
#  'rsfmri_var_cort.destrieux_g.precentral.rh',
#  'rsfmri_var_cort.destrieux_g.precuneus.rh',
#  'rsfmri_var_cort.destrieux_g.rectus.rh',
#  'rsfmri_var_cort.destrieux_g.subcallosal.rh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.g.t.transv.rh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.lateral.rh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.plan.polar.rh',
#  'rsfmri_var_cort.destrieux_g.temp.sup.plan.tempo.rh',
#  'rsfmri_var_cort.destrieux_g.temporal.inf.rh',
#  'rsfmri_var_cort.destrieux_g.temporal.middle.rh',
#  'rsfmri_var_cort.destrieux_lat.fis.ant.horizont.rh',
#  'rsfmri_var_cort.destrieux_lat.fis.ant.vertical.rh',
#  'rsfmri_var_cort.destrieux_lat.fis.post.rh',
#  'rsfmri_var_cort.destrieux_pole.occipital.rh',
#  'rsfmri_var_cort.destrieux_pole.temporal.rh',
#  'rsfmri_var_cort.destrieux_s.calcarine.rh',
#  'rsfmri_var_cort.destrieux_s.central.rh',
#  'rsfmri_var_cort.destrieux_s.cingul.marginalis.rh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.ant.rh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.inf.rh',
#  'rsfmri_var_cort.destrieux_s.circular.insula.sup.rh',
#  'rsfmri_var_cort.destrieux_s.collat.transv.ant.rh',
#  'rsfmri_var_cort.destrieux_s.collat.transv.post.rh',
#  'rsfmri_var_cort.destrieux_s.front.inf.rh',
#  'rsfmri_var_cort.destrieux_s.front.middle.rh',
#  'rsfmri_var_cort.destrieux_s.front.sup.rh',
#  'rsfmri_var_cort.destrieux_s.interm.prim.jensen.rh',
#  'rsfmri_var_cort.destrieux_s.intrapariet.and.p.trans.rh',
#  'rsfmri_var_cort.destrieux_s.oc.middle.and.lunatus.rh',
#  'rsfmri_var_cort.destrieux_s.oc.sup.and.transversal.rh',
#  'rsfmri_var_cort.destrieux_s.occipital.ant.rh',
#  'rsfmri_var_cort.destrieux_s.oc.temp.lat.rh',
#  'rsfmri_var_cort.destrieux_s.oc.temp.med.and.lingual.rh',
#  'rsfmri_var_cort.destrieux_s.orbital.lateral.rh',
#  'rsfmri_var_cort.destrieux_s.orbital.med.olfact.rh',
#  'rsfmri_var_cort.destrieux_s.orbital.h.shaped.rh',
#  'rsfmri_var_cort.destrieux_s.parieto.occipital.rh',
#  'rsfmri_var_cort.destrieux_s.pericallosal.rh',
#  'rsfmri_var_cort.destrieux_s.postcentral.rh',
#  'rsfmri_var_cort.destrieux_s.precentral.inf.part.rh',
#  'rsfmri_var_cort.destrieux_s.precentral.sup.part.rh',
#  'rsfmri_var_cort.destrieux_s.suborbital.rh',
#  'rsfmri_var_cort.destrieux_s.subparietal.rh',
#  'rsfmri_var_cort.destrieux_s.temporal.inf.rh',
#  'rsfmri_var_cort.destrieux_s.temporal.sup.rh',
#  'rsfmri_var_cort.destrieux_s.temporal.transverse.rh']

# %%
train_data_processed = train_data.fillna(0).reset_index(drop=True)
features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] + mri] 

object_feat =[]

j=0
for i in test_data[features].dtypes:
    #print(j)
    if i == 'object':
        print(test_data[features].columns[j])
        object_feat.append(test_data[features].columns[j])
    j+=1
    
print(object_feat)

features = [ col for col in train_data_processed.columns if col not in unused_feat + [target] +mri +object_feat]
# Out:
# []

# %%
def preproecessing (train_data, test_data, NUM_FOLDS):
    test_data_processed= test_data.fillna(0).reset_index(drop=True)
    train_data_processed = train_data.fillna(0).reset_index(drop=True)
    
    test_data_processed["kfold"] = -1

    train_data_processed["kfold"] = -1

    train_data_processed = train_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)

    kf = KFold(n_splits=NUM_FOLDS)

    for fold, (trn_, val_) in enumerate(kf.split(X=train_data_processed, y=train_data_processed)):
        train_data_processed.loc[val_, 'kfold'] = fold
    print("done preprocessing")
    return train_data_processed, test_data_processed

def rocvis(true , prob , label ) :
    from sklearn.metrics import roc_curve
    if type(true[0]) == str :
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        true = le.fit_transform(true)
    else :
        pass
    fpr, tpr, thresholds = roc_curve(true, prob)
    plt.plot(fpr, tpr, marker='.', label = label  )
    
# Augmented
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm

def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 


    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

def find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test):
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    # define hyperparameter space
    """
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    # Orginal hyperparameter space 
    """
    # define hyperparameter space (quick version)
    n_ = [4,8]
    lr_ = [2e-2,1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99]
    ss_ = [10, 20]
  
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    for hy in tqdm(h_space):
        clf = TabNetClassifier(n_a = hy[0],
                               n_d = hy[0],
                               optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                               scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                               scheduler_fn=torch.optim.lr_scheduler.StepLR,
                               verbose=0
                               )
        clf.fit(X_train, Y_train, X_valid, Y_valid, patience=10, batch_size=256, max_epochs=200)
        #clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200) (Recommended)
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
        print("--------Valid score: {} --------------------".format(-clf.best_cost))
        print("--------Test auc: {} Test acc:{}-------------".format(test_auc, test_acc) )
        if test_auc>max_auc:
            max_hy = hy
            max_auc = test_auc
    return max_hy
    
def bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test, max_hy, features):
 
    hy = max_hy
    clf = TabNetClassifier(n_a = hy[0],
                           n_d = hy[0],
                           optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                           scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                           scheduler_fn=torch.optim.lr_scheduler.StepLR,
                           verbose=0
                               )
    clf.fit(X_train, Y_train, X_valid, Y_valid, patience=50, batch_size=256, max_epochs=200)
    preds_acc = clf.predict(X_test)
    preds_prob = clf.predict_proba(X_test)
    test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
    test_acc = accuracy_score(preds_acc, Y_test)
    
    
    
    print("Max hy:" ,hy)
    print("--------Valid score: {} --------------------".format(-clf.best_cost))
    print("FINAL TEST SCORE(max) test auc: {} test acc: {}".format(test_auc, test_acc))
    return test_auc, clf, preds_prob
    
    
def run(train_data_processed, test_data_processed, fold, Num_feat, features):
    X_test = test_data_processed[features].values
    Y_test = test_data_processed[target].values

    df_train = train_data_processed[train_data_processed.kfold != fold]
    df_valid = train_data_processed[train_data_processed.kfold == fold]
    
    X_train = df_train[features].values
    Y_train = df_train[target].values
    
    X_valid = df_valid[features].values
    Y_valid = df_valid[target].values
    
    y_oof = np.zeros((df_valid.shape[0],len(target)))   # Out of folds validation
    
    print("---------------------------------------Training Begining for fold {}-------------------------------".format(fold+1))
    n_ = [4,8,16]
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4]
    w_ = [0.01, 0.001, 0.0001]
    g_ = [0.95, 0.99, 0.9]
    ss_ = [10, 20, 30]
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    # Start training
    max_hy = find_bestpar(X_train, Y_train, X_valid, Y_valid, X_test, Y_test)
    
    print("Found maximum hyperparmeter, now work with that")
    
    test_auc, clf, preds_prob = bestpar_tuning(X_train, Y_train, X_valid, Y_valid, X_test, Y_test
                                               , max_hy, features)
    
    import_feat=feature(Num_feat, clf, test_data_processed, features)
    preds_val_prob = clf.predict_proba(X_valid)

    return test_auc, Y_test, clf, preds_prob, import_feat, Y_valid, preds_val_prob



    
def hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat):
    CV_auc_all = []
    train_data_processed, test_data_processed = preproecessing (train_data, test_data, Num_FOLDS)
    import_feat_every = pd.DataFrame()
    features_all = [ col for col in train_data_processed.columns if col not in unused_feat + [target]] 
    features_mri = [ col for col in mri if col not in 'rsfmri_cor_network.gordon_subcort.aseg_visitid']  
    features_pheno = [ col for col in train_data_processed.columns if col not in unused_feat + [target] 
                +mri] 
    print("all")
    test_auc_all, Y_test_all, clf, preds_prob_all, import_feat_all, Y_valid_all, preds_val_prob_all = run(train_data_processed,
                                                                         test_data_processed,
                                                                         0, 
                                                                         Num_feat, 
                                                                         features_all
                                             )
    print("pheno")
    test_auc_pheno, Y_test_pheno, clf, preds_prob_pheno, import_feat_pheno, Y_valid_pheno, preds_val_prob_pheno = run(train_data_processed, test_data_processed, 
                                            0, Num_feat, features_pheno)
  
    print("mri")
    test_auc_mri, Y_test_mri, clf, preds_prob_mri, import_feat_mri, Y_valid_mri, preds_val_prob_mri = run(train_data_processed, test_data_processed,
                                            0, Num_feat, features_mri)
  
    
    fig , ax = plt.subplots(figsize= (20,10))
    plt.plot([0, 1], [0, 1], linestyle='--')
    rocvis(Y_test_all , preds_prob_all[:,1] , "MRI+Pheno")
    rocvis(Y_test_pheno , preds_prob_pheno[:,1] , "Pheno")
    rocvis(Y_test_mri , preds_prob_mri[:,1] , "MRI")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
    plt.legend(fontsize = 20)
    plt.title(dataset_name, fontsize= 25)
    plt.tight_layout()
    plt.savefig(f'{dataset_name}_ROC.png')

    
    plt.show()
    return test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri

# %%
test_auc_all, test_auc_pheno, test_auc_mri, import_feat_all, import_feat_pheno, import_feat_mri, Y_test_all , preds_prob_all, Y_test_pheno , preds_prob_pheno, Y_test_mri , preds_prob_mri, Y_valid_all, preds_val_prob_all, Y_valid_pheno, preds_val_prob_pheno, Y_valid_mri, preds_val_prob_mri= hyperparametertuning_CV (train_data, test_data, target, unused_feat, Num_FOLDS, Num_feat)
# Out:
# done preprocessing
# all
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.7608835269049548 --------------------
# --------Test auc: 0.7536646716974585 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7596410671948621 --------------------
# --------Test auc: 0.7414057304767687 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7654752258335582 --------------------
# --------Test auc: 0.7488073553647325 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7578163920650641 --------------------
# --------Test auc: 0.7593315407523058 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7619339155487531 --------------------
# --------Test auc: 0.7501951600312255 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7629542930884426 --------------------
# --------Test auc: 0.7405383525602105 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7671978632093875 --------------------
# --------Test auc: 0.7385144707549081 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7629542930884426 --------------------
# --------Test auc: 0.7405383525602105 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7552474415533749 --------------------
# --------Test auc: 0.721398213201492 Test acc:0.543010752688172-------------
# Device used : cuda
# --------Valid score: 0.7577473665256145 --------------------
# --------Test auc: 0.7263133547286553 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.750838810359833 --------------------
# --------Test auc: 0.7216295139792408 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.762462110981063 --------------------
# --------Test auc: 0.7252291323329575 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7599231715734822 --------------------
# --------Test auc: 0.7414924682684246 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7611536268419317 --------------------
# --------Test auc: 0.7445861161708157 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7496833828516551 --------------------
# --------Test auc: 0.7368664527134472 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7605474025389396 --------------------
# --------Test auc: 0.7519877410587794 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.755487530386243 --------------------
# --------Test auc: 0.7317489230057537 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7568800456168783 --------------------
# --------Test auc: 0.7339462803943678 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7517961645808948 --------------------
# --------Test auc: 0.719027380229566 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7700789292038054 --------------------
# --------Test auc: 0.7351606094775496 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7686383962065965 --------------------
# --------Test auc: 0.7211379998265244 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7541190240388944 --------------------
# --------Test auc: 0.7052649839535087 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.7590768584376218 --------------------
# --------Test auc: 0.7207621360626825 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7541190240388944 --------------------
# --------Test auc: 0.7052649839535087 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.7612076468293268 --------------------
# --------Test auc: 0.7387746841298753 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7695327271090304 --------------------
# --------Test auc: 0.7540116228640819 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.756033732481018 --------------------
# --------Test auc: 0.7284239743256137 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7702740013805108 --------------------
# --------Test auc: 0.7516986150865932 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7345877974850694 --------------------
# --------Test auc: 0.7423887587822015 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7313946160079229 --------------------
# --------Test auc: 0.728337236533958 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.734677830797395 --------------------
# --------Test auc: 0.731575447422442 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7416524113922152 --------------------
# --------Test auc: 0.735044959088675 Test acc:0.5403225806451613-------------
# Device used : cuda
# --------Valid score: 0.750943849224213 --------------------
# --------Test auc: 0.731430884436349 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7386332943188981 --------------------
# --------Test auc: 0.7291178766588604 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7397857207166652 --------------------
# --------Test auc: 0.7203862722988406 Test acc:0.543010752688172-------------
# Device used : cuda
# --------Valid score: 0.7426307733861529 --------------------
# --------Test auc: 0.7240003469511667 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7485129497914229 --------------------
# --------Test auc: 0.7154422181744586 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7570000900333123 --------------------
# --------Test auc: 0.7332234654639026 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.752606464391825 --------------------
# --------Test auc: 0.7375025298522566 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7480927943339035 --------------------
# --------Test auc: 0.7005522306068754 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.7577683742984904 --------------------
# --------Test auc: 0.7094283979529882 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.7431469643768195 --------------------
# --------Test auc: 0.7234220950067943 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7568440322919481 --------------------
# --------Test auc: 0.7022002486483361 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7477986855136399 --------------------
# --------Test auc: 0.7260242287564693 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.741958524654122 --------------------
# --------Test auc: 0.6576748489316795 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7324810179766513 --------------------
# --------Test auc: 0.6695290137913088 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.7441553374748656 --------------------
# --------Test auc: 0.6803712377482869 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7559557036103358 --------------------
# --------Test auc: 0.6997426778847544 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.750049518321779 --------------------
# --------Test auc: 0.71665654725764 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7130008102998109 --------------------
# --------Test auc: 0.6812386156648452 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7027520182467513 --------------------
# --------Test auc: 0.6805736259288172 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7509318447825695 --------------------
# --------Test auc: 0.732760863908405 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7461000570210977 --------------------
# --------Test auc: 0.7106716396333881 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7547732661084601 --------------------
# --------Test auc: 0.710324688466765 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7444374418534858 --------------------
# --------Test auc: 0.711278804174979 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7337804987845503 --------------------
# --------Test auc: 0.6691820626246856 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7215089583145764 --------------------
# --------Test auc: 0.633590655448579 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7306683472884966 --------------------
# --------Test auc: 0.7078382051059646 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7257285195522343 --------------------
# --------Test auc: 0.6834937982478967 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7102067765073077 --------------------
# --------Test auc: 0.6617515251395034 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5598631493652652 --------------------
# --------Test auc: 0.5619163269436493 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5458959815131599 --------------------
# --------Test auc: 0.5475178535287825 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5458959815131599 --------------------
# --------Test auc: 0.5475178535287825 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5458959815131599 --------------------
# --------Test auc: 0.5475178535287825 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5578103898442425 --------------------
# --------Test auc: 0.5515656171393877 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.5543531106509408 --------------------
# --------Test auc: 0.55130540376442 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.5627982353470784 --------------------
# --------Test auc: 0.5417064214878422 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.5543531106509408 --------------------
# --------Test auc: 0.55130540376442 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.5815791842981903 --------------------
# --------Test auc: 0.5846994535519126 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.5857357222172204 --------------------
# --------Test auc: 0.5721513863590366 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.53895741424327 --------------------
# --------Test auc: 0.5566831468470813 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.6164941028180426 --------------------
# --------Test auc: 0.597030676265649 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7699768914498364 --------------------
# --------Test auc: 0.7277878971868043 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.769052549443294 --------------------
# --------Test auc: 0.7411166045045827 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7632604063503496 --------------------
# --------Test auc: 0.7432416804001503 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.769052549443294 --------------------
# --------Test auc: 0.7411166045045827 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7589208006962576 --------------------
# --------Test auc: 0.7489519183508254 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7672098676510309 --------------------
# --------Test auc: 0.7341486685748981 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7655532547042406 --------------------
# --------Test auc: 0.7336860670194004 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7632964196752798 --------------------
# --------Test auc: 0.7395842368519965 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.7493712673689265 --------------------
# --------Test auc: 0.7224679792985804 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7498154317097325 --------------------
# --------Test auc: 0.7386734900396104 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.75568860478377 --------------------
# --------Test auc: 0.7202995345071848 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7480987965547253 --------------------
# --------Test auc: 0.7011304825512475 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7648690015305663 --------------------
# --------Test auc: 0.7402492265880245 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7659914168242251 --------------------
# --------Test auc: 0.7433139618931969 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7648690015305663 --------------------
# --------Test auc: 0.7402492265880245 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7681702229825036 --------------------
# --------Test auc: 0.7498192962673836 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.752828546562228 --------------------
# --------Test auc: 0.7070575649810622 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7541490351430029 --------------------
# --------Test auc: 0.7224390667013618 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7460220281504155 --------------------
# --------Test auc: 0.6917338884552 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7472284745355783 --------------------
# --------Test auc: 0.697863359065545 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.7659914168242249 --------------------
# --------Test auc: 0.7118859687165697 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.761267669037544 --------------------
# --------Test auc: 0.7247231618816319 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7523963866630653 --------------------
# --------Test auc: 0.7082429814670252 Test acc:0.5645161290322581-------------
# Device used : cuda
# --------Valid score: 0.761267669037544 --------------------
# --------Test auc: 0.7247231618816319 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7747426547822693 --------------------
# --------Test auc: 0.7695666001676931 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7744905615077579 --------------------
# --------Test auc: 0.7414057304767687 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7762792233126257 --------------------
# --------Test auc: 0.7452800185040622 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7769874853695867 --------------------
# --------Test auc: 0.7498192962673838 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7544491461840881 --------------------
# --------Test auc: 0.7304767687281348 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7404819783319827 --------------------
# --------Test auc: 0.7442680776014108 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7485489631163531 --------------------
# --------Test auc: 0.7380807817966287 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7470844212358572 --------------------
# --------Test auc: 0.733049989880591 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7432610065724319 --------------------
# --------Test auc: 0.6930927805244746 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.751916208997329 --------------------
# --------Test auc: 0.6994246393153498 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.755991716935266 --------------------
# --------Test auc: 0.6952612253158701 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7431409621559977 --------------------
# --------Test auc: 0.6909821609275162 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5200864319798325 --------------------
# --------Test auc: 0.467863648191517 Test acc:0.49193548387096775-------------
# Device used : cuda
# --------Valid score: 0.744797575102788 --------------------
# --------Test auc: 0.6954347008991818 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5200864319798325 --------------------
# --------Test auc: 0.467863648191517 Test acc:0.49193548387096775-------------
# Device used : cuda
# --------Valid score: 0.7579424387023199 --------------------
# --------Test auc: 0.7313441466446932 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7536748596980885 --------------------
# --------Test auc: 0.7069419145921878 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.757354221061793 --------------------
# --------Test auc: 0.7132159481886259 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7534407730860418 --------------------
# --------Test auc: 0.736664064532917 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7563818612886769 --------------------
# --------Test auc: 0.727007257061902 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.726442783830017 --------------------
# --------Test auc: 0.6723913609159511 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.752468413312926 --------------------
# --------Test auc: 0.7238268713678551 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7152246331142523 --------------------
# --------Test auc: 0.6858357186226038 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7500615227634225 --------------------
# --------Test auc: 0.7329343394917165 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.4928423516701179 --------------------
# --------Test auc: 0.47812762020412297 Test acc:0.4838709677419355-------------
# Device used : cuda
# --------Valid score: 0.4928423516701179 --------------------
# --------Test auc: 0.47812762020412297 Test acc:0.4838709677419355-------------
# Device used : cuda
# --------Valid score: 0.4928423516701179 --------------------
# --------Test auc: 0.47812762020412297 Test acc:0.4838709677419355-------------
# Device used : cuda
# --------Valid score: 0.4928423516701179 --------------------
# --------Test auc: 0.47812762020412297 Test acc:0.4838709677419355-------------
# Device used : cuda
# --------Valid score: 0.7477266588637796 --------------------
# --------Test auc: 0.6976609708850146 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5192581255064375 --------------------
# --------Test auc: 0.42403215080810713 Test acc:0.478494623655914-------------
# Device used : cuda
# --------Valid score: 0.5192581255064375 --------------------
# --------Test auc: 0.42403215080810713 Test acc:0.478494623655914-------------
# Device used : cuda
# --------Valid score: 0.5192581255064375 --------------------
# --------Test auc: 0.42403215080810713 Test acc:0.478494623655914-------------
# Device used : cuda
# --------Valid score: 0.5154467152846554 --------------------
# --------Test auc: 0.43047965998785664 Test acc:0.47580645161290325-------------
# Device used : cuda
# --------Valid score: 0.5154467152846554 --------------------
# --------Test auc: 0.43047965998785664 Test acc:0.47580645161290325-------------
# Device used : cuda
# --------Valid score: 0.5154467152846554 --------------------
# --------Test auc: 0.43047965998785664 Test acc:0.47580645161290325-------------
# Device used : cuda
# --------Valid score: 0.5154467152846554 --------------------
# --------Test auc: 0.43047965998785664 Test acc:0.47580645161290325-------------
# Device used : cuda
# --------Valid score: 0.5363944659524024 --------------------
# --------Test auc: 0.5093243126030012 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5363944659524024 --------------------
# --------Test auc: 0.5093243126030012 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5363944659524024 --------------------
# --------Test auc: 0.5093243126030012 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5363944659524024 --------------------
# --------Test auc: 0.5093243126030012 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5400078028870682 --------------------
# --------Test auc: 0.5245612513372077 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5400078028870682 --------------------
# --------Test auc: 0.5245612513372077 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5400078028870682 --------------------
# --------Test auc: 0.5245612513372077 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5400078028870682 --------------------
# --------Test auc: 0.5245612513372077 Test acc:0.5510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5506827526184689 --------------------
# --------Test auc: 0.5044091710758378 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.5506827526184689 --------------------
# --------Test auc: 0.5044091710758378 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.5506827526184689 --------------------
# --------Test auc: 0.5044091710758378 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.5506827526184689 --------------------
# --------Test auc: 0.5044091710758378 Test acc:0.5241935483870968-------------
#
# Found maximum hyperparmeter, now work with that
# Device used : cuda
# Max hy: (8, 0.005, 0.01, 0.95, 10)
# --------Valid score: 0.7747426547822693 --------------------
# FINAL TEST SCORE(max) test auc: 0.7695666001676931 test acc: 0.5349462365591398
# pheno
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.769661774856697 --------------------
# --------Test auc: 0.7477665018648625 Test acc:0.5591397849462365-------------
# Device used : cuda
# --------Valid score: 0.7704420635635185 --------------------
# --------Test auc: 0.7311995836586002 Test acc:0.5591397849462365-------------
# Device used : cuda
# --------Valid score: 0.7700549203205185 --------------------
# --------Test auc: 0.7468991239483043 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7704420635635185 --------------------
# --------Test auc: 0.7311995836586002 Test acc:0.5591397849462365-------------
# Device used : cuda
# --------Valid score: 0.7488670808199033 --------------------
# --------Test auc: 0.7436609130598201 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7532426997989256 --------------------
# --------Test auc: 0.7475062884898951 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7607154647219472 --------------------
# --------Test auc: 0.7482869286147975 Test acc:0.5564516129032258-------------
# Device used : cuda
# --------Valid score: 0.7580504786771106 --------------------
# --------Test auc: 0.7416659438517363 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7592479217310404 --------------------
# --------Test auc: 0.7214271257987105 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7606134269679782 --------------------
# --------Test auc: 0.7133026859802816 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.758344587497374 --------------------
# --------Test auc: 0.7181889149102264 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7586386963176375 --------------------
# --------Test auc: 0.726775956284153 Test acc:0.5483870967741935-------------
# Device used : cuda
# --------Valid score: 0.7593319528225442 --------------------
# --------Test auc: 0.745887183045653 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7541670418054679 --------------------
# --------Test auc: 0.7322693497556887 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7541910506887549 --------------------
# --------Test auc: 0.7428802729349179 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.764328801656613 --------------------
# --------Test auc: 0.7473906381010206 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7549473305122895 --------------------
# --------Test auc: 0.6994535519125684 Test acc:0.5591397849462365-------------
# Device used : cuda
# --------Valid score: 0.7356141772455808 --------------------
# --------Test auc: 0.7011593951484663 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7414843492092075 --------------------
# --------Test auc: 0.6795616850261659 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7356141772455808 --------------------
# --------Test auc: 0.7011593951484663 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7439812730710362 --------------------
# --------Test auc: 0.6888426287333392 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7392755319468203 --------------------
# --------Test auc: 0.7023737242316478 Test acc:0.5403225806451613-------------
# Device used : cuda
# --------Valid score: 0.7344437441853486 --------------------
# --------Test auc: 0.6907219475525487 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7389844242369678 --------------------
# --------Test auc: 0.6972851071211728 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7361063593529606 --------------------
# --------Test auc: 0.6992800763292566 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7519462201014376 --------------------
# --------Test auc: 0.7396709746436523 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.747858707721857 --------------------
# --------Test auc: 0.7446439413652528 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7531826775907086 --------------------
# --------Test auc: 0.7411166045045828 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.72662885267549 --------------------
# --------Test auc: 0.7074623413421227 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7385492632273941 --------------------
# --------Test auc: 0.7017376470928385 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7289757210167762 --------------------
# --------Test auc: 0.6838696620117386 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7385492632273941 --------------------
# --------Test auc: 0.7017376470928385 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7665676300231085 --------------------
# --------Test auc: 0.7104403388556394 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7269949881456138 --------------------
# --------Test auc: 0.677046289068147 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.7322169202604963 --------------------
# --------Test auc: 0.6870211351085668 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7473245100687255 --------------------
# --------Test auc: 0.7011304825512477 Test acc:0.5403225806451613-------------
# Device used : cuda
# --------Valid score: 0.7380630833408361 --------------------
# --------Test auc: 0.7268337814785902 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7231355601572581 --------------------
# --------Test auc: 0.701621996703964 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7190240388943909 --------------------
# --------Test auc: 0.6666088414722294 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.7260586416974281 --------------------
# --------Test auc: 0.6722178853326395 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7157588307673839 --------------------
# --------Test auc: 0.6745598057073466 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7159989196002522 --------------------
# --------Test auc: 0.6984126984126985 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7245400798295368 --------------------
# --------Test auc: 0.691358024691358 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7015575763032322 --------------------
# --------Test auc: 0.6696157515829648 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7081180036613547 --------------------
# --------Test auc: 0.6894208806777113 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.7202304852795535 --------------------
# --------Test auc: 0.6531933963627954 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7216470093934755 --------------------
# --------Test auc: 0.6947118859687165 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7259566039434591 --------------------
# --------Test auc: 0.6584265764593634 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7213709072356773 --------------------
# --------Test auc: 0.6839274872061758 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7349479307343716 --------------------
# --------Test auc: 0.7335704166305259 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7205005852165302 --------------------
# --------Test auc: 0.6803423251510683 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.6908196032532037 --------------------
# --------Test auc: 0.6562870442651862 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7099246721286877 --------------------
# --------Test auc: 0.6665799288750108 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7281234056600941 --------------------
# --------Test auc: 0.6766415127070865 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.704258575672999 --------------------
# --------Test auc: 0.6920519270246046 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7176195192221122 --------------------
# --------Test auc: 0.6819036054008731 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7180336724588098 --------------------
# --------Test auc: 0.6675051319860064 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.6905735121995139 --------------------
# --------Test auc: 0.6518923294879579 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.7196542720806698 --------------------
# --------Test auc: 0.6613467487784428 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7034122625371387 --------------------
# --------Test auc: 0.6621852140977825 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5372047657633324 --------------------
# --------Test auc: 0.5197039350044814 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5372047657633324 --------------------
# --------Test auc: 0.5197039350044814 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5372047657633324 --------------------
# --------Test auc: 0.5197039350044814 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5372047657633324 --------------------
# --------Test auc: 0.5197039350044814 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5440893130458269 --------------------
# --------Test auc: 0.5020094255066933 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5440893130458269 --------------------
# --------Test auc: 0.5020094255066933 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5440893130458269 --------------------
# --------Test auc: 0.5020094255066933 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5440893130458269 --------------------
# --------Test auc: 0.5020094255066933 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.5413042825845563 --------------------
# --------Test auc: 0.5201376239627606 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.5413042825845563 --------------------
# --------Test auc: 0.5201376239627606 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.5413042825845563 --------------------
# --------Test auc: 0.5201376239627606 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.5413042825845563 --------------------
# --------Test auc: 0.5201376239627606 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7621199843942259 --------------------
# --------Test auc: 0.7510625379477838 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.767509978692116 --------------------
# --------Test auc: 0.7405672651574291 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7632123885837759 --------------------
# --------Test auc: 0.7565270188221007 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7640196872842953 --------------------
# --------Test auc: 0.7623384508630411 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7397797184958436 --------------------
# --------Test auc: 0.7023158990372105 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7397797184958436 --------------------
# --------Test auc: 0.7023158990372105 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7507037603913448 --------------------
# --------Test auc: 0.7288865758811115 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7397797184958436 --------------------
# --------Test auc: 0.7023158990372105 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.766111461240659 --------------------
# --------Test auc: 0.7150229855147888 Test acc:0.543010752688172-------------
# Device used : cuda
# --------Valid score: 0.7591939017436451 --------------------
# --------Test auc: 0.6938155954549398 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7562738213138862 --------------------
# --------Test auc: 0.7307948072975394 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7582335464121726 --------------------
# --------Test auc: 0.7146471217509469 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7520722667386933 --------------------
# --------Test auc: 0.7388325093243127 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.748002761021578 --------------------
# --------Test auc: 0.7391794604909359 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7547372527835299 --------------------
# --------Test auc: 0.7414346430739873 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.748002761021578 --------------------
# --------Test auc: 0.7391794604909359 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7382371477446655 --------------------
# --------Test auc: 0.723017318645734 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7331742744815581 --------------------
# --------Test auc: 0.6864139705669761 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.7483809009333453 --------------------
# --------Test auc: 0.7233642698123572 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7348518952012246 --------------------
# --------Test auc: 0.684939428108827 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7049008133009214 --------------------
# --------Test auc: 0.6825396825396826 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7121635004951832 --------------------
# --------Test auc: 0.6593517795703587 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7315506737492873 --------------------
# --------Test auc: 0.7106716396333883 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.7121635004951832 --------------------
# --------Test auc: 0.6593517795703587 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.7460640436961676 --------------------
# --------Test auc: 0.721166912423743 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.7453377749767414 --------------------
# --------Test auc: 0.7346112701303958 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7393115452717506 --------------------
# --------Test auc: 0.7068840893977506 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7453377749767414 --------------------
# --------Test auc: 0.7346112701303958 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.7400618228744635 --------------------
# --------Test auc: 0.6989042125654147 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.757228174424537 --------------------
# --------Test auc: 0.7172926243964495 Test acc:0.5483870967741935-------------
# Device used : cuda
# --------Valid score: 0.7429188799855947 --------------------
# --------Test auc: 0.7192008558128776 Test acc:0.5376344086021505-------------
# Device used : cuda
# --------Valid score: 0.7497554095015155 --------------------
# --------Test auc: 0.7148061410356493 Test acc:0.543010752688172-------------
# Device used : cuda
# --------Valid score: 0.7297320008403109 --------------------
# --------Test auc: 0.6947986237603724 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7229915068575373 --------------------
# --------Test auc: 0.7060745366756296 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7300261096605745 --------------------
# --------Test auc: 0.6828866337063058 Test acc:0.5349462365591398-------------
# Device used : cuda
# --------Valid score: 0.7229915068575373 --------------------
# --------Test auc: 0.7060745366756296 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7459800126046637 --------------------
# --------Test auc: 0.7253303264232227 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7477446655262447 --------------------
# --------Test auc: 0.7298117789921068 Test acc:0.5241935483870968-------------
# Device used : cuda
# --------Valid score: 0.7443534107619819 --------------------
# --------Test auc: 0.7169023043339984 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.731394616007923 --------------------
# --------Test auc: 0.6355277994622257 Test acc:0.521505376344086-------------
# Device used : cuda
# --------Valid score: 0.7272290747576604 --------------------
# --------Test auc: 0.6789834330817937 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7179736502505927 --------------------
# --------Test auc: 0.6387660103507099 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7286516010924041 --------------------
# --------Test auc: 0.6782606181513287 Test acc:0.5268817204301075-------------
# Device used : cuda
# --------Valid score: 0.7179736502505927 --------------------
# --------Test auc: 0.6387660103507099 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7134839890759581 --------------------
# --------Test auc: 0.6626189030560615 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.7475826055640586 --------------------
# --------Test auc: 0.6985572613987915 Test acc:0.532258064516129-------------
# Device used : cuda
# --------Valid score: 0.7267428948711023 --------------------
# --------Test auc: 0.6343423829762629 Test acc:0.5295698924731183-------------
# Device used : cuda
# --------Valid score: 0.7339095465322168 --------------------
# --------Test auc: 0.6714083326105186 Test acc:0.5161290322580645-------------
# Device used : cuda
# --------Valid score: 0.5943279013234897 --------------------
# --------Test auc: 0.5501778124728944 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5943279013234897 --------------------
# --------Test auc: 0.5501778124728944 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5943279013234897 --------------------
# --------Test auc: 0.5501778124728944 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5943279013234897 --------------------
# --------Test auc: 0.5501778124728944 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5606014225263347 --------------------
# --------Test auc: 0.5288836846213896 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5606014225263347 --------------------
# --------Test auc: 0.5288836846213896 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5606014225263347 --------------------
# --------Test auc: 0.5288836846213896 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5606014225263347 --------------------
# --------Test auc: 0.5288836846213896 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5617718555865671 --------------------
# --------Test auc: 0.5051608986035215 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5617718555865671 --------------------
# --------Test auc: 0.5051608986035215 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5617718555865671 --------------------
# --------Test auc: 0.5051608986035215 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5617718555865671 --------------------
# --------Test auc: 0.5051608986035215 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.594198853575823 --------------------
# --------Test auc: 0.5209760892821003 Test acc:0.48655913978494625-------------
# Device used : cuda
# --------Valid score: 0.5930344227364124 --------------------
# --------Test auc: 0.5150200942550669 Test acc:0.48118279569892475-------------
# Device used : cuda
# --------Valid score: 0.6020797695147204 --------------------
# --------Test auc: 0.5190967704628907 Test acc:0.489247311827957-------------
# Device used : cuda
# --------Valid score: 0.5930344227364124 --------------------
# --------Test auc: 0.5150200942550669 Test acc:0.48118279569892475-------------
# Device used : cuda
# --------Valid score: 0.5841151225953604 --------------------
# --------Test auc: 0.5684794865122734 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5841151225953604 --------------------
# --------Test auc: 0.5684794865122734 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5841151225953604 --------------------
# --------Test auc: 0.5684794865122734 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5841151225953604 --------------------
# --------Test auc: 0.5684794865122734 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5815671798565469 --------------------
# --------Test auc: 0.588718304565299 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5815671798565469 --------------------
# --------Test auc: 0.588718304565299 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5815671798565469 --------------------
# --------Test auc: 0.588718304565299 Test acc:0.49731182795698925-------------
# Device used : cuda
# --------Valid score: 0.5815671798565469 --------------------
# --------Test auc: 0.588718304565299 Test acc:0.49731182795698925-------------
#
# Found maximum hyperparmeter, now work with that
# Device used : cuda
# Max hy: (8, 0.02, 0.01, 0.99, 20)
# --------Valid score: 0.7717055310464872 --------------------
# FINAL TEST SCORE(max) test auc: 0.7490964813369184 test acc: 0.5080645161290323
# mri
# ---------------------------------------Training Begining for fold 1-------------------------------
# HBox(children=(FloatProgress(value=0.0, max=144.0), HTML(value='')))
# Device used : cuda
# --------Valid score: 0.5335043966267519 --------------------
# --------Test auc: 0.4923526180356782 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5335043966267519 --------------------
# --------Test auc: 0.4923526180356782 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5335043966267519 --------------------
# --------Test auc: 0.4923526180356782 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5335043966267519 --------------------
# --------Test auc: 0.4923526180356782 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5654572191710933 --------------------
# --------Test auc: 0.5257755804203892 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5654572191710933 --------------------
# --------Test auc: 0.5257755804203892 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5654572191710933 --------------------
# --------Test auc: 0.5257755804203892 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5654572191710933 --------------------
# --------Test auc: 0.5257755804203892 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5423546712283545 --------------------
# --------Test auc: 0.4838234018561888 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5150925842561748 --------------------
# --------Test auc: 0.48639662300864484 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.4851475045766934 --------------------
# --------Test auc: 0.4959233237921763 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5150925842561748 --------------------
# --------Test auc: 0.48639662300864484 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.504501665616278 --------------------
# --------Test auc: 0.4933211900425015 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.504501665616278 --------------------
# --------Test auc: 0.4933211900425015 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.504501665616278 --------------------
# --------Test auc: 0.4933211900425015 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.504501665616278 --------------------
# --------Test auc: 0.4933211900425015 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5513940157858408 --------------------
# --------Test auc: 0.4434614161390118 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5513940157858408 --------------------
# --------Test auc: 0.4434614161390118 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5513940157858408 --------------------
# --------Test auc: 0.4434614161390118 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5513940157858408 --------------------
# --------Test auc: 0.4434614161390118 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5305483028720626 --------------------
# --------Test auc: 0.5294185676699338 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5200264097716154 --------------------
# --------Test auc: 0.5282476074825802 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.49201704630713367 --------------------
# --------Test auc: 0.5215543412264724 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5043726178686113 --------------------
# --------Test auc: 0.5038887443259028 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.520626631853786 --------------------
# --------Test auc: 0.5348685922456414 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.520626631853786 --------------------
# --------Test auc: 0.5348685922456414 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.520626631853786 --------------------
# --------Test auc: 0.5348685922456414 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.520626631853786 --------------------
# --------Test auc: 0.5348685922456414 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.48056781008973315 --------------------
# --------Test auc: 0.5003180385694047 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.48056781008973315 --------------------
# --------Test auc: 0.5003180385694047 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.48056781008973315 --------------------
# --------Test auc: 0.5003180385694047 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.48056781008973315 --------------------
# --------Test auc: 0.5003180385694047 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5029710993067436 --------------------
# --------Test auc: 0.5074016248879638 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5029710993067436 --------------------
# --------Test auc: 0.5074016248879638 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5029710993067436 --------------------
# --------Test auc: 0.5074016248879638 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5029710993067436 --------------------
# --------Test auc: 0.5074016248879638 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.543176975480928 --------------------
# --------Test auc: 0.5329892734264319 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.543176975480928 --------------------
# --------Test auc: 0.5329892734264319 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.543176975480928 --------------------
# --------Test auc: 0.5329892734264319 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.543176975480928 --------------------
# --------Test auc: 0.5329892734264319 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5462981303082141 --------------------
# --------Test auc: 0.5243299505594589 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5462981303082141 --------------------
# --------Test auc: 0.5243299505594589 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5462981303082141 --------------------
# --------Test auc: 0.5243299505594589 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5462981303082141 --------------------
# --------Test auc: 0.5243299505594589 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5443444074307494 --------------------
# --------Test auc: 0.4784022898776998 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5274931724738152 --------------------
# --------Test auc: 0.5115216699916153 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.4874223462681192 --------------------
# --------Test auc: 0.5167837626854022 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5274931724738152 --------------------
# --------Test auc: 0.5115216699916153 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5604573692266138 --------------------
# --------Test auc: 0.5024575707635817 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5659313946160079 --------------------
# --------Test auc: 0.5021106195969584 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5604573692266138 --------------------
# --------Test auc: 0.5024575707635817 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5659313946160079 --------------------
# --------Test auc: 0.5021106195969584 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5174844692536238 --------------------
# --------Test auc: 0.5029635412149074 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.5174844692536238 --------------------
# --------Test auc: 0.5029635412149074 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.5174844692536238 --------------------
# --------Test auc: 0.5029635412149074 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.5174844692536238 --------------------
# --------Test auc: 0.5029635412149074 Test acc:0.5134408602150538-------------
# Device used : cuda
# --------Valid score: 0.5220371537468864 --------------------
# --------Test auc: 0.528710209038078 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.5220371537468864 --------------------
# --------Test auc: 0.528710209038078 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.5220371537468864 --------------------
# --------Test auc: 0.528710209038078 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.5220371537468864 --------------------
# --------Test auc: 0.528710209038078 Test acc:0.5188172043010753-------------
# Device used : cuda
# --------Valid score: 0.5254404129527925 --------------------
# --------Test auc: 0.49952294214589305 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5239578644098316 --------------------
# --------Test auc: 0.49200566686905484 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5368836469493713 --------------------
# --------Test auc: 0.5348975048428601 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5239578644098316 --------------------
# --------Test auc: 0.49200566686905484 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.526061642807839 --------------------
# --------Test auc: 0.5099314771445919 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5301011374208457 --------------------
# --------Test auc: 0.4970942839795299 Test acc:0.510752688172043-------------
# Device used : cuda
# --------Valid score: 0.5321058791752948 --------------------
# --------Test auc: 0.5243588631566773 Test acc:0.5026881720430108-------------
# Device used : cuda
# --------Valid score: 0.5430149155187419 --------------------
# --------Test auc: 0.5147598808800995 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5434050598721527 --------------------
# --------Test auc: 0.511550582588834 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5474505567059812 --------------------
# --------Test auc: 0.5019371440136468 Test acc:0.5-------------
# Device used : cuda
# --------Valid score: 0.5376249212208517 --------------------
# --------Test auc: 0.5001590192847024 Test acc:0.5026881720430108-------------
# Device used : cuda
# --------Valid score: 0.539161489751208 --------------------
# --------Test auc: 0.48941798941798936 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5299060652441403 --------------------
# --------Test auc: 0.4799924827247232 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5299060652441403 --------------------
# --------Test auc: 0.4799924827247232 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5299060652441403 --------------------
# --------Test auc: 0.4799924827247232 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5299060652441403 --------------------
# --------Test auc: 0.4799924827247232 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5228264457849404 --------------------
# --------Test auc: 0.49788938040304165 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5399057651330993 --------------------
# --------Test auc: 0.48392459594645393 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5468383301821673 --------------------
# --------Test auc: 0.48680139936970546 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5297049908466132 --------------------
# --------Test auc: 0.507748576054587 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.4897632123885838 --------------------
# --------Test auc: 0.5016913869372885 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.4897632123885838 --------------------
# --------Test auc: 0.5016913869372885 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.4897632123885838 --------------------
# --------Test auc: 0.5016913869372885 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.4897632123885838 --------------------
# --------Test auc: 0.5016913869372885 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5259536028330483 --------------------
# --------Test auc: 0.5180848295602394 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5429008733231296 --------------------
# --------Test auc: 0.4844883915922167 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5259536028330483 --------------------
# --------Test auc: 0.5180848295602394 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5407430749377269 --------------------
# --------Test auc: 0.483693295168705 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.545550853815912 --------------------
# --------Test auc: 0.49885795240986497 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.545550853815912 --------------------
# --------Test auc: 0.49885795240986497 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.545550853815912 --------------------
# --------Test auc: 0.49885795240986497 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.545550853815912 --------------------
# --------Test auc: 0.49885795240986497 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5051228954713244 --------------------
# --------Test auc: 0.5035562494578889 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5296629753008613 --------------------
# --------Test auc: 0.5073293433949173 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5051228954713244 --------------------
# --------Test auc: 0.5035562494578889 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5296629753008613 --------------------
# --------Test auc: 0.5073293433949173 Test acc:0.5080645161290323-------------
# Device used : cuda
# --------Valid score: 0.5394315896881846 --------------------
# --------Test auc: 0.47984791973863017 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5394315896881846 --------------------
# --------Test auc: 0.47984791973863017 Test acc:0.5053763440860215-------------
# Device used : cuda
# --------Valid score: 0.5394315896881846 --------------------
# --------Test auc: 0.47984791973863017 Test acc:0.5053763440860215-------------
# Device used : cuda

# %%
fig , ax = plt.subplots(figsize= (20,10))
plt.plot([0, 1], [0, 1], linestyle='--')
rocvis(Y_test_all , preds_prob_all[:,1] , "MRI+Pheno")
rocvis(Y_test_pheno , preds_prob_pheno[:,1] , "Pheno")
rocvis(Y_test_mri , preds_prob_mri[:,1] , "MRI")
    #rocvis(caty_Test , catprob[:,1] , "CatBoost")
plt.legend(fontsize = 20)
plt.title(dataset_name, fontsize= 25)
plt.tight_layout()
plt.savefig(f'{dataset_name}_ROC.png')

# %%
valid_auc_all = roc_auc_score (Y_valid_all, preds_val_prob_all[:,1])
valid_auc_pheno = roc_auc_score (Y_valid_pheno, preds_val_prob_pheno[:,1])
valid_auc_mri = roc_auc_score (Y_valid_mri, preds_val_prob_mri[:,1])

# %%
print(dataset_name)
print("")
print("Test AUC")
print(f"Pheno+MRI:{round((test_auc_all)*100,2)}%")
print( f"Pheno:{round((test_auc_pheno),4)*100}%")
print(f"MRI:{round((test_auc_mri)*100,2)}%")
print("")
    
print("Valid AUC")

print( f"Pheno+MRI:{round(valid_auc_all,4)*100}%")
print( f"Pheno:{round(valid_auc_pheno*100,2)}%")
print( f"MRI:{round(valid_auc_mri,4)*100}%")
# Out:
# rsfMRI.fd01
#
# Test AUC
# Pheno+MRI:76.96%
# Pheno:74.91%
# MRI:54.41%
#
# Valid AUC
# Pheno+MRI:77.47%
# Pheno:77.17%
# MRI:50.68%

# %%
import_feat_every=pd.concat([import_feat_all,import_feat_pheno, import_feat_mri])

import_feat_every.to_csv(f"{dataset_name}_features.csv")

import_feat_every
# Out:
#                                          feature name     ratio
# 0                                      PPSP_frequency  0.144951
# 1                    Internal.and.External.Comobidity  0.133202
# 2                                         AnxDep.CBCL  0.114533
# 3   rsfmri_var_cort.destrieux_s.oc.temp.med.and.li...  0.068836
# 4                                      AnxDisord.CBCL  0.066534
# 5                                           high.educ  0.054606
# 6         rsfmri_var_cort.destrieux_s.temporal.sup.rh  0.043456
# 7                                        Depress.CBCL  0.043398
# 8                                     Aggressive.CBCL  0.035615
# 9                                                  Ne  0.028541
# 10       rsfmri_var_cort.destrieux_s.occipital.ant.rh  0.023584
# 11  rsfmri_var_cort.destrieux_g.cingul.post.ventra...  0.021937
# 12    rsfmri_var_cort.destrieux_s.orbital.h.shaped.rh  0.021667
# 13       rsfmri_var_cort.destrieux_g.insular.short.lh  0.019732
# 14                                        Stress.CBCL  0.016523
# 15    rsfmri_var_cort.destrieux_g.and.s.subcentral.lh  0.014405
# 16  rsfmri_var_cort.destrieux_lat.fis.ant.horizont.rh  0.013902
# 17   rsfmri_var_cort.destrieux_s.parieto.occipital.lh  0.010410
# 18           rsfmri_var_cort.destrieux_g.front.sup.lh  0.009850
# 19  rsfmri_var_cort.destrieux_g.cingul.post.dorsal.rh  0.007992
# 0                    Internal.and.External.Comobidity  0.164921
# 1                                       PPSP_distress  0.119031
# 2                                         AnxDep.CBCL  0.118204
# 3                                        Depress.CBCL  0.111343
# 4                          poa_total_6month_follow_up  0.089166
# 5                                        Conduct.CBCL  0.081862
# 6                                      PPSP_frequency  0.074847
# 7                                      AnxDisord.CBCL  0.070848
# 8                         nihtbx_cardsort_uncorrected  0.048462
# 9                                         Social.CBCL  0.016542
# 10                                       WithDep.CBCL  0.013631
# 11                                            fes_8_p  0.010956
# 12                         nihtbx_pattern_uncorrected  0.008882
# 13                                          abcd_site  0.006594
# 14                                             HC_CHM  0.005834
# 15                         nihtbx_flanker_uncorrected  0.005455
# 16                                      DOES_baseline  0.005255
# 17                         nihtbx_reading_uncorrected  0.004662
# 18                                       Somatic.CBCL  0.004573
# 19                                                age  0.004445
# 0   rsfmri_var_cort.destrieux_s.orbital.med.olfact.rh  0.111696
# 1   rsfmri_var_cort.destrieux_g.oc.temp.lat.fusifo...  0.106147
# 2   rsfmri_var_cort.destrieux_g.pariet.inf.angular.lh  0.053181
# 3     rsfmri_var_cort.destrieux_g.and.s.cingul.ant.lh  0.036038
# 4   rsfmri_var_cort.destrieux_g.front.inf.triangul.lh  0.028880
# 5   rsfmri_var_cort.destrieux_g.oc.temp.med.lingua...  0.024982
# 6   rsfmri_var_cort.destrieux_g.cingul.post.dorsal.rh  0.021842
# 7   rsfmri_var_cort.destrieux_s.precentral.inf.par...  0.020779
# 8           rsfmri_var_cort.destrieux_g.precentral.lh  0.017294
# 9   rsfmri_var_cort.destrieux_s.oc.middle.and.luna...  0.016545
# 10    rsfmri_var_cort.destrieux_g.and.s.subcentral.rh  0.014001
# 11         rsfmri_var_cort.destrieux_s.postcentral.rh  0.013974
# 12  rsfmri_var_cort.destrieux_g.and.s.frontomargin.lh  0.013918
# 13   rsfmri_var_cort.destrieux_g.and.s.paracentral.rh  0.013693
# 14  rsfmri_var_cort.destrieux_g.front.inf.opercula...  0.013402
# 15       rsfmri_var_cort.destrieux_g.insular.short.lh  0.012860
# 16         rsfmri_var_cort.destrieux_pole.temporal.lh  0.012612
# 17        rsfmri_var_cort.destrieux_s.temporal.inf.lh  0.012005
# 18           rsfmri_var_cort.destrieux_g.precuneus.lh  0.010923
# 19           rsfmri_var_cort.destrieux_g.precuneus.rh  0.010464
